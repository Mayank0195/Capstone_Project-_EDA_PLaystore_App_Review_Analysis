# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/Capstone_Project-_EDA_PLaystore_App_Review_Analysis/blob/main/Capstone_Project__EDA_PLaystore_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**The Play Store apps data has enormous potential to drive app-making** **businesses to success. Actionable insights can be drawn for developers to work** **on and capture the Android market.**
# #**Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.**
# #**Explore and analyze the data to discover key factors responsible for app engagement and success.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ## **Android Play Store Dataset Cleaning**
# #### **Overview and Motivation**
# This EDA project aims to discover patterns that lead to a successfull application on the Google Play Store. This will be done by analyzing the historical data collected from the Google Play Store as according to dataset source.
#
# Dataset columns description
# * **App:** Application name
# * **Category** Category the app belongs to
# * **Rating:** Overall user rating of the app (as when scraped)
# * **Reviews:** Number of user reviews for the app (as when scraped)
# * **Size:** Size of the app (as when scraped)
# * **Installs:** Number of user downloads/installs for the app (as when scraped)
# * **Type:** Paid or Free
# * **Price:** Price of the app (as when scraped)
# * **Content:** Rating Age group the app is targeted at - Children / Mature 21+ / Adult
# * **Genres:** An app can belong to multiple genres (apart from its main category). For eg, a musical family game will belong to Music, Game, Family genres.
# * **Last Updated:** Date when the app was last updated on Play Store (as when scraped)
# * **Current Ver:** Current version of the app available on Play Store (as when scraped)
# * **Android Ver:** Min required Android version (as when scraped)

# %%
# importing required file required for the EDA 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #**1. Dataset Reading**

# %%
# importing drive on the colab notebook for the easy access of the data provided 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing the pathway for the Playstore Data
route1='/content/drive/MyDrive/AlmaBetter/Capstone_Project_EDA/Play_Store_Data.csv'
df=pd.read_csv(route1)

# %%
#importing the pathway for the User reviews data
route2='/content/drive/MyDrive/AlmaBetter/Capstone_Project_EDA/User_Reviews.csv'
df_reviews=pd.read_csv(route2)

# %% [markdown]
# **Checking the Head and Tail of the Playstore data**

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 10831       Everyone  Maps & Navigation       June 13, 2018
# 10832       Everyone            Weather   February 16, 2014
# 10833       Everyone  Books & Reference      March 23, 2014
# 10834       Everyone          Education       June 18, 2017
# 10835       Everyone           Business  September 29, 2016
# 10836       Everyone          Education       July 25, 2017
# 10837       Everyone          Education        July 6, 2018
# 10838       Everyone            Medical    January 20, 2017
# 10839     Mature 17+  Books & Reference    January 19, 2015
# 10840       Everyone          Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device

# %% [markdown]
# **Checking he head and taill if the user review Data**

# %%
df_reviews.head(10)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
# 6  10 Best Foods for You                                            Amazing
# 7  10 Best Foods for You                                                NaN
# 8  10 Best Foods for You                               Looking forward app,
# 9  10 Best Foods for You              It helpful site ! It help foods get !
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000
# 6  Positive                0.60                0.900000
# 7       NaN                 NaN                     NaN
# 8   Neutral                0.00                0.000000
# 9   Neutral                0.00                0.000000

# %%
df_reviews.tail(10)
# Out:
#                                App Translated_Review Sentiment  \
# 64285  Houzz Interior Design Ideas               NaN       NaN
# 64286  Houzz Interior Design Ideas               NaN       NaN
# 64287  Houzz Interior Design Ideas               NaN       NaN
# 64288  Houzz Interior Design Ideas               NaN       NaN
# 64289  Houzz Interior Design Ideas               NaN       NaN
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64285                 NaN                     NaN
# 64286                 NaN                     NaN
# 64287                 NaN                     NaN
# 64288                 NaN                     NaN
# 64289                 NaN                     NaN
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# #**2. Dataset Discovery**
# **dicovering the dataset and get a notion of what the attributes describe**.

# %%
df.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
df_reviews.count()
# Out:
# App                       64295
# Translated_Review         37427
# Sentiment                 37432
# Sentiment_Polarity        37432
# Sentiment_Subjectivity    37432
# dtype: int64

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df_reviews.shape
# Out:
# (64295, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
#        'Trivia', 'Role Playing', 'Simulation;Education',
#        'Action;Action & Adventure', 'Casual;Brain Games',
#        'Simulation;Action & Adventure', 'Educational;Creativity',
#        'Puzzle;Brain Games', 'Educational;Education', 'Card;Brain Games',
#        'Educational;Brain Games', 'Educational;Pretend Play',
#        'Entertainment;Education', 'Casual;Education',
#        'Music;Music & Video', 'Racing;Action & Adventure',
#        'Arcade;Pretend Play', 'Role Playing;Action & Adventure',
#        'Simulation;Pretend Play', 'Puzzle;Creativity',
#        'Sports;Action & Adventure', 'Educational;Action & Adventure',
#        'Arcade;Action & Adventure', 'Entertainment;Action & Adventure',
#        'Puzzle;Action & Adventure', 'Strategy;Action & Adventure',
#        'Music & Audio;Music & Video', 'Health & Fitness;Education',
#        'Adventure;Education', 'Board;Brain Games',
#        'Board;Action & Adventure', 'Board;Pretend Play',
#        'Casual;Music & Video', 'Role Playing;Pretend Play',
#        'Entertainment;Pretend Play', 'Video Players & Editors;Creativity',
#        'Card;Action & Adventure', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Travel & Local',
#        'Travel & Local;Action & Adventure', 'Tools', 'Tools;Education',
#        'Personalization', 'Productivity', 'Parenting',
#        'Parenting;Music & Video', 'Parenting;Education',
#        'Parenting;Brain Games', 'Weather', 'Video Players & Editors',
#        'Video Players & Editors;Music & Video', 'News & Magazines',
#        'Maps & Navigation', 'Health & Fitness;Action & Adventure',
#        'Educational', 'Casino', 'Adventure;Brain Games',
#        'Trivia;Education', 'Lifestyle;Education',
#        'Books & Reference;Creativity', 'Books & Reference;Education',
#        'Puzzle;Education', 'Role Playing;Education',
#        'Role Playing;Brain Games', 'Strategy;Education',
#        'Racing;Pretend Play', 'Communication;Creativity',
#        'February 11, 2018', 'Strategy;Creativity'], dtype=object)

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df.Rating.unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
df.boxplot();

# %%
df_reviews.boxplot();

# %%
df.hist();

# %%
df_reviews.hist();

# %%
import missingno as msno
msno.matrix(df)
plt.show()

# %% [markdown]
# **This shows that the data has many missing values under the column Rating, Content Rating and Android Version.**

# %%
import missingno as msno
msno.matrix(df_reviews)
plt.show()

# %% [markdown]
# **This also shows that even the User Reviews csv is also full of missing data.**

# %% [markdown]
# #**3**.**DATA CLEANING**

# %% [markdown]
# **Counting the number of missing values in the Playstore Data.**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# **Checking the missing values in the User reviews data**

# %%
df_reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# ##**3.1 Outliers**
# An outlier is an object that deviates significantly from the rest of the objects. They can be caused by measurement or execution errors.

# %%
df.boxplot();
df.hist();

# %%
df[df.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.drop([10472], inplace = True)

# %%
df[10470:10474]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10473     August 7, 2018     6.06.14    4.4 and up
# 10474  November 21, 2014     2.2.1.5    2.2 and up

# %%
df.boxplot()

# %% [markdown]
# ###**3.2 Remove columns that are 90% empty**

# %%
len(df)
# Out:
# 10840

# %%
threshold = len(df) * 0.1
threshold
# Out:
# 1084.0

# %%
df.dropna(thresh = threshold, axis = 1, inplace = True)

# %%
print(df.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
boolean = df['App'].duplicated().any()
boolean
# Out:
# True

# %%
df['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9659, dtype: int64

# %% [markdown]
# ###**3.3 Checking for duplicate values**

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10357 rows x 13 columns]

# %%
df_reviews.drop_duplicates(inplace=True)

# %%
df_reviews
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
# 64236     Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
# 64236                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                     NaN                     NaN
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
# 64236                 NaN                     NaN
#
# [30679 rows x 5 columns]

# %% [markdown]
# #**4.DATA MANIPULATION**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10357 rows x 13 columns]

# %%
# Finding the mode values of Categorical columns
print(df['Type'].mode())
print(df['Current Ver'].mode())
print(df['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
# 0    Varies with device
# dtype: object
# 0    4.1 and up
# dtype: object

# %% [markdown]
# **Filling the Missing values with mode values of Type, Current ver and Android ver so that the values can be filled and the data looks more presentable.**

# %%
df['Type'].fillna(str(df['Type'].mode().values[0]),inplace=True)
df['Current Ver'].fillna(str(df['Current Ver'].mode().values[0]),inplace=True)
df['Android Ver'].fillna(str(df['Android Ver'].mode().values[0]),inplace=True)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %% [markdown]
# **Removing a $ sign from the Price as it was creating a hindarnce while doing the analysis of the data.**

# %%
df['Price'] = df['Price'].apply((lambda x: str(x).replace('$','')if '$' in str(x) else str(x)))
df['Price'] = df['Price'].apply((lambda x: float(x)))
df['Reviews'] = pd.to_numeric(df['Reviews'], errors ='coerce')

# %% [markdown]
# **Removing a + sign from the Installs as it was creating a hindarnce while doing the analysis of the data.**

# %%
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x)) 
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price
# count  8892.000000  1.035700e+04  1.035700e+04  10357.000000
# mean      4.187877  4.059046e+05  1.415776e+07      1.030800
# std       0.522377  2.696778e+06  8.023955e+07     16.278625
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.200000e+01  1.000000e+03      0.000000
# 50%       4.300000  1.680000e+03  1.000000e+05      0.000000
# 75%       4.500000  4.641600e+04  1.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# **Checking how many Apps are free for the user and how many are paid.**

# %%
df.Type.value_counts()
# Out:
# Free    9592
# Paid     765
# Name: Type, dtype: int64

# %%
df[df.Price>0].count()
# Out:
# App               765
# Category          765
# Rating            613
# Reviews           765
# Size              765
# Installs          765
# Type              765
# Price             765
# Content Rating    765
# Genres            765
# Last Updated      765
# Current Ver       765
# Android Ver       765
# dtype: int64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size    Installs  Type  Price  \
# 0         4.1      159                 19M     10000.0  Free    0.0
# 1         3.9      967                 14M    500000.0  Free    0.0
# 2         4.7    87510                8.7M   5000000.0  Free    0.0
# 3         4.5   215644                 25M  50000000.0  Free    0.0
# 4         4.3      967                2.8M    100000.0  Free    0.0
# ...       ...      ...                 ...         ...   ...    ...
# 10836     4.5       38                 53M      5000.0  Free    0.0
# 10837     5.0        4                3.6M       100.0  Free    0.0
# 10838     NaN        3                9.5M      1000.0  Free    0.0
# 10839     4.5      114  Varies with device      1000.0  Free    0.0
# 10840     4.5   398307                 19M  10000000.0  Free    0.0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10357 rows x 13 columns]

# %% [markdown]
# **Remove missing values.**

# %%
df.Rating.fillna(value=df['Rating'].median(),inplace=True)

# %% [markdown]
# **Removing the missing values as to make the data more presentable and suitable for analysis.**

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df)
plt.show()

# %% [markdown]
# **Showing that there is no missing value left in the data and that it is more presentable and suitable for analysis.**

# %%
g = df_reviews.groupby('App')
g

# %%
for App ,App_df_reviews in g:
    print(App)
    print(App_df_reviews),
# Out:
# Streaming output truncated to the last 5000 lines.
# 46208  Firefox Browser fast & private
# 46209  Firefox Browser fast & private
# 46214  Firefox Browser fast & private
#
#                                        Translated_Review Sentiment  \
# 46138  A made company actually cares. Mozilla favorit...  Positive
# 46139  Move downloads menu toolbar, never knew even e...  Positive
# 46140  This getting slow quite time. After readings r...  Negative
# 46141  Definately best Android simply install add-ons...  Positive
# 46142  Sadly recent upgrade work, even Beta version A...  Positive
# 46143                                                NaN       NaN
# 46144  Need option bring bar bottom. It permanent des...  Positive
# 46145  So far latest version (July 2018) seems great....  Positive
# 46146  Bookmarks borderline unusable. They accessed n...  Positive
# 46147  LG G3 Lately closing me. Don't know why. Only ...  Negative
# 46148  2018.06: Firefox updated since I made comments...  Negative
# 46149  I've desktop Firefox user long time recently d...  Positive
# 46150  Ugh disappointing I thought Firefox awesome mo...  Negative
# 46152  It seems every browser. The thing I like order...  Positive
# 46153  Could gesture navigation tools. Chrome allows ...  Positive
# 46154  Hello. The awesome I say something. When I lin...  Positive
# 46155  Why UI display indication registered I typed s...  Positive
# 46156  Give us option disable pocket. Tired garbage u...  Negative
# 46157  Pretty good, mobile devices PCs. Its better ot...  Positive
# 46158  Blocking unsigned add ons recourse overbearing...  Negative
# 46159  Wow, I cannot get pitiful is. I switched chrom...  Negative
# 46160  Love clean design language app. I really want ...  Positive
# 46161  Older tabs refresh opening FF again. Even clic...  Positive
# 46162  Doesn't handle incognito/private mode good goo...  Positive
# 46163  I'm lg v20, I've cleared cache end everything ...  Negative
# 46164  I know what's wrong suddenly work. I've using ...  Positive
# 46165  After update 61.0 constantly unloads itself, c...  Positive
# 46166  "auto cleaning private data select "quit" menu...  Positive
# 46167  extremely laggy unresponsive. Can't handle vid...  Negative
# 46169  I absolutely HATE using browser. They suck. Th...  Positive
# 46170  Distinct input lag chronically slow loading ti...  Positive
# 46172  I noticed sometimes setting page loading corre...  Positive
# 46174  Firefox used favorite PC Android. Now Firefox ...  Positive
# 46176  This utterly pathetic supposed computer progra...  Positive
# 46191  While great, I pixel 1 display size set small....  Positive
# 46208  Lacking important features ( backward , forwar...  Positive
# 46209  LOTS OF CRASHES since update! Besides, stopped...  Negative
# 46214  I hate pocket, otherwise great browser. I also...  Positive
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 46138            0.279911                0.496429
# 46139            0.459524                0.742857
# 46140           -0.018750                0.595833
# 46141            0.270833                0.385714
# 46142            0.033333                0.400000
# 46143                 NaN                     NaN
# 46144            0.085000                0.535000
# 46145            0.250758                0.578220
# 46146            0.136364                0.454545
# 46147           -0.075000                0.618750
# 46148           -0.075758                0.403030
# 46149            0.198951                0.408591
# 46150           -0.022917                0.766667
# 46152            0.250000                0.300000
# 46153            0.142857                0.267857
# 46154            0.233333                0.800000
# 46155            0.216667                0.466667
# 46156           -0.011111                0.347778
# 46157            0.241667                0.616667
# 46158           -0.195918                0.549660
# 46159           -0.085417                0.652917
# 46160            0.348485                0.423485
# 46161            0.150758                0.546970
# 46162            0.139583                0.447917
# 46163           -0.040043                0.281602
# 46164            0.083333                0.500000
# 46165            0.051791                0.433494
# 46166            0.240000                0.255000
# 46167           -0.131250                0.675000
# 46169            0.107143                0.537143
# 46170            0.009333                0.434000
# 46172            0.133333                0.794444
# 46174            0.160494                0.443210
# 46176            0.062500                0.584375
# 46191            0.141667                0.716667
# 46208            0.546429                0.583929
# 46209           -0.375000                0.591667
# 46214            0.025000                0.637500
# Firefox Focus: The privacy browser
#                                       App  \
# 46218  Firefox Focus: The privacy browser
# 46219  Firefox Focus: The privacy browser
# 46220  Firefox Focus: The privacy browser
# 46221  Firefox Focus: The privacy browser
# 46222  Firefox Focus: The privacy browser
# 46223  Firefox Focus: The privacy browser
# 46224  Firefox Focus: The privacy browser
# 46226  Firefox Focus: The privacy browser
# 46227  Firefox Focus: The privacy browser
# 46228  Firefox Focus: The privacy browser
# 46229  Firefox Focus: The privacy browser
# 46230  Firefox Focus: The privacy browser
# 46231  Firefox Focus: The privacy browser
# 46232  Firefox Focus: The privacy browser
# 46233  Firefox Focus: The privacy browser
# 46234  Firefox Focus: The privacy browser
# 46235  Firefox Focus: The privacy browser
# 46236  Firefox Focus: The privacy browser
# 46237  Firefox Focus: The privacy browser
# 46898                                   Crashing update.   Neutral
# 46901                         It's 1 best flight booking  Positive
# 46902                              Best flight booking .  Positive
# 46903               Very good cashback amount time .....  Positive
# 46904        It's user friendly ,and good resolve query.  Positive
# 46905  The show different price moment start booking ...  Positive
# 46907  Nice work ixigo. Best booking flight tkt reall...  Positive
# 46908  This best booking flight tickets smoothly. Lov...  Positive
# 46909           As I using first time till excellent per  Positive
# 46910                                          Very good  Positive
# 46911                 Have take trip, comments after....   Neutral
# 46912                Great !! Easy effective terms price  Positive
# 46913                                          Very Good  Positive
# 46914                                 I pleased say good  Positive
# 46916                  It's awesome flight hotel booking  Positive
# 46917                       The makes booking convenient   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 46878            0.320238                0.630159
# 46879           -0.246429                0.817857
# 46880            0.250000                0.375000
# 46881           -0.250000                0.625000
# 46882            0.450000                0.400000
# 46883            0.350000                0.800000
# 46884                 NaN                     NaN
# 46885            0.000000                0.000000
# 46886            1.000000                0.650000
# 46888           -0.500000                0.562500
# 46889           -0.500000                0.500000
# 46890            1.000000                1.000000
# 46891            0.300000                0.725000
# 46892           -0.040278                0.533333
# 46893            0.000000                0.000000
# 46894           -0.875000                0.875000
# 46895            0.000000                0.000000
# 46896            0.200000                0.200000
# 46898            0.000000                0.000000
# 46901            1.000000                0.300000
# 46902            1.000000                0.300000
# 46903            0.910000                0.780000
# 46904            0.537500                0.550000
# 46905            0.125000                0.550000
# 46907            0.650000                0.650000
# 46908            0.850000                0.550000
# 46909            0.625000                0.666667
# 46910            0.910000                0.780000
# 46911            0.000000                0.000000
# 46912            0.677778                0.794444
# 46913            0.910000                0.780000
# 46914            0.600000                0.800000
# 46916            1.000000                1.000000
# 46917            0.000000                0.000000
# Flightradar24 Flight Tracker
#                                 App  \
# 46918  Flightradar24 Flight Tracker
# 46919  Flightradar24 Flight Tracker
# 46920  Flightradar24 Flight Tracker
# 46921  Flightradar24 Flight Tracker
# 46922  Flightradar24 Flight Tracker
# 46923  Flightradar24 Flight Tracker
# 46924  Flightradar24 Flight Tracker
# 46925  Flightradar24 Flight Tracker
# 46929  Flightradar24 Flight Tracker
# 46931  Flightradar24 Flight Tracker
# 46932  Flightradar24 Flight Tracker
# 46933  Flightradar24 Flight Tracker
# 46934  Flightradar24 Flight Tracker
# 46936  Flightradar24 Flight Tracker
# 46937  Flightradar24 Flight Tracker
# 46938  Flightradar24 Flight Tracker
# 46940  Flightradar24 Flight Tracker
# 46941  Flightradar24 Flight Tracker
# 46942  Flightradar24 Flight Tracker
# 46943  Flightradar24 Flight Tracker
# 46944  Flightradar24 Flight Tracker
# 46945  Flightradar24 Flight Tracker
# 46946  Flightradar24 Flight Tracker
# 46948  Flightradar24 Flight Tracker
# 46949  Flightradar24 Flight Tracker
# 46950  Flightradar24 Flight Tracker
# 46951  Flightradar24 Flight Tracker
# 46952  Flightradar24 Flight Tracker
# 46953  Flightradar24 Flight Tracker
# 46954  Flightradar24 Flight Tracker
# 46955  Flightradar24 Flight Tracker
# 46956  Flightradar24 Flight Tracker
# 46957  Flightradar24 Flight Tracker
#
#                                        Translated_Review Sentiment  \
# 46918  I'm Gold User complain ads, cost subscription ...  Positive
# 46919  What great way piss previously loyal paying cu...  Positive
# 46920  Absolutely horrible unacceptable ads!! Full sc...  Negative
# 46921                                                NaN       NaN
# 46922  Pretty sure I bought paid version app. But ask...  Positive
# 46923  I love even though I absolutely downloaded whi...  Positive
# 46924  I spent past 2 days installing (7 far) would t...  Positive
# 46925  To clueless customer agent replying reviews su...  Positive
# 46929  I another user PAID full ad free version, see ...  Positive
# 46931  What done it? I can't see flight times one's I...   Neutral
# 46932  I found inaccurate. Flights overhead radar, sk...  Negative
# 46933  I love app.... I downloaded I lay garden, inst...  Positive
# 46934  I general aviation, airline stuff. The alerts ...  Positive
# 46936  I bought alot stuff unlocked says old updated ...  Positive
# 46937  What DF-AA-20 mean? Because I paid old app. I ...  Positive
# 46938  Love app. I alot air traffic work premises hou...  Positive
# 46940  Like adds annoying. I pay previously I changed...  Positive
# 46941  This simply awesome. I read negative reviews, ...  Positive
# 46942  An amazing real-time app. I understand info co...  Positive
# 46943  Great app, I enjoy watching planes flying ads ...  Positive
# 46944  Paid full version like many people. Opened who...  Positive
# 46945  Servers day poor lot keep taking stuff free si...  Positive
# 46946  The flight tracking feature amazing GUI convol...  Positive
# 46948  I sick getting pestered pop ups saying get app...  Positive
# 46949  Great aircraft fly home every minute I've alwa...  Positive
# 46950  Won't open...after years using I blank screen ...   Neutral
# 46951  Makes tracking arrival flights much easier try...  Positive
# 46952  Recently, flight goes nearest airport (Kualana...   Neutral
# 46953  The usefulness dropped significantly reducing ...  Positive
# 46954              What utter joke. Having pay top $3.99  Positive
# 46955  paid paid version gone replaced subscription b...  Positive
# 46956  An amazing experience using app. I trouble put...  Positive
# 46957  I like following Fire fighting aircraft. It he...   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 46918            0.320370                0.534259
# 46919            0.260185                0.612037
# 46920           -0.132143                0.669048
# 46921                 NaN                     NaN
# 46922            0.365000                0.747778
# 46923            0.385714                0.436735
# 46924            0.050000                0.470000
# 46925            0.078788                0.551515
# ...
# 64076               -0.30                0.900000
# 64077                0.10                0.475000
# 64078                0.00                0.000000
# 64079                0.00                0.000000
# 64080                0.00                0.000000
# 64081                0.00                0.000000
# 64082                 NaN                     NaN
# 64083               -0.50                1.000000
# 64084                0.40                0.800000
# 64085                0.00                0.000000
# 64087                0.00                0.000000
# 64088                0.00                0.000000
# 64089                0.60                1.000000
# 64090                1.00                0.300000
# 64091                0.91                0.780000
# 64092                0.80                0.750000
# 64093                0.60                1.000000
# 64094                0.00                0.000000
# 64095                0.50                0.600000
# 64097                0.50                0.500000
# 64098                0.00                0.000000
# 64099               -0.70                0.666667
# 64100                0.20                0.200000
# 64101                0.35                0.650000
# 64102                0.70                0.600000
# 64103                0.00                0.000000
# 64106                0.00                0.000000
# 64107                0.00                0.000000
# 64108                0.00                0.000000
# 64109                0.00                0.000000
# 64110                0.50                0.600000
# 64111                0.80                0.750000
# 64112                0.70                0.600000
# Hotstar
#            App                                  Translated_Review Sentiment  \
# 64116  Hotstar                                            running   Neutral
# 64117  Hotstar                                               Best  Positive
# 64118  Hotstar  You great collection shows movies. But functio...  Positive
# 64119  Hotstar                                                NaN       NaN
# 64120  Hotstar  Doesn't open all.. crashes time. So much hype ...  Positive
# 64121  Hotstar  2 issues. 1st subtitles get downloading videos...   Neutral
# 64123  Hotstar  A lot bugs. Doesnt show recent menu picure pic...  Negative
# 64124  Hotstar  Even trying several times, answers taken Kanna...  Negative
# 64125  Hotstar  Please make available latest movies everyone t...  Positive
# 64127  Hotstar  U people gave 1000 ads Kannadada kotyadipati p...  Negative
# 64129  Hotstar  It waste time... I playing kannadada kotyadipa...   Neutral
# 64130  Hotstar  Its really good app. Bt need shows here.. bt t...  Positive
# 64131  Hotstar  Hey developer.. Idk thinking.. ridiculous sayi...  Negative
# 64132  Hotstar  Fckng app. Slow loading many ads movies. Old m...  Negative
# 64133  Hotstar  Very slow.. always keep loading streaming.. I ...  Positive
# 64134  Hotstar  Hey Novi Digital Team need login facebook ofvt...  Negative
# 64135  Hotstar  The annoying current update...because press ho...  Negative
# 64136  Hotstar  Actually playing sabse smart kaun ...earlier w...  Positive
# 64137  Hotstar  In new update play ಕನ್ನಡದ ಕೋಟ್ಯಧಿಪತಿ (Kannadad...  Negative
# 64140  Hotstar  Dont get app. Dont get They dont full episodes...  Positive
# 64141  Hotstar  It's painful watch Kannadada kotyadhipathi r p...  Negative
# 64142  Hotstar  It optimised Iball Slide Dazzle Tablet can't s...  Positive
# 64143  Hotstar  Very worst reality big boss 2 tamil show organ...  Negative
# 64144  Hotstar  Kannadada kotyadipathi play along work properl...  Positive
# 64145  Hotstar  After recent update audio end closed. I even r...  Negative
# 64147  Hotstar  Many times disappointing playing sabse smart k...  Negative
# 64148  Hotstar  What hell Y able hotstar I need play sabse sma...  Positive
# 64150  Hotstar  Answers get lock "kannadada kotyadipati" . Eve...  Positive
# 64151  Hotstar  Stopping constantly! Adverts long n option ski...  Negative
# 64152  Hotstar  When install first time work nicely star sport...  Positive
# 64153  Hotstar  When downloading program low quality shows 37 ...   Neutral
# 64154  Hotstar  The live shows even work..then hell r uh peopl...  Positive
# 64155  Hotstar  Very bad I playing Kannada dha kotyadhipathi I...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64116            0.000000                0.000000
# 64117            1.000000                0.300000
# 64118            0.250000                0.496667
# 64119                 NaN                     NaN
# 64120            0.237500                0.650000
# 64121            0.000000                0.000000
# 64123           -0.425000                0.629167
# 64124           -0.166667                0.100000
# 64125            0.471429                0.685714
# 64127           -0.172727                0.613333
# 64129            0.000000                0.250000
# 64130            0.350000                0.800000
# 64131           -0.166667                0.550000
# 64132           -0.200000                0.400000
# 64133            0.256667                0.686667
# 64134           -0.266667                0.400000
# 64135           -0.200000                0.675000
# 64136            0.024524                0.576905
# 64137           -0.116234                0.414935
# 64140            0.250000                0.490000
# 64141           -0.350000                0.950000
# 64142            0.500000                1.000000
# 64143           -0.555556                0.644444
# 64144            0.142857                0.317857
# 64145           -0.125000                0.375000
# 64147           -0.155102                0.506122
# 64148            0.357143                0.633929
# 64150            0.500000                0.500000
# 64151           -0.039062                0.366667
# 64152            0.138889                0.511111
# 64153            0.000000                0.300000
# 64154            0.136364                0.500000
# 64155           -0.455000                0.483333
# Hotwire Hotel & Car Rental App
#                                   App  \
# 64156  Hotwire Hotel & Car Rental App
# 64157  Hotwire Hotel & Car Rental App
# 64158  Hotwire Hotel & Car Rental App
# 64159  Hotwire Hotel & Car Rental App
# 64161  Hotwire Hotel & Car Rental App
# 64163  Hotwire Hotel & Car Rental App
# 64164  Hotwire Hotel & Car Rental App
# 64165  Hotwire Hotel & Car Rental App
# 64166  Hotwire Hotel & Car Rental App
# 64168  Hotwire Hotel & Car Rental App
# 64169  Hotwire Hotel & Car Rental App
# 64170  Hotwire Hotel & Car Rental App
# 64171  Hotwire Hotel & Car Rental App
# 64173  Hotwire Hotel & Car Rental App
# 64174  Hotwire Hotel & Car Rental App
# 64175  Hotwire Hotel & Car Rental App
# 64176  Hotwire Hotel & Car Rental App
# 64177  Hotwire Hotel & Car Rental App
# 64178  Hotwire Hotel & Car Rental App
# 64179  Hotwire Hotel & Car Rental App
# 64180  Hotwire Hotel & Car Rental App
# 64181  Hotwire Hotel & Car Rental App
# 64182  Hotwire Hotel & Car Rental App
# 64183  Hotwire Hotel & Car Rental App
# 64184  Hotwire Hotel & Car Rental App
# 64185  Hotwire Hotel & Car Rental App
# 64186  Hotwire Hotel & Car Rental App
# 64187  Hotwire Hotel & Car Rental App
# 64188  Hotwire Hotel & Car Rental App
# 64189  Hotwire Hotel & Car Rental App
# 64190  Hotwire Hotel & Car Rental App
# 64191  Hotwire Hotel & Car Rental App
# 64192  Hotwire Hotel & Car Rental App
# 64194  Hotwire Hotel & Car Rental App
#
#                                        Translated_Review Sentiment  \
# 64156                                                NaN       NaN
# 64157  The worthless. It allow see information would ...  Negative
# 64158  Scam. Hotel prices shown first much lower fina...  Positive
# 64159                 The bait switch totally scandalous   Neutral
# 64161                If looking sh*thole Hotel place go.   Neutral
# 64163                                        Really easy  Positive
# 64164  WATCH OUT!! THEY WON'T REFUND YOU IF YOU CANCE...  Positive
# 64165  Scammers!!! give refunds even made mistake. ST...  Negative
# 64166  Very fast easy use. Start finish, less 5mins. ...  Positive
# 64168  Total scammers....booked rental car. Price sup...   Neutral
# 64169  No deals I wanna get room 11pm hotel price f.....   Neutral
# 64170                                                Loo   Neutral
# 64171                                              Great  Positive
# 64173  Buggy hell. Trying get hotel tonight house mes...  Negative
# 64174  This company worst. I used years ok. Now must ...  Negative
# 64175  Best similar apps... Would nice Share icon, I ...  Positive
# 64176  My first stay great I fun that's I'm back I wa...  Positive
# 64177                     Total scam worst ever! Thieves  Negative
# 64178                  No customer questions,will again.   Neutral
# 64179                                    POS screws sign   Neutral
# 64180                               Quick & Easy - super  Positive
# 64181                               Still love it! Thanx  Positive
# 64182                                       Works better  Positive
# 64183                           Quick, efficient, cheap!  Positive
# 64184  Rerouted away slc airport saying place would r...   Neutral
# 64185  I hate gives notifications can't disabled. Thi...  Negative
# 64186  Solid app. Booked many hotels & usually saved ...  Positive
# 64187                                 Always fair prices  Positive
# 64188  It work. It keeps saying problems try later. I...   Neutral
# 64189         Solid app. No issues yet. Been using year.   Neutral
# 64190                        Find good price car rental.  Positive
# 64191  Very simple, straight forward, good ui....even...  Positive
# 64192                                        Great deals  Positive
# 64194  Keeps telling there's problem date time, can't...   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64156                 NaN                     NaN
# 64157           -0.233333                0.655556
# 64158            0.183929                0.517262
# 64159            0.000000                0.750000
# 64161            0.000000                0.000000
# 64163            0.433333                0.833333
# 64164            0.738281                0.500000
# 64165           -0.875000                0.666667
# 64166            0.359167                0.615000
# 64168            0.000000                0.750000
# 64169            0.000000                0.000000
# 64170            0.000000                0.000000
# 64171            0.800000                0.750000
# 64173           -0.004167                0.270833
# 64174           -0.041667                0.662500
# 64175            0.533333                0.566667
# 64176            0.321429                0.397619
# 64177           -0.500000                0.875000
# 64178            0.000000                0.000000
# 64179            0.000000                0.000000
# 64180            0.366667                0.666667
# 64181            0.625000                0.600000
# 64182            0.500000                0.500000
# 64183            0.416667                0.600000
# 64184            0.000000                0.187500
# 64185           -0.166667                0.600000
# 64186            0.165000                0.365000
# 64187            0.700000                0.900000
# 64188            0.000000                0.000000
# 64189            0.000000                0.100000
# 64190            0.700000                0.600000
# 64191            0.350000                0.491071
# 64192            0.800000                0.750000
# 64194            0.000000                0.000000
# Housing-Real Estate & Property
#                                   App  \
# 64196  Housing-Real Estate & Property
# 64197  Housing-Real Estate & Property
# 64198  Housing-Real Estate & Property
# 64199  Housing-Real Estate & Property
# 64200  Housing-Real Estate & Property
# 64201  Housing-Real Estate & Property
# 64202  Housing-Real Estate & Property
# 64205  Housing-Real Estate & Property
# 64207  Housing-Real Estate & Property
# 64209  Housing-Real Estate & Property
# 64213  Housing-Real Estate & Property
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64217  Housing-Real Estate & Property
# 64218  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 64196  Incorrect listings. The agents show property d...  Negative
# 64197  Pathetic app.All posted leads owner either old...  Negative
# 64198  It's waste app... Most properties 2017... And ...  Positive
# 64199  Filters useless I posted owners shows agents a...  Negative
# 64200  Why business? Your filters don't work.. redire...   Neutral
# 64201         Filters work... Searching property useless  Negative
# 64202                                                NaN       NaN
# 64205   I want list property sale option. Please connect   Neutral
# 64207                                               Good  Positive
# 64209  Awesome app.. But prices date? Awesome app. Gi...  Positive
# 64213  This worse ever. They give graphic pictures pr...  Negative
# 64215  Horrible app. I wanted list property get aroun...  Negative
# 64216  Worst app. We get nothing Time waste . They up...  Negative
# 64217  I able set range 1cr, scroll space 0-1cr range...  Positive
# 64218  What nonsensical app.. doesn't owner postings ...   Neutral
# 64220  No response support team. After I login, unabl...  Negative
# 64221  Everything old stuff neither clear sold proper...  Positive
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64196           -0.025000                0.125000
# 64197           -0.362500                0.625000
# 64198            0.266667                0.375000
# 64199           -0.500000                0.200000
# 64200            0.000000                0.000000
# 64201           -0.500000                0.200000
# 64202                 NaN                     NaN
# 64205            0.000000                0.000000
# 64207            0.700000                0.600000
# 64209            0.509375                0.511458
# 64213           -0.081250                0.418750
# 64215           -0.528571                0.717262
# 64216           -0.400000                0.250000
# 64217            0.233333                0.550000
# 64218            0.000000                0.000000
# 64220           -0.377778                0.533333
# 64221            0.021591                0.259470
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
# Houzz Interior Design Ideas
#                                App Translated_Review Sentiment  \
# 64236  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64236                 NaN                     NaN

# %% [markdown]
# **Removing the missing values from the User reviews dataset**.

# %%
df_reviews
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
# 64236     Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
# 64236                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                     NaN                     NaN
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
# 64236                 NaN                     NaN
#
# [30679 rows x 5 columns]

# %%
df_reviews.isnull().sum()
# Out:
# App                         0
# Translated_Review         987
# Sentiment                 982
# Sentiment_Polarity        982
# Sentiment_Subjectivity    982
# dtype: int64

# %%
df_reviews.drop_duplicates(inplace=True)

# %%
df_reviews
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
# 64236     Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
# 64236                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                     NaN                     NaN
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
# 64236                 NaN                     NaN
#
# [30679 rows x 5 columns]

# %%
df_reviews.Translated_Review.unique()
# Out:
# array(['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#        'This help eating healthy exercise regular basis', nan, ...,
#        'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.',
#        'I property business got link SMS happy performance still guys need raise bar guys Cheers',
#        'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active'],
#       dtype=object)

# %%
df_reviews.Sentiment.unique()
# Out:
# array(['Positive', nan, 'Neutral', 'Negative'], dtype=object)

# %%
df_reviews.Sentiment_Polarity.unique()
# Out:
# array([ 1.        ,  0.25      ,         nan, ..., -0.52857143,
#        -0.37777778,  0.17333333])

# %%
df_reviews['Sentiment_Subjectivity'].unique()
# Out:
# array([0.53333333, 0.28846154,        nan, ..., 0.51145833, 0.7172619 ,
#        0.2594697 ])

# %%
print(df_reviews['Sentiment'].mode())
print(df_reviews['Sentiment_Subjectivity'].mode())
print(df_reviews['Sentiment_Polarity'].mode())
print(df_reviews['Translated_Review'].mode())
# Out:
# 0    Positive
# dtype: object
# 0    0.0
# dtype: float64
# 0    0.0
# dtype: float64
# 0    Good
# dtype: object

# %% [markdown]
# **Filling the Missing values with mode values of Sentiment, Sentiment_Polarity and Sentiment_Subjectivity so that the values can be filled and the data looks more presentable.**

# %%
df_reviews['Translated_Review'].fillna(str(df_reviews['Translated_Review'].mode().values[0]),inplace=True)
df_reviews['Sentiment'].fillna(str(df_reviews['Sentiment'].mode().values[0]),inplace=True)
df_reviews['Sentiment_Polarity'].fillna(df_reviews['Sentiment_Polarity'].median(),inplace=True)
df_reviews['Sentiment_Subjectivity'].fillna(df_reviews['Sentiment_Subjectivity'].median(),inplace=True)

# %%
df_reviews.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df_reviews)
plt.show()

# %% [markdown]
# **This shows that the missing data in the User Data has been removed successfully.**

# %%
grp = df_reviews.groupby('App')
x = grp['Sentiment_Polarity'].agg(np.mean)
y = grp['Sentiment_Subjectivity'].agg(np.mean)
print(x)
print(y)
# Out:
# App
# 10 Best Foods for You                             0.462690
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                  0.358227
# 11st                                              0.181294
# 1800 Contacts - Lens Store                        0.318145
# 1LINE – One Line with One Touch                   0.195287
#                                                     ...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security    0.221732
# Hotstar                                           0.041783
# Hotwire Hotel & Car Rental App                    0.186150
# Housing-Real Estate & Property                   -0.013310
# Houzz Interior Design Ideas                       0.157143
# Name: Sentiment_Polarity, Length: 1074, dtype: float64
# App
# 10 Best Foods for You                             0.493473
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                  0.508907
# 11st                                              0.443957
# 1800 Contacts - Lens Store                        0.591098
# 1LINE – One Line with One Touch                   0.556212
#                                                     ...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security    0.384423
# Hotstar                                           0.494580
# Hotwire Hotel & Car Rental App                    0.461322
# Housing-Real Estate & Property                    0.384702
# Houzz Interior Design Ideas                       0.514286
# Name: Sentiment_Subjectivity, Length: 1074, dtype: float64

# %% [markdown]
# # **Merging dataframes on apps**

# %%
merged_df = df.merge(df_reviews, on="App")
merged_df
# Out:
#                                 App        Category  Rating  Reviews  \
# 0               Coloring book moana  ART_AND_DESIGN     3.9      967
# 1               Coloring book moana  ART_AND_DESIGN     3.9      967
# 2               Coloring book moana  ART_AND_DESIGN     3.9      967
# 3               Coloring book moana  ART_AND_DESIGN     3.9      967
# 4               Coloring book moana  ART_AND_DESIGN     3.9      967
# ...                             ...             ...     ...      ...
# 41656  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 41657  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 41658  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 41659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 41660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
#
#                      Size    Installs  Type  Price Content Rating  \
# 0                     14M    500000.0  Free    0.0       Everyone
# 1                     14M    500000.0  Free    0.0       Everyone
# 2                     14M    500000.0  Free    0.0       Everyone
# 3                     14M    500000.0  Free    0.0       Everyone
# 4                     14M    500000.0  Free    0.0       Everyone
# ...                   ...         ...   ...    ...            ...
# 41656  Varies with device  10000000.0  Free    0.0       Everyone
# 41657  Varies with device  10000000.0  Free    0.0       Everyone
# 41658  Varies with device  10000000.0  Free    0.0       Everyone
# 41659  Varies with device  10000000.0  Free    0.0       Everyone
# 41660  Varies with device  10000000.0  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 3      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4      Art & Design;Pretend Play  January 15, 2018               2.0.0
# ...                          ...               ...                 ...
# 41656                Photography    August 6, 2018  Varies with device
# 41657                Photography    August 6, 2018  Varies with device
# 41658                Photography    August 6, 2018  Varies with device
# 41659                Photography    August 6, 2018  Varies with device
# 41660                Photography    August 6, 2018  Varies with device
#
#               Android Ver                                  Translated_Review  \
# 0            4.0.3 and up  A kid's excessive ads. The types ads allowed a...
# 1            4.0.3 and up                                         It bad >:(
# 2            4.0.3 and up                                               like
# 3            4.0.3 and up                                               Good
# 4            4.0.3 and up                           I love colors inspyering
# ...                   ...                                                ...
# 41656  Varies with device           Overall great app. Best gallery seen far
# 41657  Varies with device  Recommended, 100% love it, keep good work dev ...
# 41658  Varies with device                                       Too much ads
# 41659  Varies with device                                Just allow time ...
# 41660  Varies with device                       It's good best gallery phone
#
#       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0      Negative           -0.250000                1.000000
# 1      Negative           -0.725000                0.833333
# 2       Neutral            0.000000                0.000000
# 3      Positive            0.157143                0.514286
# 4      Positive            0.500000                0.600000
# ...         ...                 ...                     ...
# 41656  Positive            0.475000                0.512500
# 41657  Positive            0.566667                0.733333
# 41658  Positive            0.200000                0.200000
# 41659   Neutral            0.000000                0.000000
# 41660  Positive            0.850000                0.450000
#
# [41661 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          10357 non-null  float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  float64
#  6   Type            10357 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10357 non-null  object
#  12  Android Ver     10357 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1.1+ MB

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41661 entries, 0 to 41660
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     41661 non-null  object
#  1   Category                41661 non-null  object
#  2   Rating                  41661 non-null  float64
#  3   Reviews                 41661 non-null  int64
#  4   Size                    41661 non-null  object
#  5   Installs                41661 non-null  float64
#  6   Type                    41661 non-null  object
#  7   Price                   41661 non-null  float64
#  8   Content Rating          41661 non-null  object
#  9   Genres                  41661 non-null  object
#  10  Last Updated            41661 non-null  object
#  11  Current Ver             41661 non-null  object
#  12  Android Ver             41661 non-null  object
#  13  Translated_Review       41661 non-null  object
#  14  Sentiment               41661 non-null  object
#  15  Sentiment_Polarity      41661 non-null  float64
#  16  Sentiment_Subjectivity  41661 non-null  float64
# dtypes: float64(5), int64(1), object(11)
# memory usage: 5.7+ MB

# %% [markdown]
# **In the merged dataframe, we have four new columns i.e.. Translated_Review,    Sentiment, Sentiment Polarity and Sentiment Subjectivity. Sentiment basically determines the attitude or the emotion of the writer, i.e., whether it is positive or negative or neutral. Sentiment Polarity is float which lies in the range of [-1,1] where 1 means positive statement and -1 means a negative statement. Sentiment Subjectivity generally refer to personal opinion, emotion or judgment, which lies in the range of [0,1]**

# %% [markdown]
# #**5. Dataset Visualization**
# **Asking questions and aswering them.**
# * **Installs per Category**
# * **Pricing vs Category**
# * **Number of Reviews per Category**
# * **What are the top 20 apps present in the google play store per in the Genres?**
# * **What are the Genre that are getting installed the most in top 20 Genres?**
# * **Count of applications for each Category**
# * **Number of Installed applications for each category**
# * **Distribution of Rating**
# * **Highest and Lowest Genres**
# * **Rating according to Genres**
# * **What are teh count of applications in each category differentiated by their type**
# * **How many apps wqere installed according to their type**
# * **How does size impact on the Number of installs of any applications**
# * **Histogram of log installs**
# * **Histogram of size**
# * **Different Android Version**
# * **Scatter Matrix**
# * **What is the percentage of paid to free apps?**
# * **What is the most dominant category?**
# * **What size should my app have?**
# * **What price should my paid app have?**
# * **What are the number of installs for apps priced more than $100?**
# * **What is the most successful category?**
# * **Distribution of app sizes**
# * **Rating per categories and type**
# * **Distribution of content rating per categories**
# * **Number of Installs type wise according to Genre**
# * **Histogram of Subjectivity**
# * **Does Sentiment_subjectivity propotional to sentiment_polarity**
# * **Wordcloud**
# * **Percentage of Review Sentiments**

# %%
  grp = merged_df.groupby('Category')
  x = grp['Installs'].agg(np.mean)
  y = grp['Price'].agg(np.sum)
  z = grp['Reviews'].agg(np.mean)
  print(x)
  print(y)
  print(z)
# Out:
# Category
# ART_AND_DESIGN         2.019699e+06
# AUTO_AND_VEHICLES      1.567123e+06
# BEAUTY                 1.545846e+06
# BOOKS_AND_REFERENCE    4.112269e+07
# BUSINESS               9.387696e+06
# COMICS                 8.371910e+05
# COMMUNICATION          2.189331e+08
# DATING                 1.406690e+06
# EDUCATION              1.634968e+07
# ENTERTAINMENT          9.390635e+06
# EVENTS                 2.944444e+05
# FAMILY                 2.978561e+07
# FINANCE                9.650031e+06
# FOOD_AND_DRINK         2.705564e+06
# GAME                   6.247934e+07
# HEALTH_AND_FITNESS     1.033843e+07
# HOUSE_AND_HOME         1.044848e+06
# LIBRARIES_AND_DEMO     2.000439e+06
# LIFESTYLE              4.887402e+06
# MAPS_AND_NAVIGATION    2.050000e+06
# MEDICAL                5.144582e+05
# NEWS_AND_MAGAZINES     1.508365e+08
# PARENTING              7.269663e+05
# PERSONALIZATION        1.997274e+07
# PHOTOGRAPHY            2.800494e+08
# PRODUCTIVITY           7.643985e+07
# SHOPPING               3.946980e+07
# SOCIAL                 3.090147e+08
# SPORTS                 1.182029e+07
# TOOLS                  1.079716e+08
# TRAVEL_AND_LOCAL       2.010088e+07
# VIDEO_PLAYERS          1.539403e+07
# WEATHER                2.156223e+07
# Name: Installs, dtype: float64
# Category
# ART_AND_DESIGN            0.00
# AUTO_AND_VEHICLES         0.00
# BEAUTY                    0.00
# BOOKS_AND_REFERENCE       0.00
# BUSINESS                  0.00
# COMICS                    0.00
# COMMUNICATION             0.00
# DATING                    6.99
# EDUCATION                 0.00
# ENTERTAINMENT             0.00
# EVENTS                    0.00
# FAMILY                  298.25
# FINANCE                   0.00
# FOOD_AND_DRINK            0.00
# GAME                    229.55
# HEALTH_AND_FITNESS        0.00
# HOUSE_AND_HOME            0.00
# LIBRARIES_AND_DEMO        0.00
# LIFESTYLE                 0.00
# MAPS_AND_NAVIGATION       0.00
# MEDICAL                 921.17
# NEWS_AND_MAGAZINES        0.00
# PARENTING                 0.00
# PERSONALIZATION         557.58
# PHOTOGRAPHY               7.90
# PRODUCTIVITY              0.00
# SHOPPING                  0.00
# SOCIAL                    0.00
# SPORTS                 1199.60
# TOOLS                     0.00
# TRAVEL_AND_LOCAL          0.00
# VIDEO_PLAYERS             0.00
# WEATHER                   0.00
# Name: Price, dtype: float64
# Category
# ART_AND_DESIGN         3.122851e+04
# AUTO_AND_VEHICLES      5.305454e+04
# BEAUTY                 1.641219e+04
# BOOKS_AND_REFERENCE    5.709814e+05
# BUSINESS               1.495605e+05
# COMICS                 2.184475e+04
# COMMUNICATION          1.960400e+06
# DATING                 2.727265e+04
# EDUCATION              9.453058e+05
# ENTERTAINMENT          3.435750e+05
# EVENTS                 3.546463e+03
# FAMILY                 2.229475e+06
# FINANCE                1.379527e+05
# FOOD_AND_DRINK         1.250311e+05
# GAME                   4.227788e+06
# HEALTH_AND_FITNESS     3.532712e+05
# HOUSE_AND_HOME         2.057489e+04
# LIBRARIES_AND_DEMO     3.018201e+04
# LIFESTYLE              2.253753e+05
# MAPS_AND_NAVIGATION    3.721800e+04
# MEDICAL                1.379041e+04
# NEWS_AND_MAGAZINES     2.277290e+05
# PARENTING              9.064041e+03
# PERSONALIZATION        6.859193e+05
# PHOTOGRAPHY            3.518660e+06
# PRODUCTIVITY           1.054097e+06
# SHOPPING               1.391513e+06
# SOCIAL                 2.148097e+07
# SPORTS                 1.013682e+06
# TOOLS                  1.457194e+06
# TRAVEL_AND_LOCAL       3.148543e+05
# VIDEO_PLAYERS          4.691979e+05
# WEATHER                7.276926e+05
# Name: Reviews, dtype: float64

# %% [markdown]
# ## **Number of Installs per Category**

# %%
plt.figure(figsize=(20,10))
plt.plot(x, 'ro', color='b')
plt.xticks(rotation = 90)
plt.title('Number of Installs per Category')
plt.xlabel('Categories ------->')
plt.ylabel('Installs ------>');

# %% [markdown]
# ### **Pricing per Category**

# %%
plt.figure(figsize = (20,10))
plt.plot(y, 'r--', color = 'r')
plt.xticks(rotation = 90)
plt.title('Pricing per Category')
plt.xlabel('Catgories ------>')
plt.ylabel('Prices ----->');

# %% [markdown]
# ### **Number of Reviews per Category**

# %%
plt.figure(figsize = (20,10))
plt.plot(z, 'g^', color = 'g')
plt.xticks(rotation = 90)
plt.title('Category vs Reviews')
plt.xlabel('Catgories ------>')
plt.ylabel('Reviews ----->');

# %% [markdown]
# ### **What are the top 20 apps present in the google play store as per their Genres?**

# %%
top_genres = df.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
genres_installs = df.groupby(['Genres'])[['Installs']].sum()
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.head(20)

plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count)
plt.show();

# %% [markdown]
# ### **As we can see from the above plots: Maxinum number of apps present in google play store comes under Tools, Entertainment and Education Genres but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Communication, Tools and Productivity Genres.**

# %% [markdown]
# ### **Which are the Genres that are getting installed the most in top 20 Genres?**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Installs")
plt.title("Installs according to Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Installs)
plt.show()

# %% [markdown]
# ### **As we can see from the above two plots: Maxinum number of apps present in google play store comes under Communication,Social, Productivity and Tools, Genres but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Communication, Tools and Productivity Genres.**

# %% [markdown]
# ### **Count of applications for each Category**

# %%
top_category = df.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})
category_installs = df.groupby(['Category'])[['Installs']].sum()
top_category_installs = pd.merge(top_category, category_installs, on='Category')
top_20_category_installs = top_category_installs

plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of application")
plt.title("Count of applications for each Category")
sns.barplot(top_20_category_installs.Category, top_20_category_installs.Count)
plt.show()

# %% [markdown]
# ### **Number of installed applications for each Category**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installed applications for each Category")
sns.barplot(top_20_category_installs.Category, top_20_category_installs.Installs)
plt.show();

# %% [markdown]
# ### **Average rating**

# %%
genres_ratings_df = df.groupby(['Genres'])[['Rating']].mean()
genres_installs_ratings = pd.merge(top_genres_installs, genres_ratings_df, on='Genres')
genres_installs_ratings['Rating'].describe()
# Out:
# count    119.000000
# mean       4.267642
# std        0.169731
# min        3.800000
# 25%        4.168080
# 50%        4.279775
# 75%        4.350000
# max        4.800000
# Name: Rating, dtype: float64

# %% [markdown]
# ### **Distribution of Rating**

# %%
plt.figure(figsize=(14,7))
g = sns.kdeplot(genres_installs_ratings.Rating, color="Green", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
plt.show()

# %% [markdown]
# ### **Highest and lowest rated Genres**

# %%
genres_installs_ratings.sort_values('Rating', ascending =False, inplace=True)

highest_rated_genres = genres_installs_ratings.iloc[0:20]
lowest_rated_genres = genres_installs_ratings.iloc[-20:]
lowest_rated_genres = lowest_rated_genres[lowest_rated_genres['Rating'].notnull()]

plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Rating")
plt.title("Ratings according to Genres")
sns.barplot(highest_rated_genres.Genres, highest_rated_genres.Rating)
plt.show()

# %% [markdown]
# ### **Ratings according to Genres**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Rating")
plt.title("Ratings according to Genres")
sns.barplot(lowest_rated_genres.Genres, lowest_rated_genres.Rating)
plt.show()

# %% [markdown]
# ### **What are the count of applications in each category differentiated by their type?**

# %%
app_count = df.groupby(['Category','Type'])[['App']].count().reset_index().rename(columns={'App':'Count','index':'App'})
df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()


df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9))
plt.xlabel("Category", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Count of applications in each category differentiated by their type")
plt.show()

# %% [markdown]
# **It looks like certain app categories have more free apps available for download than others. In our dataset, the majority of apps in Family, Food & Drink and Tools, as well as Social categories were free to install. At the same time Family, Sports, Tools and Medical categories had the biggest number of paid apps available for download.**

# %% [markdown]
# ### **How many apps were installed according to its type?**

# %%
df['log_installs'] = np.log2(df['Installs'])
df['Gaming Category App'] = df['Category']=='GAME'
categoty_type_installs = df.groupby(['Category','Type'])[['Installs']].sum().reset_index()
categoty_type_installs['log_Installs'] = np.log2(categoty_type_installs['Installs'])

plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Category")
sns.barplot('Category', 'log_Installs', hue='Type', data=categoty_type_installs);
plt.show();

# %% [markdown]
# **It can be concluded that the number of free applications installed by the user are high when compared with the paid ones.**

# %% [markdown]
# **Size of the applications present in the datset are in MB and KB. Therefore for ease in data processing, converting entire size column to MB.**

# %%
# Converting KB to MB 
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(x))

# %% [markdown]
# ### **How does size impact on the number of installs of any application?**

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(df['Size'], df['log_installs'], hue=df['Type'])
plt.show()

# %% [markdown]
# ## **Histogram of log installs**

# %%
df.loc[df['log_installs']== df['log_installs'].min(),'log_installs']=0


plt.xlabel("Log of Installs")
plt.title("Distribution of Logrithm of Installs")
plt.hist(df['log_installs']);

# %% [markdown]
# ### **Histogram of size**

# %%
# to remove null values from size column
df.loc[df['Size'].isnull(),'Size']=0

plt.xlabel("Size")
plt.title("Distribution of Size")
plt.hist(df['Size']);
plt.show()

# %% [markdown]
# ##  **Different Android version**

# %%
pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
import plotly.graph_objects as go
labels = merged_df['Android Ver'].unique()
values=[]
for each in labels:
    values.append(len(merged_df[merged_df['Android Ver']==each]))

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3, title="Android Version")])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="412c90f8-9985-4a5c-a6a9-561b4e83b791" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("412c90f8-9985-4a5c-a6a9-561b4e83b791")) {                    Plotly.newPlot(                        "412c90f8-9985-4a5c-a6a9-561b4e83b791",                        [{"hole":0.3,"labels":["4.0.3 and up","3.0 and up","2.3 and up","4.0 and up","4.1 and up","2.3.3 and up","4.2 and up","5.0 and up","Varies with device","1.6 and up","1.5 and up","4.4 and up","7.0 and up","2.2 and up","4.3 and up","4.0.3 - 7.1.1","2.1 and up","2.0 and up","5.1 and up","6.0 and up","7.1 and up","3.2 and up","4.4W and up","8.0 and up","5.0 - 8.0"],"title":{"text":"Android Version"},"values":[6289,497,1687,2888,9396,456,1313,2827,10871,75,39,3919,72,199,393,33,205,35,2,382,40,38,1,1,3],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type" ...

# %% [markdown]
# ![Screenshot 2022-07-01 123842.png](data:image/png;base64,...)

# %% [markdown]
# **Since plotly plot are not shown on github I am saving a picture of the plot to give an example.**

# %% [markdown]
# ## **Scatter Plot**

# %%
sns.pairplot(df[["Size", "Reviews", "Installs", "Rating", "Type"]], hue="Type", palette="GnBu")

# %% [markdown]
# **This matches our assumption that size greatly affects other features. The Scatter Matrix shows that when the app size is relatively small, other features prosper. This shows that cosumer behaviour on the play store is greatly affected by the app download size**.
#
# **Takeaway: Developers should optimize their app download size as much as possible**

# %% [markdown]
# ###**What is the percentage of paid to free apps?**

# %%
plt.rcParams['figure.figsize']=(14,7)
size = df["Type"].value_counts()
labels = df["Type"].unique()
colors=["#43a6cc", "#bae4bf"]

plt.pie(size, labels=labels, colors=colors, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## **What size should my app have?**

# %%
plt.rcParams['figure.figsize']=(14,8)
medians = df.groupby(['Category'])['Size'].median().values
median_labels = [str(np.round(s, 2)) for s in medians]
ax = sns.boxplot(x="Size", y="Category", data=df, palette="GnBu")
ax = sns.boxplot()
df["Size"].mean()
# Out:
# 18.151246355122137

# %% [markdown]
# **The trend is games have a much larger download size than any other category. If you're developing anything other than a game, you need to optimize your downlaod size. on Average any app should have a size of 17.8 MB.**

# %% [markdown]
# ### **What is the most dominant category?**

# %%
categories = df["Category"].value_counts()
sns.barplot(x=categories.values, y=categories.index, palette="GnBu")

# %% [markdown]
# **This is an interesting finding, our first assumption for the most dominant category was family.**

# %% [markdown]
# ###**What price should my paid app have?**

# %%
paid_apps = df[df["Type"] == "Paid"]
sns.boxplot(x="Price", y="Category", data=paid_apps, palette="GnBu")
df["Price"].mean()
# Out:
# 1.030800424833446

# %% [markdown]
# **Finance and lifestyle are valued the most but it's intresting to find that there are apps with values of more than $100.**
#
# **On average an app price is $1**

# %% [markdown]
# ### **What are the number of installs for apps priced more than $100?**

# %%
plt.rcParams['figure.figsize']=(10,5)
expensive_apps = df[df["Price"] > 100]
sns.lineplot(x="Price", y="Installs", data=expensive_apps, palette="GnBu")

# %% [markdown]
# ### **What is the most successful category?**

# %%
plt.rcParams['figure.figsize']=(10,10)
plot = sns.barplot(x="Installs", y="Category", data=df, palette="GnBu")

# %% [markdown]
# **Most successful category based on the number of installs is the communication category.**

# %% [markdown]
# ### **Distribution of app sizes**

# %%
plt.rcParams['figure.figsize']=(10,5)
sns.distplot(df["Size"], color="blue")

# %% [markdown]
# ### **Rating per categories and type**

# %%
plt.rcParams['figure.figsize']=(10,17)
sns.violinplot(x="Rating", y="Category", hue="Type", data=df, split=True, palette="GnBu")

# %% [markdown]
# ### **Distribution of content rating per categories**
#
# ---

# %%
plt.rcParams['figure.figsize']=(10,15)
content_category = df[["Content Rating", "Category"]].groupby(["Content Rating", "Category"]).size().reset_index(name='counts')
sns.barplot(x="counts" , y="Category", hue="Content Rating",data=content_category, palette="GnBu")

# %% [markdown]
# ### **Number of installs type wise according to Genres**

# %%
category_sentiment = merged_df.groupby(['Category','Sentiment']).size().reset_index(name='Sentiment Count')
category_sentiment['log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])

plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Genres")
sns.barplot('Category', 'log_sentiment_count', hue='Sentiment', data=category_sentiment);

# %% [markdown]
# ### **Histogram of subjectivity**

# %%
plt.figure(figsize=(14,7))
plt.xlabel("Subjectivity")
plt.title("Distribution of Subjectivity")
plt.hist(merged_df[merged_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'])
plt.show()

# %% [markdown]
# **It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that macimum number of users give reviews to the applications, according to their experience.**

# %% [markdown]
# ### **Does sentiment_subjectivity proportional to sentiment_polarity?**

# %%
sentimet_subjectivity_polarity = merged_df.groupby(['Category'])['Sentiment_Polarity','Sentiment_Subjectivity'].mean().reset_index().rename(columns={'Sentiment_Polarity':'Sentiment_polarity_avg','Sentiment_Subjectivity':'sentiment_subjectivity_avg'})
merged_df['Sentiment_Subjectivity'] = merged_df['Sentiment_Subjectivity'].abs()
merged_df['Sentiment_Polarity'] = merged_df['Sentiment_Polarity'].abs()

plt.figure(figsize=(14,7))
sns.scatterplot(merged_df['Sentiment_Subjectivity'], merged_df['Sentiment_Polarity'])
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity")
plt.show()

# %% [markdown]
# **From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low**

# %% [markdown]
# ### **Wordcloud**

# %%
review_notnull = merged_df[merged_df['Translated_Review'].notnull()]

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = review_notnull.Translated_Review.values
wordcloud = WordCloud(
    width = 3920,
    height = 2080,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text).lower())
fig = plt.figure(
    figsize = (20, 15),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### **Percentage of Review Sentimets**

# %%
import matplotlib
counts = list(merged_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (8, 8)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentimets', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()
