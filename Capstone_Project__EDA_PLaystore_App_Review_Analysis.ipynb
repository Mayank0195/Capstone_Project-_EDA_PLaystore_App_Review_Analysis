# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/Capstone_Project-_EDA_PLaystore_App_Review_Analysis/blob/main/Capstone_Project__EDA_PLaystore_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.
# #Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
# #Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ###Android Play Store Dataset Cleaning
# ####Overview and Motivation
# This EDA project aims to discover patterns that lead to a successfull application on the Google Play Store. This will be done by analyzing the historical data collected from the Google Play Store as according to dataset source.
#
# Dataset columns description
# * App: Application name
# * Category: Category the app belongs to
# * Rating: Overall user rating of the app (as when scraped)
# * Reviews: Number of user reviews for the app (as when scraped)
# * Size: Size of the app (as when scraped)
# * Installs: Number of user downloads/installs for the app (as when scraped)
# * Type: Paid or Free
# *Price: Price of the app (as when scraped)
# *Content: Rating Age group the app is targeted at - Children / Mature 21+ / Adult
# * Genres: An app can belong to multiple genres (apart from its main category). For eg, a musical family game will belong to Music, Game, Family genres.
# * Last Updated: Date when the app was last updated on Play Store (as when scraped)
# * Current Ver: Current version of the app available on Play Store (as when scraped)
# * Android Ver: Min required Android version (as when scraped)

# %%
# importing required file required for the EDA 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #**1. Dataset Reading**

# %%
# importing drive on the volab notebook for the easy access of the data provided 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing the pathway for the Playstore Data
route1='/content/drive/MyDrive/AlmaBetter/Capstone_Project_EDA/Play_Store_Data.csv'
df=pd.read_csv(route1)
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10841 rows x 13 columns]

# %%
#importing the pathway for the User reviews data
route2='/content/drive/MyDrive/AlmaBetter/Capstone_Project_EDA/User_Reviews.csv'
df_reviews=pd.read_csv(route2)
df_reviews
# Out:
#                                App  ... Sentiment_Subjectivity
# 0            10 Best Foods for You  ...               0.533333
# 1            10 Best Foods for You  ...               0.288462
# 2            10 Best Foods for You  ...                    NaN
# 3            10 Best Foods for You  ...               0.875000
# 4            10 Best Foods for You  ...               0.300000
# ...                            ...  ...                    ...
# 64290  Houzz Interior Design Ideas  ...                    NaN
# 64291  Houzz Interior Design Ideas  ...                    NaN
# 64292  Houzz Interior Design Ideas  ...                    NaN
# 64293  Houzz Interior Design Ideas  ...                    NaN
# 64294  Houzz Interior Design Ideas  ...                    NaN
#
# [64295 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Checking the Head and Tail of the Playstore data**

# %%
df.head(10)
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
# 5                         Paper flowers instructions  ...    2.3 and up
# 6            Smoke Effect Photo Maker - Smoke Editor  ...  4.0.3 and up
# 7                                   Infinite Painter  ...    4.2 and up
# 8                               Garden Coloring Book  ...    3.0 and up
# 9                      Kids Paint Free - Drawing Fun  ...  4.0.3 and up
#
# [10 rows x 13 columns]

# %%
df.tail(10)
# Out:
#                                                  App  ...         Android Ver
# 10831                       payermonstationnement.fr  ...          4.0 and up
# 10832                                       FR Tides  ...          2.1 and up
# 10833                                    Chemin (fr)  ...          2.2 and up
# 10834                                  FR Calculator  ...          4.1 and up
# 10835                                       FR Forms  ...          4.0 and up
# 10836                               Sya9a Maroc - FR  ...          4.1 and up
# 10837               Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                         Parkinson Exercices FR  ...          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10 rows x 13 columns]

# %% [markdown]
# **Checking he head and taill if the user review Data**

# %%
df_reviews.head(10)
# Out:
#                      App  ... Sentiment_Subjectivity
# 0  10 Best Foods for You  ...               0.533333
# 1  10 Best Foods for You  ...               0.288462
# 2  10 Best Foods for You  ...                    NaN
# 3  10 Best Foods for You  ...               0.875000
# 4  10 Best Foods for You  ...               0.300000
# 5  10 Best Foods for You  ...               0.300000
# 6  10 Best Foods for You  ...               0.900000
# 7  10 Best Foods for You  ...                    NaN
# 8  10 Best Foods for You  ...               0.000000
# 9  10 Best Foods for You  ...               0.000000
#
# [10 rows x 5 columns]

# %%
df_reviews.tail(10)
# Out:
#                                App  ... Sentiment_Subjectivity
# 64285  Houzz Interior Design Ideas  ...                    NaN
# 64286  Houzz Interior Design Ideas  ...                    NaN
# 64287  Houzz Interior Design Ideas  ...                    NaN
# 64288  Houzz Interior Design Ideas  ...                    NaN
# 64289  Houzz Interior Design Ideas  ...                    NaN
# 64290  Houzz Interior Design Ideas  ...                    NaN
# 64291  Houzz Interior Design Ideas  ...                    NaN
# 64292  Houzz Interior Design Ideas  ...                    NaN
# 64293  Houzz Interior Design Ideas  ...                    NaN
# 64294  Houzz Interior Design Ideas  ...                    NaN
#
# [10 rows x 5 columns]

# %% [markdown]
# #**2. Dataset Discovery**
# **dicovering the dataset and get a notion of what the attributes describe**.

# %%
df.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
df_reviews.count()
# Out:
# App                       64295
# Translated_Review         37427
# Sentiment                 37432
# Sentiment_Polarity        37432
# Sentiment_Subjectivity    37432
# dtype: int64

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df_reviews.shape
# Out:
# (64295, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df.boxplot();

# %%
df_reviews.boxplot();

# %%
df.hist();

# %%
df_reviews.hist();

# %%
import missingno as msno
msno.matrix(df)
plt.show()

# %% [markdown]
# **This shows that the data has many missing values under the column Rating, Content Rating and Android Version.**

# %%
import missingno as msno
msno.matrix(df_reviews)
plt.show()

# %% [markdown]
# **This also shows that even the User Reviews csv is also full of missing data.**

# %% [markdown]
# #**3**.**DATA CLEANING**

# %% [markdown]
# **Checking the missing values in the Playstore data**

# %%
df.isnull()
# Out:
#          App  Category  Rating  ...  Last Updated  Current Ver  Android Ver
# 0      False     False   False  ...         False        False        False
# 1      False     False   False  ...         False        False        False
# 2      False     False   False  ...         False        False        False
# 3      False     False   False  ...         False        False        False
# 4      False     False   False  ...         False        False        False
# ...      ...       ...     ...  ...           ...          ...          ...
# 10836  False     False   False  ...         False        False        False
# 10837  False     False   False  ...         False        False        False
# 10838  False     False    True  ...         False        False        False
# 10839  False     False   False  ...         False        False        False
# 10840  False     False   False  ...         False        False        False
#
# [10841 rows x 13 columns]

# %% [markdown]
# **Countiing the number of missing values in the Playstore Data.**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df_reviews.isnull()
# Out:
#          App  Translated_Review  ...  Sentiment_Polarity  Sentiment_Subjectivity
# 0      False              False  ...               False                   False
# 1      False              False  ...               False                   False
# 2      False               True  ...                True                    True
# 3      False              False  ...               False                   False
# 4      False              False  ...               False                   False
# ...      ...                ...  ...                 ...                     ...
# 64290  False               True  ...                True                    True
# 64291  False               True  ...                True                    True
# 64292  False               True  ...                True                    True
# 64293  False               True  ...                True                    True
# 64294  False               True  ...                True                    True
#
# [64295 rows x 5 columns]

# %% [markdown]
# **Checking the missing values in the User reviews data**

# %%
df_reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# ##**3.1 Outliers**
# An outlier is an object that deviates significantly from the rest of the objects. They can be caused by measurement or execution errors.

# %%
df.boxplot();
df.hist();

# %%
df[df.Rating>5]
# Out:
#                                            App Category  ...  Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9  ...   4.0 and up         NaN
#
# [1 rows x 13 columns]

# %%
df.drop([10472], inplace = True)

# %%
df[10470:10474]
# Out:
#                            App         Category  ...  Current Ver   Android Ver
# 10470               Jazz Wi-Fi    COMMUNICATION  ...          0.1    2.3 and up
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION  ...        3.0.0  4.0.3 and up
# 10473  osmino Wi-Fi: free WiFi            TOOLS  ...      6.06.14    4.4 and up
# 10474             Sat-Fi Voice    COMMUNICATION  ...      2.2.1.5    2.2 and up
#
# [4 rows x 13 columns]

# %%
df.boxplot()

# %% [markdown]
# ###**3.2 Remove columns that are 90% empty**

# %%
len(df)
# Out:
# 10840

# %%
threshold = len(df) * 0.1
threshold
# Out:
# 1084.0

# %%
df.dropna(thresh = threshold, axis = 1, inplace = True)

# %%
print(df.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
boolean = df['App'].duplicated().any()
boolean
# Out:
# True

# %%
df['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9659, dtype: int64

# %%
df[df['App'] == 'ROBLOX']
# Out:
#          App Category  Rating  ...   Last Updated   Current Ver Android Ver
# 1653  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1701  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1748  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1841  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1870  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 2016  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 2088  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 2206  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 4527  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
#
# [9 rows x 13 columns]

# %% [markdown]
# ###**3.3 Checking for duplicate values**

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10357 rows x 13 columns]

# %%
df_reviews.drop_duplicates(inplace=True)

# %%
df_reviews
# Out:
#                                   App  ... Sentiment_Subjectivity
# 0               10 Best Foods for You  ...               0.533333
# 1               10 Best Foods for You  ...               0.288462
# 2               10 Best Foods for You  ...                    NaN
# 3               10 Best Foods for You  ...               0.875000
# 4               10 Best Foods for You  ...               0.300000
# ...                               ...  ...                    ...
# 64223  Housing-Real Estate & Property  ...               0.447222
# 64226  Housing-Real Estate & Property  ...               0.250000
# 64227  Housing-Real Estate & Property  ...               1.000000
# 64230  Housing-Real Estate & Property  ...               0.400000
# 64236     Houzz Interior Design Ideas  ...                    NaN
#
# [30679 rows x 5 columns]

# %% [markdown]
# #**4.DATA MANIPULATION**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
def impute_medium(series):
  return series.fillna(series.median)

# %%
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10357 rows x 13 columns]

# %%
print(df['Type'].mode())
print(df['Current Ver'].mode())
print(df['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
# 0    Varies with device
# dtype: object
# 0    4.1 and up
# dtype: object

# %% [markdown]
# **Filling the Missing values with mode values of Type, Current ver and Android ver so that the values can be filled and the data looks more presentable.**

# %%
df['Type'].fillna(str(df['Type'].mode().values[0]),inplace=True)
df['Current Ver'].fillna(str(df['Current Ver'].mode().values[0]),inplace=True)
df['Android Ver'].fillna(str(df['Android Ver'].mode().values[0]),inplace=True)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %% [markdown]
# **Removing a $ sign from the Price as it was creating a hindarnce while doing the analysis of the data.**

# %%
df['Price'] = df['Price'].apply((lambda x: str(x).replace('$','')if '$' in str(x) else str(x)))
df['Price'] = df['Price'].apply((lambda x: float(x)))
df['Reviews'] = pd.to_numeric(df['Reviews'], errors ='coerce')

# %% [markdown]
# **Removing a + sign from the Installs as it was creating a hindarnce while doing the analysis of the data.**

# %%
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x)) 
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price
# count  8892.000000  1.035700e+04  1.035700e+04  10357.000000
# mean      4.187877  4.059046e+05  1.415776e+07      1.030800
# std       0.522377  2.696778e+06  8.023955e+07     16.278625
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.200000e+01  1.000000e+03      0.000000
# 50%       4.300000  1.680000e+03  1.000000e+05      0.000000
# 75%       4.500000  4.641600e+04  1.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# **Checking how many Apps are free for the user and how many are paid.**

# %%
df[df.Price>0].count()
# Out:
# App               765
# Category          765
# Rating            613
# Reviews           765
# Size              765
# Installs          765
# Type              765
# Price             765
# Content Rating    765
# Genres            765
# Last Updated      765
# Current Ver       765
# Android Ver       765
# dtype: int64

# %%
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10357 rows x 13 columns]

# %% [markdown]
# **Remove missing values.**

# %%
df1 = df.dropna()
df1
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10834                                      FR Calculator  ...          4.1 and up
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [8892 rows x 13 columns]

# %% [markdown]
# **Removing the missing values as to make the data more presentable and suitable for analysis.**

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df1)
plt.show()

# %% [markdown]
# **Showing that there is no missing value left in the data and that it is more presentable and suitable for analysis.**

# %%
g = df_reviews.groupby('App')
g

# %%
for App ,App_df_reviews in g:
    print(App)
    print(App_df_reviews),
# Out:
# Streaming output truncated to the last 5000 lines.
# 53164  Genius Scan - PDF Scanner  ...               0.189766
# 53165  Genius Scan - PDF Scanner  ...               0.636667
# 53166  Genius Scan - PDF Scanner  ...               0.900000
# 53167  Genius Scan - PDF Scanner  ...               0.666667
# 53168  Genius Scan - PDF Scanner  ...               0.200000
# 53169  Genius Scan - PDF Scanner  ...               0.453571
# 53170  Genius Scan - PDF Scanner  ...               0.500000
# 53171  Genius Scan - PDF Scanner  ...               0.753333
# 53172  Genius Scan - PDF Scanner  ...               0.616667
# 53173  Genius Scan - PDF Scanner  ...               0.875000
# 53174  Genius Scan - PDF Scanner  ...               0.000000
# 53175  Genius Scan - PDF Scanner  ...               0.394444
# 53176  Genius Scan - PDF Scanner  ...               0.552222
# 53177  Genius Scan - PDF Scanner  ...                    NaN
#
# [14 rows x 5 columns]
# Geo Tracker - GPS tracker
#                              App  ... Sentiment_Subjectivity
# 53244  Geo Tracker - GPS tracker  ...                    NaN
#
# [1 rows x 5 columns]
# Geocaching®
#                App  ... Sentiment_Subjectivity
# 53284  Geocaching®  ...                    NaN
#
# [1 rows x 5 columns]
# Geometry Dash World
#                        App  ... Sentiment_Subjectivity
# 53324  Geometry Dash World  ...                    NaN
#
# [1 rows x 5 columns]
# Ghostery Privacy Browser
#                             App  ... Sentiment_Subjectivity
# 53364  Ghostery Privacy Browser  ...                    NaN
#
# [1 rows x 5 columns]
# GialloZafferano: le Ricette
#                                App  ... Sentiment_Subjectivity
# 53404  GialloZafferano: le Ricette  ...                    NaN
#
# [1 rows x 5 columns]
# Girls Hairstyles
#                     App  ... Sentiment_Subjectivity
# 53444  Girls Hairstyles  ...                    NaN
#
# [1 rows x 5 columns]
# Girls Live Chat - Free Text & Video Chat
#                                             App  ... Sentiment_Subjectivity
# 53524  Girls Live Chat - Free Text & Video Chat  ...                    NaN
#
# [1 rows x 5 columns]
# Girls Online Talk - Free Text and Video Chat
#                                                 App  ... Sentiment_Subjectivity
# 53582  Girls Online Talk - Free Text and Video Chat  ...                    NaN
#
# [1 rows x 5 columns]
# Girls' Frontline
#                     App  ... Sentiment_Subjectivity
# 53622  Girls' Frontline  ...                    NaN
#
# [1 rows x 5 columns]
# Girly Lock Screen Wallpaper with Quotes
#                                            App  ... Sentiment_Subjectivity
# 53662  Girly Lock Screen Wallpaper with Quotes  ...                    NaN
#
# [1 rows x 5 columns]
# Girly Wallpapers Backgrounds
#                                 App  ... Sentiment_Subjectivity
# 53702  Girly Wallpapers Backgrounds  ...                    NaN
#
# [1 rows x 5 columns]
# Glam - Premium Dating App
#                              App  ... Sentiment_Subjectivity
# 53742  Glam - Premium Dating App  ...                    NaN
#
# [1 rows x 5 columns]
# GlassesOff
#               App Translated_Review  ... Sentiment_Polarity  Sentiment_Subjectivity
# 53782  GlassesOff               NaN  ...                NaN                     NaN
#
# [1 rows x 5 columns]
# Glide - Video Chat Messenger
#                                 App  ... Sentiment_Subjectivity
# 53822  Glide - Video Chat Messenger  ...                    NaN
#
# [1 rows x 5 columns]
# Glow Hockey
#                App  ... Sentiment_Subjectivity
# 53902  Glow Hockey  ...                    NaN
#
# [1 rows x 5 columns]
# Glowing Flowers Live Wallpaper
#                                   App  ... Sentiment_Subjectivity
# 53942  Glowing Flowers Live Wallpaper  ...                    NaN
#
# [1 rows x 5 columns]
# Gmail
#          App  ... Sentiment_Subjectivity
# 53982  Gmail  ...                    NaN
# 53995  Gmail  ...               0.500000
# 53996  Gmail  ...               0.571429
# 53997  Gmail  ...               0.324242
# 53998  Gmail  ...               0.664526
# 53999  Gmail  ...               0.950000
# 54000  Gmail  ...               0.000000
# 54001  Gmail  ...               0.350000
# 54002  Gmail  ...               0.481847
# 54003  Gmail  ...               0.540278
# 54004  Gmail  ...               0.338095
# 54005  Gmail  ...               0.341667
# 54006  Gmail  ...               0.550000
# 54007  Gmail  ...               0.494444
# 54008  Gmail  ...               0.593750
# 54009  Gmail  ...               0.750000
# 54011  Gmail  ...               0.562500
# 54012  Gmail  ...               0.300000
# 54013  Gmail  ...               0.291667
# 54014  Gmail  ...               0.310606
# 54015  Gmail  ...               0.525000
# 54016  Gmail  ...               0.333333
# 54017  Gmail  ...               0.150000
# 54018  Gmail  ...               0.750000
# 54019  Gmail  ...               0.900000
# 54020  Gmail  ...               0.000000
# 54021  Gmail  ...               0.350000
# 54022  Gmail  ...               0.417708
# 54023  Gmail  ...               0.260000
# 54024  Gmail  ...               0.357341
# 54025  Gmail  ...               0.393056
# 54026  Gmail  ...               0.500000
# 54027  Gmail  ...               0.524567
# 54028  Gmail  ...               0.408333
# 54029  Gmail  ...               0.440000
# 54031  Gmail  ...               1.000000
# 54032  Gmail  ...               0.791667
# 54033  Gmail  ...               0.258333
# 54034  Gmail  ...               0.486111
# 54040  Gmail  ...               0.485000
# 54051  Gmail  ...               0.000000
#
# [41 rows x 5 columns]
# GoBank
#           App  ... Sentiment_Subjectivity
# 54062  GoBank  ...               0.492121
# 54063  GoBank  ...               0.518750
# 54064  GoBank  ...               0.762500
# 54065  GoBank  ...               0.573718
# 54066  GoBank  ...               0.683333
# 54067  GoBank  ...               0.525397
# 54068  GoBank  ...               0.600000
# 54069  GoBank  ...               0.386429
# 54070  GoBank  ...               0.541667
# 54071  GoBank  ...               0.200000
# 54072  GoBank  ...               0.833333
# 54073  GoBank  ...               0.500000
# 54074  GoBank  ...               0.517857
# 54075  GoBank  ...               0.350000
# 54076  GoBank  ...               0.498148
# 54077  GoBank  ...               0.316667
# 54078  GoBank  ...               0.458333
# 54079  GoBank  ...               0.367685
# 54080  GoBank  ...               0.700000
# 54081  GoBank  ...               0.544444
# 54082  GoBank  ...               0.295833
# 54083  GoBank  ...               0.470085
# 54084  GoBank  ...               0.212963
# 54085  GoBank  ...               0.300000
# 54086  GoBank  ...               0.747917
# 54087  GoBank  ...                    NaN
# 54088  GoBank  ...               0.321429
# 54089  GoBank  ...               0.369231
# 54090  GoBank  ...               0.000000
# 54091  GoBank  ...               0.666667
# 54092  GoBank  ...               0.600000
# 54093  GoBank  ...               0.883333
# 54094  GoBank  ...               0.750000
# 54095  GoBank  ...               0.577273
# 54096  GoBank  ...               0.566667
# 54097  GoBank  ...               0.500000
# 54098  GoBank  ...               0.700000
# 54099  GoBank  ...               0.700000
# 54100  GoBank  ...               0.900000
# 54101  GoBank  ...               0.750000
#
# [40 rows x 5 columns]
# GoPro (formerly Capture)
#                             App  ... Sentiment_Subjectivity
# 54102  GoPro (formerly Capture)  ...               0.533333
# 54103  GoPro (formerly Capture)  ...               0.775794
# 54104  GoPro (formerly Capture)  ...               0.662500
# 54105  GoPro (formerly Capture)  ...               0.642857
# 54106  GoPro (formerly Capture)  ...               0.556250
# 54107  GoPro (formerly Capture)  ...               0.386111
# 54108  GoPro (formerly Capture)  ...               0.405000
# 54109  GoPro (formerly Capture)  ...               0.500000
# 54110  GoPro (formerly Capture)  ...               0.340476
# 54111  GoPro (formerly Capture)  ...               0.400000
# 54112  GoPro (formerly Capture)  ...               0.766667
# 54113  GoPro (formerly Capture)  ...               0.284943
# 54114  GoPro (formerly Capture)  ...               0.497917
# 54115  GoPro (formerly Capture)  ...               0.366402
# 54116  GoPro (formerly Capture)  ...               0.000000
# 54117  GoPro (formerly Capture)  ...               0.639583
# 54118  GoPro (formerly Capture)  ...               0.307071
# 54119  GoPro (formerly Capture)  ...               0.326667
# 54120  GoPro (formerly Capture)  ...               0.775000
# 54121  GoPro (formerly Capture)  ...               0.577778
# 54122  GoPro (formerly Capture)  ...               0.478571
# 54123  GoPro (formerly Capture)  ...               0.642857
# 54124  GoPro (formerly Capture)  ...               0.486905
# 54125  GoPro (formerly Capture)  ...               0.000000
# 54126  GoPro (formerly Capture)  ...               0.625000
# 54127  GoPro (formerly Capture)  ...               0.476531
# 54128  GoPro (formerly Capture)  ...               0.637500
# 54129  GoPro (formerly Capture)  ...               0.358333
# 54130  GoPro (formerly Capture)  ...               0.192308
# 54131  GoPro (formerly Capture)  ...                    NaN
# 54132  GoPro (formerly Capture)  ...               0.393750
# 54133  GoPro (formerly Capture)  ...               0.208929
# 54134  GoPro (formerly Capture)  ...               0.404762
# 54135  GoPro (formerly Capture)  ...               0.300000
# 54136  GoPro (formerly Capture)  ...               0.778535
# 54137  GoPro (formerly Capture)  ...               0.441667
# 54138  GoPro (formerly Capture)  ...               0.380000
# 54139  GoPro (formerly Capture)  ...               0.812500
# 54140  GoPro (formerly Capture)  ...               0.281250
# 54141  GoPro (formerly Capture)  ...               0.375000
#
# [40 rows x 5 columns]
# Goal Live Scores
#                     App  ... Sentiment_Subjectivity
# 54142  Goal Live Scores  ...               0.704167
# 54143  Goal Live Scores  ...               0.594444
# 54144  Goal Live Scores  ...               0.425000
# 54145  Goal Live Scores  ...               0.633333
# 54146  Goal Live Scores  ...               0.600000
# 54147  Goal Live Scores  ...               0.683333
# 54148  Goal Live Scores  ...               0.550000
# 54149  Goal Live Scores  ...               0.466667
# 54150  Goal Live Scores  ...               0.433983
# 54151  Goal Live Scores  ...               0.353333
# 54152  Goal Live Scores  ...               0.736000
# 54153  Goal Live Scores  ...               0.483333
# 54154  Goal Live Scores  ...               0.675000
# 54155  Goal Live Scores  ...               0.566667
# 54156  Goal Live Scores  ...               0.233333
# 54157  Goal Live Scores  ...               0.700000
# 54158  Goal Live Scores  ...               0.600000
# 54159  Goal Live Scores  ...               0.717857
# 54160  Goal Live Scores  ...               0.366667
# 54161  Goal Live Scores  ...               0.427273
# 54162  Goal Live Scores  ...               0.500000
# 54163  Goal Live Scores  ...               0.500000
# 54164  Goal Live Scores  ...               0.723810
# 54165  Goal Live Scores  ...               1.000000
# 54166  Goal Live Scores  ...               0.300000
# 54167  Goal Live Scores  ...               0.540000
# 54168  Goal Live Scores  ...               0.000000
# 54169  Goal Live Scores  ...               0.214286
# 54170  Goal Live Scores  ...               0.450000
# 54171  Goal Live Scores  ...               0.000000
# 54172  Goal Live Scores  ...               0.600000
# 54173  Goal Live Scores  ...               0.000000
# 54174  Goal Live Scores  ...               0.625000
# 54175  Goal Live Scores  ...               0.416667
# 54176  Goal Live Scores  ...               0.800000
# 54177  Goal Live Scores  ...               0.666667
# 54178  Goal Live Scores  ...               1.000000
# 54179  Goal Live Scores  ...               0.666667
# 54180  Goal Live Scores  ...               0.600000
# 54181  Goal Live Scores  ...               0.000000
#
# [40 rows x 5 columns]
# Goibibo - Flight Hotel Bus Car IRCTC Booking App
#                                                     App  ... Sentiment_Subjectivity
# 54182  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.429630
# 54183  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.520833
# 54184  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.500000
# 54185  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.750000
# 54186  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.716667
# 54187  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54188  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.650000
# 54189  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.780000
# 54190  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.300000
# 54191  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.875000
# 54192  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54193  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54194  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54195  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.780000
# 54196  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.900000
# 54197  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.780000
# 54198  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54199  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.600000
# 54200  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.600000
# 54201  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.950000
# 54202  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.716667
# 54203  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54204  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.900000
# 54205  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.300000
# 54206  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.600000
# 54207  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               1.000000
# 54208  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.600000
# 54209  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.600000
# 54210  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.000000
# 54211  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               1.000000
# 54214  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...                    NaN
# 54215  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.750000
# 54216  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               1.000000
# 54217  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.383333
# 54218  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.800000
# 54221  Goibibo - Flight Hotel Bus Car IRCTC Booking App  ...               0.485909
#
# [36 rows x 5 columns]
# Goku Wallpaper Art
#                       App  ... Sentiment_Subjectivity
# 54222  Goku Wallpaper Art  ...               0.650000
# 54223  Goku Wallpaper Art  ...               0.700000
# 54224  Goku Wallpaper Art  ...               0.650000
# 54225  Goku Wallpaper Art  ...               0.883333
# 54226  Goku Wallpaper Art  ...               0.650000
# 54227  Goku Wallpaper Art  ...                    NaN
# 54228  Goku Wallpaper Art  ...               0.000000
# 54229  Goku Wallpaper Art  ...               0.800000
# 54230  Goku Wallpaper Art  ...               0.000000
# 54231  Goku Wallpaper Art  ...               1.000000
# 54232  Goku Wallpaper Art  ...               0.700000
# 54234  Goku Wallpaper Art  ...               0.600000
# 54235  Goku Wallpaper Art  ...               1.000000
# 54236  Goku Wallpaper Art  ...               0.000000
# 54237  Goku Wallpaper Art  ...               0.750000
# 54238  Goku Wallpaper Art  ...               0.300000
# 54239  Goku Wallpaper Art  ...               0.600000
# 54240  Goku Wallpaper Art  ...               1.000000
# 54241  Goku Wallpaper Art  ...               0.000000
# 54242  Goku Wallpaper Art  ...               0.600000
# 54244  Goku Wallpaper Art  ...               0.750000
# 54245  Goku Wallpaper Art  ...               0.000000
# 54246  Goku Wallpaper Art  ...               0.753571
# 54247  Goku Wallpaper Art  ...               0.600000
# 54248  Goku Wallpaper Art  ...               0.000000
# 54249  Goku Wallpaper Art  ...               0.800000
# 54250  Goku Wallpaper Art  ...               0.750000
# 54251  Goku Wallpaper Art  ...               0.525000
# 54252  Goku Wallpaper Art  ...               0.000000
# 54253  Goku Wallpaper Art  ...               0.300000
# 54256  Goku Wallpaper Art  ...               0.300000
# 54257  Goku Wallpaper Art  ...               0.600000
# 54258  Goku Wallpaper Art  ...               0.600000
# 54259  Goku Wallpaper Art  ...               0.500000
# 54260  Goku Wallpaper Art  ...               0.750000
# 54261  Goku Wallpaper Art  ...               0.000000
#
# [36 rows x 5 columns]
# Gold Butterfly Keyboard Theme
#                                  App  ... Sentiment_Subjectivity
# 54262  Gold Butterfly Keyboard Theme  ...               0.900000
# 54263  Gold Butterfly Keyboard Theme  ...               0.600000
# 54264  Gold Butterfly Keyboard Theme  ...               0.600000
# 54265  Gold Butterfly Keyboard Theme  ...               0.600000
# 54266  Gold Butterfly Keyboard Theme  ...               0.900000
# 54267  Gold Butterfly Keyboard Theme  ...               1.000000
# 54268  Gold Butterfly Keyboard Theme  ...               0.850000
# 54269  Gold Butterfly Keyboard Theme  ...               0.645960
# 54270  Gold Butterfly Keyboard Theme  ...               0.600000
# 54271  Gold Butterfly Keyboard Theme  ...               0.377273
# 54272  Gold Butterfly Keyboard Theme  ...               0.600000
# 54273  Gold Butterfly Keyboard Theme  ...               1.000000
# 54274  Gold Butterfly Keyboard Theme  ...               0.000000
# 54275  Gold Butterfly Keyboard Theme  ...               0.000000
# 54276  Gold Butterfly Keyboard Theme  ...               0.000000
# 54277  Gold Butterfly Keyboard Theme  ...               1.000000
# 54278  Gold Butterfly Keyboard Theme  ...               0.650000
# 54279  Gold Butterfly Keyboard Theme  ...               0.000000
# 54280  Gold Butterfly Keyboard Theme  ...               1.000000
# 54281  Gold Butterfly Keyboard Theme  ...               0.600000
# 54282  Gold Butterfly Keyboard Theme  ...               0.600000
# 54283  Gold Butterfly Keyboard Theme  ...               0.600000
# 54284  Gold Butterfly Keyboard Theme  ...               0.520000
# 54285  Gold Butterfly Keyboard Theme  ...               0.000000
# 54286  Gold Butterfly Keyboard Theme  ...               0.000000
# 54287  Gold Butterfly Keyboard Theme  ...               1.000000
# 54289  Gold Butterfly Keyboard Theme  ...               0.600000
# 54290  Gold Butterfly Keyboard Theme  ...               0.500000
# 54291  Gold Butterfly Keyboard Theme  ...               1.000000
# 54292  Gold Butterfly Keyboard Theme  ...               0.600000
# 54293  Gold Butterfly Keyboard Theme  ...               1.000000
# 54297  Gold Butterfly Keyboard Theme  ...               0.000000
# 54298  Gold Butterfly Keyboard Theme  ...                    NaN
# 54299  Gold Butterfly Keyboard Theme  ...               0.300000
# 54301  Gold Butterfly Keyboard Theme  ...               1.000000
#
# [35 rows x 5 columns]
# Golden Dictionary (EN-AR)
#                              App  ... Sentiment_Subjectivity
# 54302  Golden Dictionary (EN-AR)  ...               0.400000
# 54303  Golden Dictionary (EN-AR)  ...               0.583333
# 54304  Golden Dictionary (EN-AR)  ...                    NaN
# 54305  Golden Dictionary (EN-AR)  ...               0.866667
# 54306  Golden Dictionary (EN-AR)  ...               0.300000
# 54307  Golden Dictionary (EN-AR)  ...               0.600000
# 54308  Golden Dictionary (EN-AR)  ...               0.000000
# 54309  Golden Dictionary (EN-AR)  ...               0.200000
# 54310  Golden Dictionary (EN-AR)  ...               0.000000
# 54311  Golden Dictionary (EN-AR)  ...               0.000000
# 54312  Golden Dictionary (EN-AR)  ...               0.500000
# 54313  Golden Dictionary (EN-AR)  ...               0.500000
# 54314  Golden Dictionary (EN-AR)  ...               0.900000
# 54315  Golden Dictionary (EN-AR)  ...               0.611111
# 54316  Golden Dictionary (EN-AR)  ...               0.400000
# 54317  Golden Dictionary (EN-AR)  ...               0.000000
# 54318  Golden Dictionary (EN-AR)  ...               1.000000
# 54319  Golden Dictionary (EN-AR)  ...               0.250000
# 54321  Golden Dictionary (EN-AR)  ...               0.000000
# 54322  Golden Dictionary (EN-AR)  ...               0.000000
# 54323  Golden Dictionary (EN-AR)  ...               0.000000
# 54324  Golden Dictionary (EN-AR)  ...               1.000000
# 54325  Golden Dictionary (EN-AR)  ...               0.000000
# 54326  Golden Dictionary (EN-AR)  ...               0.750000
# 54327  Golden Dictionary (EN-AR)  ...               0.780000
# 54328  Golden Dictionary (EN-AR)  ...               0.900000
# 54329  Golden Dictionary (EN-AR)  ...               1.000000
# 54331  Golden Dictionary (EN-AR)  ...               1.000000
# 54332  Golden Dictionary (EN-AR)  ...               1.000000
# 54333  Golden Dictionary (EN-AR)  ...               0.000000
# 54334  Golden Dictionary (EN-AR)  ...               0.900000
# 54335  Golden Dictionary (EN-AR)  ...               1.000000
# 54336  Golden Dictionary (EN-AR)  ...               0.000000
# 54337  Golden Dictionary (EN-AR)  ...               0.000000
# 54338  Golden Dictionary (EN-AR)  ...               0.600000
# 54339  Golden Dictionary (EN-AR)  ...               0.900000
# 54340  Golden Dictionary (EN-AR)  ...               0.600000
# 54341  Golden Dictionary (EN-AR)  ...               0.600000
#
# [38 rows x 5 columns]
# Golden Launcher
#                    App  ... Sentiment_Subjectivity
# 54342  Golden Launcher  ...               0.850000
# 54343  Golden Launcher  ...               0.750000
# 54344  Golden Launcher  ...               0.300000
# 54345  Golden Launcher  ...               0.602273
# 54346  Golden Launcher  ...               1.000000
# 54347  Golden Launcher  ...               0.000000
# 54348  Golden Launcher  ...                    NaN
# 54349  Golden Launcher  ...               0.000000
# 54350  Golden Launcher  ...               0.750000
# 54351  Golden Launcher  ...               0.400000
# 54352  Golden Launcher  ...               1.000000
# 54353  Golden Launcher  ...               0.500000
# 54354  Golden Launcher  ...               1.000000
# 54355  Golden Launcher  ...               0.600000
# 54357  Golden Launcher  ...               0.600000
# 54358  Golden Launcher  ...               0.950000
# 54359  Golden Launcher  ...               0.000000
# 54360  Golden Launcher  ...               0.000000
# 54361  Golden Launcher  ...               0.000000
# 54362  Golden Launcher  ...               1.000000
# 54363  Golden Launcher  ...               0.600000
# 54364  Golden Launcher  ...               1.000000
# 54365  Golden Launcher  ...               0.300000
# 54366  Golden Launcher  ...               0.650000
# 54367  Golden Launcher  ...               0.300000
# 54368  Golden Launcher  ...               0.600000
# 54369  Golden Launcher  ...               1.000000
# 54370  Golden Launcher  ...               1.000000
# 54371  Golden Launcher  ...               1.000000
# 54373  Golden Launcher  ...               0.600000
# 54374  Golden Launcher  ...               0.600000
# 54378  Golden Launcher  ...               0.600000
# 54379  Golden Launcher  ...               0.666667
# 54380  Golden Launcher  ...               0.000000
# 54381  Golden Launcher  ...               0.000000
#
# [35 rows x 5 columns]
# Goldstar: Live Event Tickets
#                                 App  ... Sentiment_Subjectivity
# 54382  Goldstar: Live Event Tickets  ...               0.750000
# 54383  Goldstar: Live Event Tickets  ...               0.600000
# 54384  Goldstar: Live Event Tickets  ...               0.645000
# 54385  Goldstar: Live Event Tickets  ...               0.675000
# 54386  Goldstar: Live Event Tickets  ...               0.750000
# 54387  Goldstar: Live Event Tickets  ...               0.616667
# 54388  Goldstar: Live Event Tickets  ...               0.535714
# 54389  Goldstar: Live Event Tickets  ...               0.550000
# 54390  Goldstar: Live Event Tickets  ...               0.500000
# 54391  Goldstar: Live Event Tickets  ...               0.600000
# 54392  Goldstar: Live Event Tickets  ...               0.600000
# 54393  Goldstar: Live Event Tickets  ...               0.550000
# 54394  Goldstar: Live Event Tickets  ...               0.000000
# 54395  Goldstar: Live Event Tickets  ...               0.800000
# 54396  Goldstar: Live Event Tickets  ...               0.700000
# 54397  Goldstar: Live Event Tickets  ...               0.611111
# 54398  Goldstar: Live Event Tickets  ...               0.000000
# 54399  Goldstar: Live Event Tickets  ...               1.000000
# 54400  Goldstar: Live Event Tickets  ...               0.750000
# 54401  Goldstar: Live Event Tickets  ...               0.570833
# 54402  Goldstar: Live Event Tickets  ...               1.000000
# 54403  Goldstar: Live Event Tickets  ...               0.450000
# 54404  Goldstar: Live Event Tickets  ...               0.430159
# 54405  Goldstar: Live Event Tickets  ...               0.833333
# 54406  Goldstar: Live Event Tickets  ...               0.950000
# 54407  Goldstar: Live Event Tickets  ...               0.833333
# 54408  Goldstar: Live Event Tickets  ...               0.600000
# 54409  Goldstar: Live Event Tickets  ...               0.437500
# 54410  Goldstar: Live Event Tickets  ...               0.475000
# 54411  Goldstar: Live Event Tickets  ...               0.300000
# 54412  Goldstar: Live Event Tickets  ...               0.750000
# 54413  Goldstar: Live Event Tickets  ...               0.750000
# 54414  Goldstar: Live Event Tickets  ...               0.666667
# 54415  Goldstar: Live Event Tickets  ...               0.750000
# 54416  Goldstar: Live Event Tickets  ...               0.950000
# 54417  Goldstar: Live Event Tickets  ...               0.733333
# 54418  Goldstar: Live Event Tickets  ...               0.750000
# 54419  Goldstar: Live Event Tickets  ...               0.750000
# 54420  Goldstar: Live Event Tickets  ...               0.750000
# 54421  Goldstar: Live Event Tickets  ...               0.454545
#
# [40 rows x 5 columns]
# Golf Channel
#                 App  ... Sentiment_Subjectivity
# 54422  Golf Channel  ...               0.800000
# 54423  Golf Channel  ...               0.450000
# 54424  Golf Channel  ...               0.472222
# 54425  Golf Channel  ...               0.426190
# 54426  Golf Channel  ...               0.530000
# 54427  Golf Channel  ...               0.522222
# 54428  Golf Channel  ...               0.512500
# 54429  Golf Channel  ...               0.000000
# 54430  Golf Channel  ...               0.333333
# 54431  Golf Channel  ...               0.291111
# 54432  Golf Channel  ...               0.750000
# 54433  Golf Channel  ...               0.411111
# 54434  Golf Channel  ...               0.400000
# 54435  Golf Channel  ...               0.322222
# 54436  Golf Channel  ...               0.700000
# 54437  Golf Channel  ...               0.637500
# 54438  Golf Channel  ...               0.300000
# 54439  Golf Channel  ...               0.000000
# 54440  Golf Channel  ...               0.375000
# 54441  Golf Channel  ...               0.216667
# 54442  Golf Channel  ...               0.475000
# 54443  Golf Channel  ...               0.216667
# 54444  Golf Channel  ...               0.750000
# 54445  Golf Channel  ...               0.400000
# 54446  Golf Channel  ...               0.400000
# 54447  Golf Channel  ...               0.900000
# 54448  Golf Channel  ...               0.616667
# 54449  Golf Channel  ...               0.600000
# 54450  Golf Channel  ...               0.616667
# 54451  Golf Channel  ...               0.333333
# 54452  Golf Channel  ...               0.500000
# 54453  Golf Channel  ...               0.600000
# 54454  Golf Channel  ...               0.500000
# 54455  Golf Channel  ...               0.400000
# 54456  Golf Channel  ...               0.500000
# 54457  Golf Channel  ...               0.387500
# 54458  Golf Channel  ...               0.450000
# 54459  Golf Channel  ...               0.513333
# 54460  Golf Channel  ...               0.333333
# 54461  Golf Channel  ...               0.500000
#
# [40 rows x 5 columns]
# Golf GPS Rangefinder: Golf Pad
#                                   App  ... Sentiment_Subjectivity
# 54462  Golf GPS Rangefinder: Golf Pad  ...               0.427143
# 54463  Golf GPS Rangefinder: Golf Pad  ...               0.537037
# 54464  Golf GPS Rangefinder: Golf Pad  ...               0.454643
# 54465  Golf GPS Rangefinder: Golf Pad  ...               0.400000
# 54466  Golf GPS Rangefinder: Golf Pad  ...               0.664583
# 54467  Golf GPS Rangefinder: Golf Pad  ...               0.241667
# 54468  Golf GPS Rangefinder: Golf Pad  ...               0.633333
# 54469  Golf GPS Rangefinder: Golf Pad  ...               0.750000
# 54470  Golf GPS Rangefinder: Golf Pad  ...               0.666667
# 54471  Golf GPS Rangefinder: Golf Pad  ...               0.833333
# 54472  Golf GPS Rangefinder: Golf Pad  ...               0.675000
# 54473  Golf GPS Rangefinder: Golf Pad  ...               0.150000
# 54474  Golf GPS Rangefinder: Golf Pad  ...               1.000000
# 54475  Golf GPS Rangefinder: Golf Pad  ...               0.666667
# 54476  Golf GPS Rangefinder: Golf Pad  ...               0.600000
# 54477  Golf GPS Rangefinder: Golf Pad  ...               0.675000
# 54478  Golf GPS Rangefinder: Golf Pad  ...               0.566667
# 54479  Golf GPS Rangefinder: Golf Pad  ...               0.300000
# 54480  Golf GPS Rangefinder: Golf Pad  ...               0.000000
# 54481  Golf GPS Rangefinder: Golf Pad  ...               0.791667
# 54482  Golf GPS Rangefinder: Golf Pad  ...               0.600000
# 54483  Golf GPS Rangefinder: Golf Pad  ...               0.650000
# 54484  Golf GPS Rangefinder: Golf Pad  ...               0.812500
# 54485  Golf GPS Rangefinder: Golf Pad  ...               0.566667
# 54486  Golf GPS Rangefinder: Golf Pad  ...               0.608929
# 54487  Golf GPS Rangefinder: Golf Pad  ...               0.514583
# 54488  Golf GPS Rangefinder: Golf Pad  ...               0.544156
# 54489  Golf GPS Rangefinder: Golf Pad  ...               0.583333
# 54490  Golf GPS Rangefinder: Golf Pad  ...               0.616667
# 54491  Golf GPS Rangefinder: Golf Pad  ...               0.572917
# 54492  Golf GPS Rangefinder: Golf Pad  ...               0.116667
# 54493  Golf GPS Rangefinder: Golf Pad  ...               0.551852
# 54494  Golf GPS Rangefinder: Golf Pad  ...               0.556667
# 54495  Golf GPS Rangefinder: Golf Pad  ...               0.613333
# 54496  Golf GPS Rangefinder: Golf Pad  ...               0.576667
# 54497  Golf GPS Rangefinder: Golf Pad  ...                    NaN
# 54498  Golf GPS Rangefinder: Golf Pad  ...               0.650000
# 54499  Golf GPS Rangefinder: Golf Pad  ...               0.477778
# 54500  Golf GPS Rangefinder: Golf Pad  ...               0.386667
# 54501  Golf GPS Rangefinder: Golf Pad  ...               1.000000
#
# [40 rows x 5 columns]
# Golf GPS by SwingxSwing
#                            App  ... Sentiment_Subjectivity
# 54502  Golf GPS by SwingxSwing  ...               0.477778
# 54503  Golf GPS by SwingxSwing  ...               0.335000
# 54504  Golf GPS by SwingxSwing  ...               0.314583
# 54505  Golf GPS by SwingxSwing  ...               0.598413
# 54506  Golf GPS by SwingxSwing  ...               0.650000
# 54507  Golf GPS by SwingxSwing  ...               0.455191
# 54508  Golf GPS by SwingxSwing  ...               0.549444
# 54509  Golf GPS by SwingxSwing  ...               0.748611
# 54510  Golf GPS by SwingxSwing  ...               0.580556
# 54511  Golf GPS by SwingxSwing  ...               0.444808
# 54512  Golf GPS by SwingxSwing  ...               0.390476
# 54513  Golf GPS by SwingxSwing  ...               0.351190
# 54514  Golf GPS by SwingxSwing  ...               0.345833
# 54515  Golf GPS by SwingxSwing  ...               0.150000
# 54516  Golf GPS by SwingxSwing  ...               0.575000
# 54517  Golf GPS by SwingxSwing  ...               0.387500
# 54518  Golf GPS by SwingxSwing  ...               0.200000
# 54519  Golf GPS by SwingxSwing  ...               0.277273
# 54520  Golf GPS by SwingxSwing  ...               0.600000
# 54521  Golf GPS by SwingxSwing  ...               0.066667
# 54522  Golf GPS by SwingxSwing  ...               0.483333
# 54523  Golf GPS by SwingxSwing  ...               0.283333
# 54524  Golf GPS by SwingxSwing  ...               0.451136
# 54525  Golf GPS by SwingxSwing  ...               0.441667
# 54526  Golf GPS by SwingxSwing  ...               0.200000
# 54527  Golf GPS by SwingxSwing  ...               0.312222
# 54528  Golf GPS by SwingxSwing  ...               0.562500
# 54529  Golf GPS by SwingxSwing  ...               0.454545
# 54530  Golf GPS by SwingxSwing  ...               0.900000
# 54531  Golf GPS by SwingxSwing  ...               0.377778
# 54532  Golf GPS by SwingxSwing  ...               0.362500
# 54533  Golf GPS by SwingxSwing  ...               0.598611
# 54534  Golf GPS by SwingxSwing  ...               0.495000
# 54535  Golf GPS by SwingxSwing  ...               0.750000
# 54536  Golf GPS by SwingxSwing  ...               0.741667
# 54537  Golf GPS by SwingxSwing  ...               0.477778
# 54538  Golf GPS by SwingxSwing  ...               0.600000
# 54539  Golf GPS by SwingxSwing  ...               0.725000
# 54540  Golf GPS by SwingxSwing  ...               0.441667
# 54541  Golf GPS by SwingxSwing  ...               0.150000
#
# [40 rows x 5 columns]
# GolfLogix GPS + Putt Breaks
#                                App  ... Sentiment_Subjectivity
# 54542  GolfLogix GPS + Putt Breaks  ...               0.400000
# 54543  GolfLogix GPS + Putt Breaks  ...               0.225000
# 54544  GolfLogix GPS + Putt Breaks  ...               0.510455
# 54545  GolfLogix GPS + Putt Breaks  ...               0.433333
# 54546  GolfLogix GPS + Putt Breaks  ...               0.516667
# 54547  GolfLogix GPS + Putt Breaks  ...               0.300000
# 54548  GolfLogix GPS + Putt Breaks  ...               0.700000
# 54549  GolfLogix GPS + Putt Breaks  ...               0.955000
# 54550  GolfLogix GPS + Putt Breaks  ...               0.000000
# 54551  GolfLogix GPS + Putt Breaks  ...               0.133333
# 54552  GolfLogix GPS + Putt Breaks  ...               0.500000
# 54553  GolfLogix GPS + Putt Breaks  ...               0.285714
# 54554  GolfLogix GPS + Putt Breaks  ...               0.485185
# 54555  GolfLogix GPS + Putt Breaks  ...               0.860000
# 54556  GolfLogix GPS + Putt Breaks  ...               0.379167
# 54557  GolfLogix GPS + Putt Breaks  ...               0.577633
# 54558  GolfLogix GPS + Putt Breaks  ...               0.569444
# 54559  GolfLogix GPS + Putt Breaks  ...               0.800000
# 54560  GolfLogix GPS + Putt Breaks  ...               1.000000
# 54561  GolfLogix GPS + Putt Breaks  ...               0.789286
# 54562  GolfLogix GPS + Putt Breaks  ...               0.467121
# 54563  GolfLogix GPS + Putt Breaks  ...               0.487500
# 54564  GolfLogix GPS + Putt Breaks  ...               0.483333
# 54565  GolfLogix GPS + Putt Breaks  ...               0.542857
# 54566  GolfLogix GPS + Putt Breaks  ...               0.255556
# 54567  GolfLogix GPS + Putt Breaks  ...               0.466667
# 54568  GolfLogix GPS + Putt Breaks  ...               0.227273
# 54569  GolfLogix GPS + Putt Breaks  ...               0.702381
# 54570  GolfLogix GPS + Putt Breaks  ...               0.500000
# 54571  GolfLogix GPS + Putt Breaks  ...                    NaN
# 54572  GolfLogix GPS + Putt Breaks  ...               0.000000
# 54573  GolfLogix GPS + Putt Breaks  ...               0.000000
# 54574  GolfLogix GPS + Putt Breaks  ...               0.333333
# 54575  GolfLogix GPS + Putt Breaks  ...               0.487500
# 54576  GolfLogix GPS + Putt Breaks  ...               0.000000
# 54577  GolfLogix GPS + Putt Breaks  ...               0.288889
# 54578  GolfLogix GPS + Putt Breaks  ...               0.291667
# 54579  GolfLogix GPS + Putt Breaks  ...               0.000000
# 54580  GolfLogix GPS + Putt Breaks  ...               0.700000
# 54581  GolfLogix GPS + Putt Breaks  ...               1.000000
#
# [40 rows x 5 columns]
# GolfNow: Tee Time Deals at Golf Courses, Golf GPS
#                                                      App  ... Sentiment_Subjectivity
# 54582  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.471795
# 54583  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.453125
# 54584  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.527381
# 54585  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.525000
# 54586  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.700000
# 54587  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.416667
# 54588  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.637500
# 54589  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.504630
# 54590  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.396667
# 54591  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.375000
# 54592  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...                    NaN
# 54593  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.674074
# 54594  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.507576
# 54595  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.338068
# 54596  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.466667
# 54597  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.401429
# 54598  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.535714
# 54599  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.513889
# 54600  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.500000
# 54601  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.437500
# 54602  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.350000
# 54603  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.617262
# 54604  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.504167
# 54605  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.690972
# 54606  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.900000
# 54607  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.317857
# 54608  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.808333
# 54609  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.651136
# 54610  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.383929
# 54611  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.449767
# 54612  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.000000
# 54613  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.640000
# 54614  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.454545
# 54615  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.750000
# 54617  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.000000
# 54618  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.650000
# 54619  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.375000
# 54620  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.600000
# 54621  GolfNow: Tee Time Deals at Golf Courses, Golf GPS  ...               0.633333
#
# [39 rows x 5 columns]
# Golfshot Plus: Golf GPS
#                            App  ... Sentiment_Subjectivity
# 54622  Golfshot Plus: Golf GPS  ...               0.333333
# 54623  Golfshot Plus: Golf GPS  ...               0.358333
# 54624  Golfshot Plus: Golf GPS  ...               0.333333
# 54625  Golfshot Plus: Golf GPS  ...               0.500000
# 54626  Golfshot Plus: Golf GPS  ...               0.000000
# 54627  Golfshot Plus: Golf GPS  ...               0.777778
# 54628  Golfshot Plus: Golf GPS  ...               0.690000
# 54629  Golfshot Plus: Golf GPS  ...               0.750000
# 54630  Golfshot Plus: Golf GPS  ...               1.000000
# 54631  Golfshot Plus: Golf GPS  ...               0.000000
# 54632  Golfshot Plus: Golf GPS  ...               0.650000
# 54633  Golfshot Plus: Golf GPS  ...               0.727273
# 54634  Golfshot Plus: Golf GPS  ...               0.300000
# 54635  Golfshot Plus: Golf GPS  ...               0.000000
# 54636  Golfshot Plus: Golf GPS  ...               0.420833
# 54637  Golfshot Plus: Golf GPS  ...               0.500000
# 54638  Golfshot Plus: Golf GPS  ...               0.585000
# 54639  Golfshot Plus: Golf GPS  ...               0.442857
# 54640  Golfshot Plus: Golf GPS  ...               0.590000
# 54641  Golfshot Plus: Golf GPS  ...               0.727778
# 54642  Golfshot Plus: Golf GPS  ...               0.000000
# 54643  Golfshot Plus: Golf GPS  ...               0.300000
# 54644  Golfshot Plus: Golf GPS  ...               0.600000
# 54645  Golfshot Plus: Golf GPS  ...               0.625000
# 54646  Golfshot Plus: Golf GPS  ...               0.000000
# 54647  Golfshot Plus: Golf GPS  ...               0.750000
# 54648  Golfshot Plus: Golf GPS  ...               0.400000
# 54649  Golfshot Plus: Golf GPS  ...               0.458333
# 54650  Golfshot Plus: Golf GPS  ...               0.460000
# 54651  Golfshot Plus: Golf GPS  ...               0.466667
# 54652  Golfshot Plus: Golf GPS  ...               0.500000
# 54653  Golfshot Plus: Golf GPS  ...               0.675000
# 54654  Golfshot Plus: Golf GPS  ...               0.600000
# 54655  Golfshot Plus: Golf GPS  ...               0.558333
# 54656  Golfshot Plus: Golf GPS  ...               0.250000
# 54657  Golfshot Plus: Golf GPS  ...               0.422619
# 54658  Golfshot Plus: Golf GPS  ...               0.468333
# 54659  Golfshot Plus: Golf GPS  ...               0.000000
# 54660  Golfshot Plus: Golf GPS  ...               0.791667
# 54661  Golfshot Plus: Golf GPS  ...               1.000000
#
# [40 rows x 5 columns]
# Golfshot: Golf GPS + Tee Times
#                                   App  ... Sentiment_Subjectivity
# 54662  Golfshot: Golf GPS + Tee Times  ...               0.534722
# 54663  Golfshot: Golf GPS + Tee Times  ...               0.557576
# 54664  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54665  Golfshot: Golf GPS + Tee Times  ...               0.750000
# 54666  Golfshot: Golf GPS + Tee Times  ...               0.483333
# 54667  Golfshot: Golf GPS + Tee Times  ...               0.358333
# 54668  Golfshot: Golf GPS + Tee Times  ...               0.268000
# 54669  Golfshot: Golf GPS + Tee Times  ...               0.662963
# 54670  Golfshot: Golf GPS + Tee Times  ...               0.514048
# 54671  Golfshot: Golf GPS + Tee Times  ...               0.646429
# 54672  Golfshot: Golf GPS + Tee Times  ...               0.650000
# 54673  Golfshot: Golf GPS + Tee Times  ...               0.550000
# 54674  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54675  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54676  Golfshot: Golf GPS + Tee Times  ...               0.525000
# 54677  Golfshot: Golf GPS + Tee Times  ...               0.616667
# 54678  Golfshot: Golf GPS + Tee Times  ...               0.300000
# 54679  Golfshot: Golf GPS + Tee Times  ...               0.300000
# 54680  Golfshot: Golf GPS + Tee Times  ...               0.500000
# 54681  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54682  Golfshot: Golf GPS + Tee Times  ...               0.600000
# 54683  Golfshot: Golf GPS + Tee Times  ...               1.000000
# 54684  Golfshot: Golf GPS + Tee Times  ...               0.900000
# 54685  Golfshot: Golf GPS + Tee Times  ...               0.600000
# 54686  Golfshot: Golf GPS + Tee Times  ...               0.600000
# 54687  Golfshot: Golf GPS + Tee Times  ...               0.250000
# 54688  Golfshot: Golf GPS + Tee Times  ...               0.750000
# 54689  Golfshot: Golf GPS + Tee Times  ...               0.367857
# 54690  Golfshot: Golf GPS + Tee Times  ...               0.255556
# 54691  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54692  Golfshot: Golf GPS + Tee Times  ...               0.750000
# 54693  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54694  Golfshot: Golf GPS + Tee Times  ...               0.780000
# 54695  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54696  Golfshot: Golf GPS + Tee Times  ...               0.666667
# 54697  Golfshot: Golf GPS + Tee Times  ...               0.675000
# 54698  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54699  Golfshot: Golf GPS + Tee Times  ...               0.833333
# 54700  Golfshot: Golf GPS + Tee Times  ...               0.750000
# 54701  Golfshot: Golf GPS + Tee Times  ...               0.600000
#
# [40 rows x 5 columns]
# GoodRx Drug Prices and Coupons
#                                   App  ... Sentiment_Subjectivity
# 54742  GoodRx Drug Prices and Coupons  ...               0.628571
# 54743  GoodRx Drug Prices and Coupons  ...                    NaN
# 54744  GoodRx Drug Prices and Coupons  ...               0.533333
# 54745  GoodRx Drug Prices and Coupons  ...               0.309722
# 54746  GoodRx Drug Prices and Coupons  ...               0.497222
# 54747  GoodRx Drug Prices and Coupons  ...               0.566667
# 54748  GoodRx Drug Prices and Coupons  ...               0.520000
# 54749  GoodRx Drug Prices and Coupons  ...               0.200000
# 54750  GoodRx Drug Prices and Coupons  ...               0.600000
# 54751  GoodRx Drug Prices and Coupons  ...               0.000000
# 54752  GoodRx Drug Prices and Coupons  ...               0.710000
# 54753  GoodRx Drug Prices and Coupons  ...               0.838889
# 54754  GoodRx Drug Prices and Coupons  ...               0.750000
# 54755  GoodRx Drug Prices and Coupons  ...               0.700000
# 54756  GoodRx Drug Prices and Coupons  ...               0.450000
# 54758  GoodRx Drug Prices and Coupons  ...               0.412500
# 54759  GoodRx Drug Prices and Coupons  ...               1.000000
# 54760  GoodRx Drug Prices and Coupons  ...               0.900000
# 54761  GoodRx Drug Prices and Coupons  ...               0.442143
# 54762  GoodRx Drug Prices and Coupons  ...               0.000000
# 54763  GoodRx Drug Prices and Coupons  ...               0.000000
# 54764  GoodRx Drug Prices and Coupons  ...               0.750000
# 54765  GoodRx Drug Prices and Coupons  ...               0.000000
# 54766  GoodRx Drug Prices and Coupons  ...               0.600000
# 54767  GoodRx Drug Prices and Coupons  ...               0.408333
# 54769  GoodRx Drug Prices and Coupons  ...               0.000000
# 54770  GoodRx Drug Prices and Coupons  ...               0.900000
# 54771  GoodRx Drug Prices and Coupons  ...               0.000000
# 54772  GoodRx Drug Prices and Coupons  ...               0.600000
# 54773  GoodRx Drug Prices and Coupons  ...               0.583333
# 54774  GoodRx Drug Prices and Coupons  ...               0.450000
# 54775  GoodRx Drug Prices and Coupons  ...               0.680000
# 54776  GoodRx Drug Prices and Coupons  ...               0.833333
# 54777  GoodRx Drug Prices and Coupons  ...               0.750000
# 54778  GoodRx Drug Prices and Coupons  ...               0.000000
# 54779  GoodRx Drug Prices and Coupons  ...               0.000000
# 54780  GoodRx Drug Prices and Coupons  ...               0.000000
# 54781  GoodRx Drug Prices and Coupons  ...               0.000000
#
# [38 rows x 5 columns]
# Google
#           App  ... Sentiment_Subjectivity
# 54782  Google  ...               1.000000
# 54783  Google  ...               0.475000
# 54784  Google  ...               0.568182
# 54785  Google  ...               0.750000
# 54786  Google  ...               0.750000
# 54787  Google  ...               1.000000
# ...
# 63641  Hot Wheels: Race Off  ...               0.525000
# 63642  Hot Wheels: Race Off  ...               0.766667
#
# [21 rows x 5 columns]
# Hot or Not - Find someone right now
#                                        App  ... Sentiment_Subjectivity
# 63696  Hot or Not - Find someone right now  ...                    NaN
#
# [1 rows x 5 columns]
# HotelTonight: Book amazing deals at great hotels
#                                                     App  ... Sentiment_Subjectivity
# 63776  HotelTonight: Book amazing deals at great hotels  ...                    NaN
# 63786  HotelTonight: Book amazing deals at great hotels  ...               0.750000
# 63790  HotelTonight: Book amazing deals at great hotels  ...               0.716667
# 63798  HotelTonight: Book amazing deals at great hotels  ...               0.562500
# 63799  HotelTonight: Book amazing deals at great hotels  ...               0.500000
# ...                                                 ...  ...                    ...
# 63950  HotelTonight: Book amazing deals at great hotels  ...               0.636667
# 63952  HotelTonight: Book amazing deals at great hotels  ...               0.605556
# 63953  HotelTonight: Book amazing deals at great hotels  ...               0.066667
# 63954  HotelTonight: Book amazing deals at great hotels  ...               0.597576
# 63955  HotelTonight: Book amazing deals at great hotels  ...               0.600000
#
# [94 rows x 5 columns]
# Hotels Combined - Cheap deals
#                                  App  ... Sentiment_Subjectivity
# 63956  Hotels Combined - Cheap deals  ...               0.427778
# 63957  Hotels Combined - Cheap deals  ...               0.593333
# 63958  Hotels Combined - Cheap deals  ...               0.750000
# 63959  Hotels Combined - Cheap deals  ...               0.000000
# 63960  Hotels Combined - Cheap deals  ...               0.000000
# 63961  Hotels Combined - Cheap deals  ...               0.000000
# 63962  Hotels Combined - Cheap deals  ...               0.000000
# 63963  Hotels Combined - Cheap deals  ...                    NaN
# 63964  Hotels Combined - Cheap deals  ...               0.600000
# 63965  Hotels Combined - Cheap deals  ...               1.000000
# 63966  Hotels Combined - Cheap deals  ...               0.000000
# 63967  Hotels Combined - Cheap deals  ...               0.000000
# 63968  Hotels Combined - Cheap deals  ...               0.000000
# 63970  Hotels Combined - Cheap deals  ...               1.000000
# 63971  Hotels Combined - Cheap deals  ...               0.833333
# 63972  Hotels Combined - Cheap deals  ...               0.000000
# 63973  Hotels Combined - Cheap deals  ...               0.600000
# 63974  Hotels Combined - Cheap deals  ...               0.000000
# 63975  Hotels Combined - Cheap deals  ...               0.600000
# 63976  Hotels Combined - Cheap deals  ...               0.666667
# 63977  Hotels Combined - Cheap deals  ...               0.400000
# 63978  Hotels Combined - Cheap deals  ...               0.050000
# 63979  Hotels Combined - Cheap deals  ...               0.300000
# 63981  Hotels Combined - Cheap deals  ...               0.500000
# 63982  Hotels Combined - Cheap deals  ...               0.400000
# 63984  Hotels Combined - Cheap deals  ...               0.350000
# 63985  Hotels Combined - Cheap deals  ...               0.375000
# 63986  Hotels Combined - Cheap deals  ...               0.000000
# 63987  Hotels Combined - Cheap deals  ...               1.000000
# 63988  Hotels Combined - Cheap deals  ...               0.200000
# 63989  Hotels Combined - Cheap deals  ...               0.550000
# 63990  Hotels Combined - Cheap deals  ...               0.000000
# 63991  Hotels Combined - Cheap deals  ...               0.000000
# 63992  Hotels Combined - Cheap deals  ...               0.300000
# 63993  Hotels Combined - Cheap deals  ...               0.415476
# 63994  Hotels Combined - Cheap deals  ...               0.000000
# 63995  Hotels Combined - Cheap deals  ...               0.800000
#
# [37 rows x 5 columns]
# Hotels.com: Book Hotel Rooms & Find Vacation Deals
#                                                      App  ... Sentiment_Subjectivity
# 63996  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.566667
# 63997  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.633333
# 63998  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.404167
# 63999  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.646667
# 64000  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.338889
# 64001  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.950000
# 64002  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.806250
# 64003  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.412500
# 64004  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.383333
# 64005  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.800000
# 64006  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.578571
# 64007  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.916667
# 64008  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.100000
# 64009  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.300000
# 64010  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.583333
# 64011  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.562500
# 64012  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.733333
# 64013  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.000000
# 64014  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.716667
# 64015  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.760000
# 64016  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.355556
# 64017  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.427959
# 64018  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.300000
# 64019  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.450000
# 64020  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.666667
# 64021  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.633333
# 64022  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.000000
# 64023  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.833333
# 64024  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.500000
# 64025  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.633333
# 64026  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.691667
# 64027  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.600000
# 64028  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...                    NaN
# 64029  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.675000
# 64030  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.290000
# 64031  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.500000
# 64033  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.670909
# 64034  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.624167
# 64035  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.200000
# 64072  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.250000
#
# [40 rows x 5 columns]
# Hotspot Shield Free VPN Proxy & Wi-Fi Security
#                                                   App  ... Sentiment_Subjectivity
# 64076  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.900000
# 64077  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.475000
# 64078  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64079  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64080  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64081  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64082  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
# 64083  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               1.000000
# 64084  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.800000
# 64085  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64087  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64088  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64089  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               1.000000
# 64090  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.300000
# 64091  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.780000
# 64092  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.750000
# 64093  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               1.000000
# 64094  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64095  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64097  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.500000
# 64098  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64099  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.666667
# 64100  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.200000
# 64101  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.650000
# 64102  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64103  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64106  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64107  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64108  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64109  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64110  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64111  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.750000
# 64112  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
#
# [33 rows x 5 columns]
# Hotstar
#            App  ... Sentiment_Subjectivity
# 64116  Hotstar  ...               0.000000
# 64117  Hotstar  ...               0.300000
# 64118  Hotstar  ...               0.496667
# 64119  Hotstar  ...                    NaN
# 64120  Hotstar  ...               0.650000
# 64121  Hotstar  ...               0.000000
# 64123  Hotstar  ...               0.629167
# 64124  Hotstar  ...               0.100000
# 64125  Hotstar  ...               0.685714
# 64127  Hotstar  ...               0.613333
# 64129  Hotstar  ...               0.250000
# 64130  Hotstar  ...               0.800000
# 64131  Hotstar  ...               0.550000
# 64132  Hotstar  ...               0.400000
# 64133  Hotstar  ...               0.686667
# 64134  Hotstar  ...               0.400000
# 64135  Hotstar  ...               0.675000
# 64136  Hotstar  ...               0.576905
# 64137  Hotstar  ...               0.414935
# 64140  Hotstar  ...               0.490000
# 64141  Hotstar  ...               0.950000
# 64142  Hotstar  ...               1.000000
# 64143  Hotstar  ...               0.644444
# 64144  Hotstar  ...               0.317857
# 64145  Hotstar  ...               0.375000
# 64147  Hotstar  ...               0.506122
# 64148  Hotstar  ...               0.633929
# 64150  Hotstar  ...               0.500000
# 64151  Hotstar  ...               0.366667
# 64152  Hotstar  ...               0.511111
# 64153  Hotstar  ...               0.300000
# 64154  Hotstar  ...               0.500000
# 64155  Hotstar  ...               0.483333
#
# [33 rows x 5 columns]
# Hotwire Hotel & Car Rental App
#                                   App  ... Sentiment_Subjectivity
# 64156  Hotwire Hotel & Car Rental App  ...                    NaN
# 64157  Hotwire Hotel & Car Rental App  ...               0.655556
# 64158  Hotwire Hotel & Car Rental App  ...               0.517262
# 64159  Hotwire Hotel & Car Rental App  ...               0.750000
# 64161  Hotwire Hotel & Car Rental App  ...               0.000000
# 64163  Hotwire Hotel & Car Rental App  ...               0.833333
# 64164  Hotwire Hotel & Car Rental App  ...               0.500000
# 64165  Hotwire Hotel & Car Rental App  ...               0.666667
# 64166  Hotwire Hotel & Car Rental App  ...               0.615000
# 64168  Hotwire Hotel & Car Rental App  ...               0.750000
# 64169  Hotwire Hotel & Car Rental App  ...               0.000000
# 64170  Hotwire Hotel & Car Rental App  ...               0.000000
# 64171  Hotwire Hotel & Car Rental App  ...               0.750000
# 64173  Hotwire Hotel & Car Rental App  ...               0.270833
# 64174  Hotwire Hotel & Car Rental App  ...               0.662500
# 64175  Hotwire Hotel & Car Rental App  ...               0.566667
# 64176  Hotwire Hotel & Car Rental App  ...               0.397619
# 64177  Hotwire Hotel & Car Rental App  ...               0.875000
# 64178  Hotwire Hotel & Car Rental App  ...               0.000000
# 64179  Hotwire Hotel & Car Rental App  ...               0.000000
# 64180  Hotwire Hotel & Car Rental App  ...               0.666667
# 64181  Hotwire Hotel & Car Rental App  ...               0.600000
# 64182  Hotwire Hotel & Car Rental App  ...               0.500000
# 64183  Hotwire Hotel & Car Rental App  ...               0.600000
# 64184  Hotwire Hotel & Car Rental App  ...               0.187500
# 64185  Hotwire Hotel & Car Rental App  ...               0.600000
# 64186  Hotwire Hotel & Car Rental App  ...               0.365000
# 64187  Hotwire Hotel & Car Rental App  ...               0.900000
# 64188  Hotwire Hotel & Car Rental App  ...               0.000000
# 64189  Hotwire Hotel & Car Rental App  ...               0.100000
# 64190  Hotwire Hotel & Car Rental App  ...               0.600000
# 64191  Hotwire Hotel & Car Rental App  ...               0.491071
# 64192  Hotwire Hotel & Car Rental App  ...               0.750000
# 64194  Hotwire Hotel & Car Rental App  ...               0.000000
#
# [34 rows x 5 columns]
# Housing-Real Estate & Property
#                                   App  ... Sentiment_Subjectivity
# 64196  Housing-Real Estate & Property  ...               0.125000
# 64197  Housing-Real Estate & Property  ...               0.625000
# 64198  Housing-Real Estate & Property  ...               0.375000
# 64199  Housing-Real Estate & Property  ...               0.200000
# 64200  Housing-Real Estate & Property  ...               0.000000
# 64201  Housing-Real Estate & Property  ...               0.200000
# 64202  Housing-Real Estate & Property  ...                    NaN
# 64205  Housing-Real Estate & Property  ...               0.000000
# 64207  Housing-Real Estate & Property  ...               0.600000
# 64209  Housing-Real Estate & Property  ...               0.511458
# 64213  Housing-Real Estate & Property  ...               0.418750
# 64215  Housing-Real Estate & Property  ...               0.717262
# 64216  Housing-Real Estate & Property  ...               0.250000
# 64217  Housing-Real Estate & Property  ...               0.550000
# 64218  Housing-Real Estate & Property  ...               0.000000
# 64220  Housing-Real Estate & Property  ...               0.533333
# 64221  Housing-Real Estate & Property  ...               0.259470
# 64222  Housing-Real Estate & Property  ...               0.486667
# 64223  Housing-Real Estate & Property  ...               0.447222
# 64226  Housing-Real Estate & Property  ...               0.250000
# 64227  Housing-Real Estate & Property  ...               1.000000
# 64230  Housing-Real Estate & Property  ...               0.400000
#
# [22 rows x 5 columns]
# Houzz Interior Design Ideas
#                                App  ... Sentiment_Subjectivity
# 64236  Houzz Interior Design Ideas  ...                    NaN
#
# [1 rows x 5 columns]

# %% [markdown]
# **Removing the missing values from the User reviews dataset**.

# %%
new_df_reviews = df_reviews.dropna()
new_df_reviews
# Out:
#                                   App  ... Sentiment_Subjectivity
# 0               10 Best Foods for You  ...               0.533333
# 1               10 Best Foods for You  ...               0.288462
# 3               10 Best Foods for You  ...               0.875000
# 4               10 Best Foods for You  ...               0.300000
# 5               10 Best Foods for You  ...               0.300000
# ...                               ...  ...                    ...
# 64222  Housing-Real Estate & Property  ...               0.486667
# 64223  Housing-Real Estate & Property  ...               0.447222
# 64226  Housing-Real Estate & Property  ...               0.250000
# 64227  Housing-Real Estate & Property  ...               1.000000
# 64230  Housing-Real Estate & Property  ...               0.400000
#
# [29692 rows x 5 columns]

# %%
new_df_reviews.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
new_df_reviews
# Out:
#                                   App  ... Sentiment_Subjectivity
# 0               10 Best Foods for You  ...               0.533333
# 1               10 Best Foods for You  ...               0.288462
# 3               10 Best Foods for You  ...               0.875000
# 4               10 Best Foods for You  ...               0.300000
# 5               10 Best Foods for You  ...               0.300000
# ...                               ...  ...                    ...
# 64222  Housing-Real Estate & Property  ...               0.486667
# 64223  Housing-Real Estate & Property  ...               0.447222
# 64226  Housing-Real Estate & Property  ...               0.250000
# 64227  Housing-Real Estate & Property  ...               1.000000
# 64230  Housing-Real Estate & Property  ...               0.400000
#
# [29692 rows x 5 columns]

# %%
new_df_reviews.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
import missingno as msno
msno.matrix(new_df_reviews)
plt.show()

# %% [markdown]
# **This shows that the missing data in the User Data has been removed successfully.**

# %%
grp = new_df_reviews.groupby('App')
x = grp['Sentiment_Polarity'].agg(np.mean)
y = grp['Sentiment_Subjectivity'].agg(np.mean)
print(x)
print(y)
# Out:
# App
# 10 Best Foods for You                                 0.465906
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      0.358227
# 11st                                                  0.185943
# 1800 Contacts - Lens Store                            0.318145
# 1LINE – One Line with One Touch                       0.196290
#                                                         ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals    0.098559
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        0.223750
# Hotstar                                               0.038178
# Hotwire Hotel & Car Rental App                        0.187029
# Housing-Real Estate & Property                       -0.021427
# Name: Sentiment_Polarity, Length: 865, dtype: float64
# App
# 10 Best Foods for You                                 0.493254
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      0.508907
# 11st                                                  0.455340
# 1800 Contacts - Lens Store                            0.591098
# 1LINE – One Line with One Touch                       0.557315
#                                                         ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals    0.525508
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        0.380365
# Hotstar                                               0.493964
# Hotwire Hotel & Car Rental App                        0.459717
# Housing-Real Estate & Property                        0.378532
# Name: Sentiment_Subjectivity, Length: 865, dtype: float64

# %% [markdown]
# # **Merging dataframes on apps**

# %%
merged_df = df.merge(new_df_reviews, on="App")
merged_df
# Out:
#                                 App  ... Sentiment_Subjectivity
# 0               Coloring book moana  ...               1.000000
# 1               Coloring book moana  ...               0.833333
# 2               Coloring book moana  ...               0.000000
# 3               Coloring book moana  ...               0.600000
# 4               Coloring book moana  ...               0.900000
# ...                             ...  ...                    ...
# 40409  A+ Gallery - Photos & Videos  ...               0.512500
# 40410  A+ Gallery - Photos & Videos  ...               0.733333
# 40411  A+ Gallery - Photos & Videos  ...               0.200000
# 40412  A+ Gallery - Photos & Videos  ...               0.000000
# 40413  A+ Gallery - Photos & Videos  ...               0.450000
#
# [40414 rows x 17 columns]

# %% [markdown]
# **In the merged dataframe, we have three new columns i.e.. Sentiment, Sentiment Polarity and Sentiment Subjectivity. Sentiment basically determines the attitude or the emotion of the writer, i.e., whether it is positive or negative or neutral. Sentiment Polarity is float which lies in the range of [-1,1] where 1 means positive statement and -1 means a negative statement. Sentiment Subjectivity generally refer to personal opinion, emotion or judgment, which lies in the range of [0,1]**

# %% [markdown]
# #**5. Dataset Visualization**
# **Asking questions and aswering them.**
# * **Installs per Category**
# * **Pricing vs Category**
# * **Number of Reviews per Category**
# * **What are the top 20 apps present in the google play store per in the Genres?**
# * **What are the Genre that are getting installed the most in top 20 Genres?**
# * **Count of applications for each Category**
# * **Number of Installed applications for each category**
# * **Distribution of Rating**
# * **Highest and Lowest Genres**
# * **Rating according to Genres**
# * **What are teh count of applications in each category differentiated by their type**
# * **How many apps wqere installed according to their type**
# * **How does size impact on the Number of installs of any applications**
# * **Histogram of log installs**
# * **Histogram of size**
# * **Different Android Version**
# * **Scatter Matrix**
# * **What is the percentage of paid to free apps?**
# * **What is the most dominant category?**
# * **What size should my app have?**
# * **What price should my paid app have?**
# * **What are the number of installs for apps priced more than $100?**
# * **What is the most successful category?**
# * **Distribution of app sizes**
# * **Rating per categories and type**
# * **Distribution of content rating per categories**
# * **Number of Installs type wise according to Genre**
# * **Histogram of Subjectivity**
# * **Does Sentiment_subjectivity propotional to sentiment_polarity**
# * **Wordcloud**
# * **Percentage of Review Sentiments**

# %%
  grp = df1.groupby('Category')
  x = grp['Installs'].agg(np.mean)
  y = grp['Price'].agg(np.sum)
  z = grp['Reviews'].agg(np.mean)
  print(x)
  print(y)
  print(z)
# Out:
# Category
# ART_AND_DESIGN         2.003760e+06
# AUTO_AND_VEHICLES      7.278055e+05
# BEAUTY                 6.408619e+05
# BOOKS_AND_REFERENCE    1.082651e+07
# BUSINESS               3.198215e+06
# COMICS                 9.661397e+05
# COMMUNICATION          7.867180e+07
# DATING                 1.298883e+06
# EDUCATION              4.138388e+06
# ENTERTAINMENT          2.212306e+07
# EVENTS                 3.544313e+05
# FAMILY                 5.844663e+06
# FINANCE                2.430008e+06
# FOOD_AND_DRINK         2.431866e+06
# GAME                   2.937045e+07
# HEALTH_AND_FITNESS     5.194680e+06
# HOUSE_AND_HOME         1.839441e+06
# LIBRARIES_AND_DEMO     9.551231e+05
# LIFESTYLE              1.753250e+06
# MAPS_AND_NAVIGATION    5.840867e+06
# MEDICAL                1.396115e+05
# NEWS_AND_MAGAZINES     2.520145e+07
# PARENTING              6.223222e+05
# PERSONALIZATION        6.691461e+06
# PHOTOGRAPHY            3.197777e+07
# PRODUCTIVITY           3.731458e+07
# SHOPPING               1.273927e+07
# SOCIAL                 5.128624e+07
# SPORTS                 5.344516e+06
# TOOLS                  1.560044e+07
# TRAVEL_AND_LOCAL       3.103346e+07
# VIDEO_PLAYERS          3.888686e+07
# WEATHER                5.681287e+06
# Name: Installs, dtype: float64
# Category
# ART_AND_DESIGN            5.97
# AUTO_AND_VEHICLES         1.99
# BEAUTY                    0.00
# BOOKS_AND_REFERENCE      23.88
# BUSINESS                 64.41
# COMICS                    0.00
# COMMUNICATION            56.69
# DATING                   22.96
# EDUCATION                17.96
# ENTERTAINMENT             7.98
# EVENTS                    0.00
# FAMILY                 2282.78
# FINANCE                2439.87
# FOOD_AND_DRINK            8.48
# GAME                    280.36
# HEALTH_AND_FITNESS       42.39
# HOUSE_AND_HOME            0.00
# LIBRARIES_AND_DEMO        0.00
# LIFESTYLE              1960.88
# MAPS_AND_NAVIGATION      26.95
# MEDICAL                 648.86
# NEWS_AND_MAGAZINES        3.98
# PARENTING                 9.58
# PERSONALIZATION         125.27
# PHOTOGRAPHY              76.26
# PRODUCTIVITY             70.92
# SHOPPING                  5.48
# SOCIAL                    1.98
# SPORTS                   93.21
# TOOLS                   207.90
# TRAVEL_AND_LOCAL         37.49
# VIDEO_PLAYERS            10.46
# WEATHER                  29.43
# Name: Price, dtype: float64
# Category
# ART_AND_DESIGN         2.765116e+04
# AUTO_AND_VEHICLES      1.594014e+04
# BEAUTY                 9.407929e+03
# BOOKS_AND_REFERENCE    1.235752e+05
# BUSINESS               4.576928e+04
# COMICS                 5.830940e+04
# COMMUNICATION          1.958544e+06
# DATING                 3.487525e+04
# EDUCATION              1.795715e+05
# ENTERTAINMENT          4.285650e+05
# EVENTS                 3.568667e+03
# FAMILY                 2.309480e+05
# FINANCE                5.362640e+04
# FOOD_AND_DRINK         7.237033e+04
# GAME                   1.318002e+06
# HEALTH_AND_FITNESS     1.177293e+05
# HOUSE_AND_HOME         4.109399e+04
# LIBRARIES_AND_DEMO     1.590054e+04
# LIFESTYLE              4.203134e+04
# MAPS_AND_NAVIGATION    2.472505e+05
# MEDICAL                4.623930e+03
# NEWS_AND_MAGAZINES     1.787145e+05
# PARENTING              1.907218e+04
# PERSONALIZATION        2.425575e+05
# PHOTOGRAPHY            6.720308e+05
# PRODUCTIVITY           3.070486e+05
# SHOPPING               4.699553e+05
# SOCIAL                 2.186789e+06
# SPORTS                 2.283990e+05
# TOOLS                  3.721855e+05
# TRAVEL_AND_LOCAL       2.710488e+05
# VIDEO_PLAYERS          6.898731e+05
# WEATHER                1.947293e+05
# Name: Reviews, dtype: float64

# %% [markdown]
# ## **Number of Installs per Category**

# %%
plt.figure(figsize=(20,10))
plt.plot(x, 'ro', color='b')
plt.xticks(rotation = 90)
plt.title('Number of Installs per Category')
plt.xlabel('Categories ------->')
plt.ylabel('Installs ------>');

# %% [markdown]
# ### **Pricing per Category**

# %%
plt.figure(figsize = (20,10))
plt.plot(y, 'r--', color = 'r')
plt.xticks(rotation = 90)
plt.title('Pricing per Category')
plt.xlabel('Catgories ------>')
plt.ylabel('Prices ----->');

# %% [markdown]
# ### **Number of Reviews per Category**

# %%
plt.figure(figsize = (20,10))
plt.plot(z, 'g^', color = 'g')
plt.xticks(rotation = 90)
plt.title('Category vs Reviews')
plt.xlabel('Catgories ------>')
plt.ylabel('Reviews ----->');

# %% [markdown]
# ### **What are the top 20 apps present in the google play store as per their Genres?**

# %%
top_genres = df1.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
genres_installs = df1.groupby(['Genres'])[['Installs']].sum()
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.head(20)

plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Which are the Genres that are getting installed the most in top 20 Genres?**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Installs")
plt.title("Installs according to Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Installs)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **As we can see from the above two plots: Maxinum number of apps present in google play store comes under Tools, Entertainment and Education Genres but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Communication, Tools and Productivity Genres.**

# %% [markdown]
# ### **Count of applications for each Category**

# %%
top_category = df1.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})
category_installs = df1.groupby(['Category'])[['Installs']].sum()
top_category_installs = pd.merge(top_category, category_installs, on='Category')
top_20_category_installs = top_category_installs

plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of application")
plt.title("Count of applications for each Category")
sns.barplot(top_20_category_installs.Category, top_20_category_installs.Count)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Number of installed applications for each Category**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installed applications for each Category")
sns.barplot(top_20_category_installs.Category, top_20_category_installs.Installs)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Average rating**

# %%
df1.dropna()
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10834                                      FR Calculator  ...          4.1 and up
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [8892 rows x 13 columns]

# %%
genres_ratings_df = df1.groupby(['Genres'])[['Rating']].mean()
genres_installs_ratings = pd.merge(top_genres_installs, genres_ratings_df, on='Genres')
genres_installs_ratings['Rating'].describe()
# Out:
# count    115.000000
# mean       4.258865
# std        0.182193
# min        3.800000
# 25%        4.148914
# 50%        4.266667
# 75%        4.354464
# max        4.800000
# Name: Rating, dtype: float64

# %% [markdown]
# ### **Distribution of Rating**

# %%
plt.figure(figsize=(14,7))
g = sns.kdeplot(genres_installs_ratings.Rating, color="Green", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
plt.show()

# %% [markdown]
# ### **Highest and lowest rated Genres**

# %%
genres_installs_ratings.sort_values('Rating', ascending =False, inplace=True)

highest_rated_genres = genres_installs_ratings.iloc[0:20]
lowest_rated_genres = genres_installs_ratings.iloc[-20:]
lowest_rated_genres = lowest_rated_genres[lowest_rated_genres['Rating'].notnull()]

plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Rating")
plt.title("Ratings according to Genres")
sns.barplot(highest_rated_genres.Genres, highest_rated_genres.Rating)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Ratings according to Genres**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Rating")
plt.title("Ratings according to Genres")
sns.barplot(lowest_rated_genres.Genres, lowest_rated_genres.Rating)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **What are the count of applications in each category differentiated by their type?**

# %%
app_count = df1.groupby(['Category','Type'])[['App']].count().reset_index().rename(columns={'App':'Count','index':'App'})
df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()


df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9))
plt.xlabel("Category", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Count of applications in each category differentiated by their type")
plt.show()

# %% [markdown]
# **It looks like certain app categories have more free apps available for download than others. In our dataset, the majority of apps in Family, Food & Drink and Tools, as well as Social categories were free to install. At the same time Family, Sports, Tools and Medical categories had the biggest number of paid apps available for download.**

# %% [markdown]
# ### **How many apps were installed according to its type?**

# %%
df['log_installs'] = np.log2(df1['Installs'])
df['Gaming Category App'] = df1['Category']=='GAME'
categoty_type_installs = df1.groupby(['Category','Type'])[['Installs']].sum().reset_index()
categoty_type_installs['log_Installs'] = np.log2(categoty_type_installs['Installs'])

plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Category")
sns.barplot('Category', 'log_Installs', hue='Type', data=categoty_type_installs);
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **It can be concludd that the number of free applications installed by the user are high when compared with the paid ones.**

# %% [markdown]
# **Size of the applications present in the datset are in MB and KB. Therefore for ease in data processing, converting entire size column to MB.**

# %%
# Converting KB to MB 
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(x))

# %% [markdown]
# ### **How does size impact on the number of installs of any application?**

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(df['Size'], df['log_installs'], hue=df['Type'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## **Histogram of log installs**

# %%
df.loc[df['log_installs']== df['log_installs'].min(),'log_installs']=0


plt.xlabel("Log of Installs")
plt.title("Distribution of Logrithm of Installs")
plt.hist(df['log_installs']);

# %% [markdown]
# ### **Histogram of size**

# %%
# to remove null values from size column
df1.loc[df1['Size'].isnull(),'Size']=0

plt.xlabel("Size")
plt.title("Distribution of Size")
plt.hist(df['Size']);
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# ## ** Different Android version**

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
import plotly.graph_objects as go
labels = df1['Android Ver'].unique()
values=[]
for each in labels:
    values.append(len(df1[df1['Android Ver']==each]))

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3, title="Android Version")])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9a06184c-0f8d-45f0-b8b1-5fe6a5cc9128" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a06184c-0f8d-45f0-b8b1-5fe6a5cc9128")) {                    Plotly.newPlot(                        "9a06184c-0f8d-45f0-b8b1-5fe6a5cc9128",                        [{"hole":0.3,"labels":["4.0.3 and up","4.2 and up","4.4 and up","2.3 and up","3.0 and up","4.1 and up","4.0 and up","2.3.3 and up","Varies with device","2.2 and up","5.0 and up","6.0 and up","1.6 and up","1.5 and up","2.1 and up","7.0 and up","4.3 and up","4.0.3 - 7.1.1","2.0 and up","3.2 and up","4.4W and up","5.1 and up","7.1 and up","7.0 - 7.1.1","8.0 and up","5.0 - 8.0","3.1 and up","2.0.1 and up","4.1 - 7.1.1","5.0 - 6.0","1.0 and up"],"title":{"text":"Android Version"},"values":[1197,331,789,573,207,1989,1094,238,1178,203,481,46,87,16,112,41,199,2,27,31,5,16,3,1,5,2,8,7,1,1,2],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"t ...

# %% [markdown]
# ## **Scatter Plot**

# %%
sns.pairplot(df1[["Size", "Reviews", "Installs", "Rating", "Type"]], hue="Type", palette="GnBu")

# %% [markdown]
# **This matches our assumption that size greatly affects other features. The Scatter Matrix shows that when the app size is relatively small, other features prosper. This shows that cosumer behaviour on the play store is greatly affected by the app download size**.
#
# **Takeaway: Developers should optimize their app download size as much as possible**

# %% [markdown]
# ###**What is the percentage of paid to free apps?**

# %%
plt.rcParams['figure.figsize']=(14,7)
size = df1["Type"].value_counts()
labels = df1["Type"].unique()
colors=["#43a6cc", "#bae4bf"]

plt.pie(size, labels=labels, colors=colors, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## **What size should my app have?**

# %%
plt.rcParams['figure.figsize']=(20,15)
medians = df.groupby(['Category'])['Size'].median().values
median_labels = [str(np.round(s, 2)) for s in medians]
ax = sns.boxplot(x="Size", y="Category", data=df, palette="GnBu")
ax = sns.boxplot()
df["Size"].mean()
# Out:
# 21.28778830257038

# %% [markdown]
# **The trend is games have a much larger download size than any other category. If you're developing anything other than a game, you need to optimize your downlaod size. on Average any app should have a size of 17.8 MB.**

# %% [markdown]
# ### **What is the most dominant category?**

# %%
categories = df1["Category"].value_counts()
sns.barplot(x=categories.values, y=categories.index, palette="GnBu")

# %% [markdown]
# **This is an interesting finding, our first assumption for the most dominant category was family.**

# %% [markdown]
# ###**What price should my paid app have?**

# %%
paid_apps = df1[df1["Type"] == "Paid"]
sns.boxplot(x="Price", y="Category", data=paid_apps, palette="GnBu")
df1["Price"].mean()
# Out:
# 0.9631545209176688

# %% [markdown]
# **Finance and lifestyle are valued the most but it's intresting to find that there are apps with values of more than $100.**
#
# **On average an app price is $1 **

# %% [markdown]
# ### **What are the number of installs for apps priced more than $100?**

# %%
plt.rcParams['figure.figsize']=(10,5)
expensive_apps = df1[df1["Price"] > 100]
sns.lineplot(x="Price", y="Installs", data=expensive_apps, palette="GnBu")

# %% [markdown]
# ### **What is the most successful category?**

# %%
plt.rcParams['figure.figsize']=(10,10)
plot = sns.barplot(x="Installs", y="Category", data=df1, palette="GnBu")

# %% [markdown]
# **Most successful category based on the number of installs is the communication category.**

# %% [markdown]
# ### **Distribution of app sizes**

# %%
plt.rcParams['figure.figsize']=(10,5)
sns.distplot(df["Size"], color="blue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### **Rating per categories and type**

# %%
plt.rcParams['figure.figsize']=(10,17)
sns.violinplot(x="Rating", y="Category", hue="Type", data=df1, split=True, palette="GnBu")

# %% [markdown]
# ### **Distribution of content rating per categories**
#
# ---

# %%
plt.rcParams['figure.figsize']=(10,15)
content_category = df1[["Content Rating", "Category"]].groupby(["Content Rating", "Category"]).size().reset_index(name='counts')
sns.barplot(x="counts" , y="Category", hue="Content Rating",data=content_category, palette="GnBu")

# %% [markdown]
# ### **Number of installs type wise according to Genres**

# %%
category_sentiment = merged_df.groupby(['Category','Sentiment']).size().reset_index(name='Sentiment Count')
category_sentiment['log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])

plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Genres")
sns.barplot('Category', 'log_sentiment_count', hue='Sentiment', data=category_sentiment);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### **Histogram of subjectivity**

# %%
plt.figure(figsize=(14,7))
plt.xlabel("Subjectivity")
plt.title("Distribution of Subjectivity")
plt.hist(merged_df[merged_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'])
plt.show()

# %% [markdown]
# **It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that macimum number of users give reviews to the applications, according to their experience.**

# %% [markdown]
# ### **Does sentiment_subjectivity proportional to sentiment_polarity?**

# %%
sentimet_subjectivity_polarity = merged_df.groupby(['Category'])['Sentiment_Polarity','Sentiment_Subjectivity'].mean().reset_index().rename(columns={'Sentiment_Polarity':'Sentiment_polarity_avg','Sentiment_Subjectivity':'sentiment_subjectivity_avg'})
merged_df['Sentiment_Subjectivity'] = merged_df['Sentiment_Subjectivity'].abs()
merged_df['Sentiment_Polarity'] = merged_df['Sentiment_Polarity'].abs()

plt.figure(figsize=(14,7))
sns.scatterplot(merged_df['Sentiment_Subjectivity'], merged_df['Sentiment_Polarity'])
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# **From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low**

# %% [markdown]
# ### **Wordcloud**

# %%
review_notnull = merged_df[merged_df['Translated_Review'].notnull()]

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = review_notnull.Translated_Review.values
wordcloud = WordCloud(
    width = 3920,
    height = 2080,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text).lower())
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### **Percentage of Review Sentimets**

# %%
import matplotlib
counts = list(merged_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (8, 8)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentimets', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()
