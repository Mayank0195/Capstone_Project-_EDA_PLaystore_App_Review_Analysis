# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/Capstone_Project-_EDA_PLaystore_App_Review_Analysis/blob/main/Capstone_Project__EDA_PLaystore_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.
# #Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
# #Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ###Android Play Store Dataset Cleaning
# ####Overview and Motivation
# This EDA project aims to discover patterns that lead to a successfull application on the Google Play Store. This will be done by analyzing the historical data collected from the Google Play Store as according to dataset source.
#
# Dataset columns description
# * App: Application name
# * Category: Category the app belongs to
# * Rating: Overall user rating of the app (as when scraped)
# * Reviews: Number of user reviews for the app (as when scraped)
# * Size: Size of the app (as when scraped)
# * Installs: Number of user downloads/installs for the app (as when scraped)
# * Type: Paid or Free
# *Price: Price of the app (as when scraped)
# *Content: Rating Age group the app is targeted at - Children / Mature 21+ / Adult
# * Genres: An app can belong to multiple genres (apart from its main category). For eg, a musical family game will belong to Music, Game, Family genres.
# * Last Updated: Date when the app was last updated on Play Store (as when scraped)
# * Current Ver: Current version of the app available on Play Store (as when scraped)
# * Android Ver: Min required Android version (as when scraped)

# %%
# importing required file required for the EDA 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #**1. Dataset Reading**

# %%
# importing drive on the volab notebook for the easy access of the data provided 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing the pathway for the Playstore Data
route1='/content/drive/MyDrive/AlmaBetter/Capstone_Project_EDA/Play_Store_Data.csv'
df=pd.read_csv(route1)
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10841 rows x 13 columns]

# %%
#importing the pathway for the User reviews data
route2='/content/drive/MyDrive/AlmaBetter/Capstone_Project_EDA/User_Reviews.csv'
df_reviews=pd.read_csv(route2)
df_reviews
# Out:
#                                App  ... Sentiment_Subjectivity
# 0            10 Best Foods for You  ...               0.533333
# 1            10 Best Foods for You  ...               0.288462
# 2            10 Best Foods for You  ...                    NaN
# 3            10 Best Foods for You  ...               0.875000
# 4            10 Best Foods for You  ...               0.300000
# ...                            ...  ...                    ...
# 64290  Houzz Interior Design Ideas  ...                    NaN
# 64291  Houzz Interior Design Ideas  ...                    NaN
# 64292  Houzz Interior Design Ideas  ...                    NaN
# 64293  Houzz Interior Design Ideas  ...                    NaN
# 64294  Houzz Interior Design Ideas  ...                    NaN
#
# [64295 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Checking the Head and Tail of the Playstore data**

# %%
df.head(10)
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
# 5                         Paper flowers instructions  ...    2.3 and up
# 6            Smoke Effect Photo Maker - Smoke Editor  ...  4.0.3 and up
# 7                                   Infinite Painter  ...    4.2 and up
# 8                               Garden Coloring Book  ...    3.0 and up
# 9                      Kids Paint Free - Drawing Fun  ...  4.0.3 and up
#
# [10 rows x 13 columns]

# %%
df.tail(10)
# Out:
#                                                  App  ...         Android Ver
# 10831                       payermonstationnement.fr  ...          4.0 and up
# 10832                                       FR Tides  ...          2.1 and up
# 10833                                    Chemin (fr)  ...          2.2 and up
# 10834                                  FR Calculator  ...          4.1 and up
# 10835                                       FR Forms  ...          4.0 and up
# 10836                               Sya9a Maroc - FR  ...          4.1 and up
# 10837               Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                         Parkinson Exercices FR  ...          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10 rows x 13 columns]

# %% [markdown]
# **Checking he head and taill if the user review Data**

# %%
df_reviews.head(10)
# Out:
#                      App  ... Sentiment_Subjectivity
# 0  10 Best Foods for You  ...               0.533333
# 1  10 Best Foods for You  ...               0.288462
# 2  10 Best Foods for You  ...                    NaN
# 3  10 Best Foods for You  ...               0.875000
# 4  10 Best Foods for You  ...               0.300000
# 5  10 Best Foods for You  ...               0.300000
# 6  10 Best Foods for You  ...               0.900000
# 7  10 Best Foods for You  ...                    NaN
# 8  10 Best Foods for You  ...               0.000000
# 9  10 Best Foods for You  ...               0.000000
#
# [10 rows x 5 columns]

# %%
df_reviews.tail(10)
# Out:
#                                App  ... Sentiment_Subjectivity
# 64285  Houzz Interior Design Ideas  ...                    NaN
# 64286  Houzz Interior Design Ideas  ...                    NaN
# 64287  Houzz Interior Design Ideas  ...                    NaN
# 64288  Houzz Interior Design Ideas  ...                    NaN
# 64289  Houzz Interior Design Ideas  ...                    NaN
# 64290  Houzz Interior Design Ideas  ...                    NaN
# 64291  Houzz Interior Design Ideas  ...                    NaN
# 64292  Houzz Interior Design Ideas  ...                    NaN
# 64293  Houzz Interior Design Ideas  ...                    NaN
# 64294  Houzz Interior Design Ideas  ...                    NaN
#
# [10 rows x 5 columns]

# %% [markdown]
# #**2. Dataset Discovery**
# **dicovering the dataset and get a notion of what the attributes describe**.

# %%
df.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
df_reviews.count()
# Out:
# App                       64295
# Translated_Review         37427
# Sentiment                 37432
# Sentiment_Polarity        37432
# Sentiment_Subjectivity    37432
# dtype: int64

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df_reviews.shape
# Out:
# (64295, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df.boxplot();

# %%
df_reviews.boxplot();

# %%
df.hist();

# %%
df_reviews.hist();

# %%
import missingno as msno
msno.matrix(df)
plt.show()

# %% [markdown]
# **This shows that the data has many missing values under the column Rating, Content Rating and Android Version.**

# %%
import missingno as msno
msno.matrix(df_reviews)
plt.show()

# %% [markdown]
# **This also shows that even the User Reviews csv is also full of missing data.**

# %% [markdown]
# #**3**.**DATA CLEANING**

# %% [markdown]
# **Checking the missing values in the Playstore data**

# %%
df.isnull()
# Out:
#          App  Category  Rating  ...  Last Updated  Current Ver  Android Ver
# 0      False     False   False  ...         False        False        False
# 1      False     False   False  ...         False        False        False
# 2      False     False   False  ...         False        False        False
# 3      False     False   False  ...         False        False        False
# 4      False     False   False  ...         False        False        False
# ...      ...       ...     ...  ...           ...          ...          ...
# 10836  False     False   False  ...         False        False        False
# 10837  False     False   False  ...         False        False        False
# 10838  False     False    True  ...         False        False        False
# 10839  False     False   False  ...         False        False        False
# 10840  False     False   False  ...         False        False        False
#
# [10841 rows x 13 columns]

# %% [markdown]
# **Countiing the number of missing values in the Playstore Data.**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df_reviews.isnull()
# Out:
#          App  Translated_Review  ...  Sentiment_Polarity  Sentiment_Subjectivity
# 0      False              False  ...               False                   False
# 1      False              False  ...               False                   False
# 2      False               True  ...                True                    True
# 3      False              False  ...               False                   False
# 4      False              False  ...               False                   False
# ...      ...                ...  ...                 ...                     ...
# 64290  False               True  ...                True                    True
# 64291  False               True  ...                True                    True
# 64292  False               True  ...                True                    True
# 64293  False               True  ...                True                    True
# 64294  False               True  ...                True                    True
#
# [64295 rows x 5 columns]

# %% [markdown]
# **Checking the missing values in the User reviews data**

# %%
df_reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# ##**3.1 Outliers**
# An outlier is an object that deviates significantly from the rest of the objects. They can be caused by measurement or execution errors.

# %%
df.boxplot();
df.hist();

# %%
df[df.Rating>5]
# Out:
#                                            App Category  ...  Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9  ...   4.0 and up         NaN
#
# [1 rows x 13 columns]

# %%
df.drop([10472], inplace = True)

# %%
df[10470:10474]
# Out:
#                            App         Category  ...  Current Ver   Android Ver
# 10470               Jazz Wi-Fi    COMMUNICATION  ...          0.1    2.3 and up
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION  ...        3.0.0  4.0.3 and up
# 10473  osmino Wi-Fi: free WiFi            TOOLS  ...      6.06.14    4.4 and up
# 10474             Sat-Fi Voice    COMMUNICATION  ...      2.2.1.5    2.2 and up
#
# [4 rows x 13 columns]

# %%
df.boxplot()

# %% [markdown]
# ###**3.2 Remove columns that are 90% empty**

# %%
len(df)
# Out:
# 10840

# %%
threshold = len(df) * 0.1
threshold
# Out:
# 1084.0

# %%
df.dropna(thresh = threshold, axis = 1, inplace = True)

# %%
print(df.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
boolean = df['App'].duplicated().any()
boolean
# Out:
# True

# %%
df['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9659, dtype: int64

# %%
df[df['App'] == 'ROBLOX']
# Out:
#          App Category  Rating  ...   Last Updated   Current Ver Android Ver
# 1653  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1701  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1748  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1841  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 1870  ROBLOX     GAME     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 2016  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 2088  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 2206  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
# 4527  ROBLOX   FAMILY     4.5  ...  July 31, 2018  2.347.225742  4.1 and up
#
# [9 rows x 13 columns]

# %% [markdown]
# ###**3.3 Checking for duplicate values**

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10357 rows x 13 columns]

# %% [markdown]
# #**4.DATA MANIPULATION**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
def impute_medium(series):
  return series.fillna(series.median)

# %%
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10357 rows x 13 columns]

# %%
print(df['Type'].mode())
print(df['Current Ver'].mode())
print(df['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
# 0    Varies with device
# dtype: object
# 0    4.1 and up
# dtype: object

# %% [markdown]
# **Filling the Missing values with mode values of Type, Current ver and Android ver so that the values can be filled and the data looks more presentable.**

# %%
df['Type'].fillna(str(df['Type'].mode().values[0]),inplace=True)
df['Current Ver'].fillna(str(df['Current Ver'].mode().values[0]),inplace=True)
df['Android Ver'].fillna(str(df['Android Ver'].mode().values[0]),inplace=True)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %% [markdown]
# **Removing a $ sign from the Price as it was creating a hindarnce while doing the analysis of the data.**

# %%
df['Price'] = df['Price'].apply((lambda x: str(x).replace('$','')if '$' in str(x) else str(x)))
df['Price'] = df['Price'].apply((lambda x: float(x)))
df['Reviews'] = pd.to_numeric(df['Reviews'], errors ='coerce')

# %% [markdown]
# **Removing a + sign from the Installs as it was creating a hindarnce while doing the analysis of the data.**

# %%
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x)) 
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price
# count  8892.000000  1.035700e+04  1.035700e+04  10357.000000
# mean      4.187877  4.059046e+05  1.415776e+07      1.030800
# std       0.522377  2.696778e+06  8.023955e+07     16.278625
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.200000e+01  1.000000e+03      0.000000
# 50%       4.300000  1.680000e+03  1.000000e+05      0.000000
# 75%       4.500000  4.641600e+04  1.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# **Checking how many Apps are free for the user and how many are paid.**

# %%
df[df.Price>0].count()
# Out:
# App               765
# Category          765
# Rating            613
# Reviews           765
# Size              765
# Installs          765
# Type              765
# Price             765
# Content Rating    765
# Genres            765
# Last Updated      765
# Current Ver       765
# Android Ver       765
# dtype: int64

# %%
df
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [10357 rows x 13 columns]

# %% [markdown]
# **Remove missing values.**

# %%
df1 = df.dropna()
df1
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10834                                      FR Calculator  ...          4.1 and up
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [8892 rows x 13 columns]

# %% [markdown]
# **Removing the missing values as to make the data more presentable and suitable for analysis.**

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df1)
plt.show()

# %% [markdown]
# **Showing that there is no missing value left in the data and that it is more presentable and suitable for analysis.**

# %%
g = df_reviews.groupby('App')
g

# %%
for App ,App_df_reviews in g:
    print(App)
    print(App_df_reviews),
# Out:
# Streaming output truncated to the last 5000 lines.
# 54629  Golfshot Plus: Golf GPS  ...               0.750000
# 54630  Golfshot Plus: Golf GPS  ...               1.000000
# 54631  Golfshot Plus: Golf GPS  ...               0.000000
# 54632  Golfshot Plus: Golf GPS  ...               0.650000
# 54633  Golfshot Plus: Golf GPS  ...               0.727273
# 54634  Golfshot Plus: Golf GPS  ...               0.300000
# 54635  Golfshot Plus: Golf GPS  ...               0.000000
# 54636  Golfshot Plus: Golf GPS  ...               0.420833
# 54637  Golfshot Plus: Golf GPS  ...               0.500000
# 54638  Golfshot Plus: Golf GPS  ...               0.585000
# 54639  Golfshot Plus: Golf GPS  ...               0.442857
# 54640  Golfshot Plus: Golf GPS  ...               0.590000
# 54641  Golfshot Plus: Golf GPS  ...               0.727778
# 54642  Golfshot Plus: Golf GPS  ...               0.000000
# 54643  Golfshot Plus: Golf GPS  ...               0.300000
# 54644  Golfshot Plus: Golf GPS  ...               0.600000
# 54645  Golfshot Plus: Golf GPS  ...               0.625000
# 54646  Golfshot Plus: Golf GPS  ...               0.000000
# 54647  Golfshot Plus: Golf GPS  ...               0.750000
# 54648  Golfshot Plus: Golf GPS  ...               0.400000
# 54649  Golfshot Plus: Golf GPS  ...               0.458333
# 54650  Golfshot Plus: Golf GPS  ...               0.460000
# 54651  Golfshot Plus: Golf GPS  ...               0.466667
# 54652  Golfshot Plus: Golf GPS  ...               0.500000
# 54653  Golfshot Plus: Golf GPS  ...               0.675000
# 54654  Golfshot Plus: Golf GPS  ...               0.600000
# 54655  Golfshot Plus: Golf GPS  ...               0.558333
# 54656  Golfshot Plus: Golf GPS  ...               0.250000
# 54657  Golfshot Plus: Golf GPS  ...               0.422619
# 54658  Golfshot Plus: Golf GPS  ...               0.468333
# 54659  Golfshot Plus: Golf GPS  ...               0.000000
# 54660  Golfshot Plus: Golf GPS  ...               0.791667
# 54661  Golfshot Plus: Golf GPS  ...               1.000000
#
# [40 rows x 5 columns]
# Golfshot: Golf GPS + Tee Times
#                                   App  ... Sentiment_Subjectivity
# 54662  Golfshot: Golf GPS + Tee Times  ...               0.534722
# 54663  Golfshot: Golf GPS + Tee Times  ...               0.557576
# 54664  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54665  Golfshot: Golf GPS + Tee Times  ...               0.750000
# 54666  Golfshot: Golf GPS + Tee Times  ...               0.483333
# ...                               ...  ...                    ...
# 54737  Golfshot: Golf GPS + Tee Times  ...               0.675000
# 54738  Golfshot: Golf GPS + Tee Times  ...               0.000000
# 54739  Golfshot: Golf GPS + Tee Times  ...               0.750000
# 54740  Golfshot: Golf GPS + Tee Times  ...               0.833333
# 54741  Golfshot: Golf GPS + Tee Times  ...               0.600000
#
# [80 rows x 5 columns]
# GoodRx Drug Prices and Coupons
#                                   App  ... Sentiment_Subjectivity
# 54742  GoodRx Drug Prices and Coupons  ...               0.628571
# 54743  GoodRx Drug Prices and Coupons  ...                    NaN
# 54744  GoodRx Drug Prices and Coupons  ...               0.533333
# 54745  GoodRx Drug Prices and Coupons  ...               0.309722
# 54746  GoodRx Drug Prices and Coupons  ...               0.497222
# 54747  GoodRx Drug Prices and Coupons  ...               0.566667
# 54748  GoodRx Drug Prices and Coupons  ...               0.520000
# 54749  GoodRx Drug Prices and Coupons  ...               0.200000
# 54750  GoodRx Drug Prices and Coupons  ...               0.600000
# 54751  GoodRx Drug Prices and Coupons  ...               0.000000
# 54752  GoodRx Drug Prices and Coupons  ...               0.710000
# 54753  GoodRx Drug Prices and Coupons  ...               0.838889
# 54754  GoodRx Drug Prices and Coupons  ...               0.750000
# 54755  GoodRx Drug Prices and Coupons  ...               0.700000
# 54756  GoodRx Drug Prices and Coupons  ...               0.450000
# 54757  GoodRx Drug Prices and Coupons  ...                    NaN
# 54758  GoodRx Drug Prices and Coupons  ...               0.412500
# 54759  GoodRx Drug Prices and Coupons  ...               1.000000
# 54760  GoodRx Drug Prices and Coupons  ...               0.900000
# 54761  GoodRx Drug Prices and Coupons  ...               0.442143
# 54762  GoodRx Drug Prices and Coupons  ...               0.000000
# 54763  GoodRx Drug Prices and Coupons  ...               0.000000
# 54764  GoodRx Drug Prices and Coupons  ...               0.750000
# 54765  GoodRx Drug Prices and Coupons  ...               0.000000
# 54766  GoodRx Drug Prices and Coupons  ...               0.600000
# 54767  GoodRx Drug Prices and Coupons  ...               0.408333
# 54768  GoodRx Drug Prices and Coupons  ...                    NaN
# 54769  GoodRx Drug Prices and Coupons  ...               0.000000
# 54770  GoodRx Drug Prices and Coupons  ...               0.900000
# 54771  GoodRx Drug Prices and Coupons  ...               0.000000
# 54772  GoodRx Drug Prices and Coupons  ...               0.600000
# 54773  GoodRx Drug Prices and Coupons  ...               0.583333
# 54774  GoodRx Drug Prices and Coupons  ...               0.450000
# 54775  GoodRx Drug Prices and Coupons  ...               0.680000
# 54776  GoodRx Drug Prices and Coupons  ...               0.833333
# 54777  GoodRx Drug Prices and Coupons  ...               0.750000
# 54778  GoodRx Drug Prices and Coupons  ...               0.000000
# 54779  GoodRx Drug Prices and Coupons  ...               0.000000
# 54780  GoodRx Drug Prices and Coupons  ...               0.000000
# 54781  GoodRx Drug Prices and Coupons  ...               0.000000
#
# [40 rows x 5 columns]
# Google
#           App  ... Sentiment_Subjectivity
# 54782  Google  ...               1.000000
# 54783  Google  ...               0.475000
# 54784  Google  ...               0.568182
# 54785  Google  ...               0.750000
# 54786  Google  ...               0.750000
# 54787  Google  ...               1.000000
# 54788  Google  ...               0.700000
# 54789  Google  ...               0.800000
# 54790  Google  ...               0.477273
# 54791  Google  ...               0.283333
# 54792  Google  ...               0.500000
# 54793  Google  ...               0.500000
# 54794  Google  ...               0.000000
# 54795  Google  ...               1.000000
# 54796  Google  ...               0.000000
# 54797  Google  ...               0.900000
# 54798  Google  ...                    NaN
# 54799  Google  ...               1.000000
# 54800  Google  ...               0.000000
# 54801  Google  ...               0.000000
# 54802  Google  ...               0.000000
# 54803  Google  ...               0.200000
# 54804  Google  ...               0.000000
# 54805  Google  ...                    NaN
# 54806  Google  ...               0.000000
# 54807  Google  ...               0.300000
# 54808  Google  ...               1.000000
# 54809  Google  ...               0.741667
# 54810  Google  ...               0.425000
# 54811  Google  ...               0.456250
# 54812  Google  ...               0.538889
# 54813  Google  ...               0.492708
# 54814  Google  ...               0.250000
# 54815  Google  ...               0.463636
# 54816  Google  ...               0.708333
# 54817  Google  ...               0.250000
# 54818  Google  ...               0.283929
# 54819  Google  ...               1.000000
# 54820  Google  ...               0.477778
# 54821  Google  ...               0.432292
#
# [40 rows x 5 columns]
# Google Ads
#               App  ... Sentiment_Subjectivity
# 54822  Google Ads  ...               0.522222
# 54823  Google Ads  ...               0.000000
# 54824  Google Ads  ...               0.600000
# 54825  Google Ads  ...               1.000000
# 54826  Google Ads  ...               1.000000
# ...           ...  ...                    ...
# 54897  Google Ads  ...                    NaN
# 54898  Google Ads  ...                    NaN
# 54899  Google Ads  ...                    NaN
# 54900  Google Ads  ...                    NaN
# 54901  Google Ads  ...                    NaN
#
# [80 rows x 5 columns]
# Google Allo
#                App  ... Sentiment_Subjectivity
# 54902  Google Allo  ...                    NaN
# 54903  Google Allo  ...                    NaN
# 54904  Google Allo  ...                    NaN
# 54905  Google Allo  ...                    NaN
# 54906  Google Allo  ...                    NaN
# ...            ...  ...                    ...
# 54977  Google Allo  ...                    NaN
# 54978  Google Allo  ...                    NaN
# 54979  Google Allo  ...                    NaN
# 54980  Google Allo  ...                    NaN
# 54981  Google Allo  ...                    NaN
#
# [80 rows x 5 columns]
# Google Analytics
#                     App  ... Sentiment_Subjectivity
# 54982  Google Analytics  ...                    NaN
# 54983  Google Analytics  ...                    NaN
# 54984  Google Analytics  ...                    NaN
# 54985  Google Analytics  ...                    NaN
# 54986  Google Analytics  ...                    NaN
# ...                 ...  ...                    ...
# 55057  Google Analytics  ...                    NaN
# 55058  Google Analytics  ...                    NaN
# 55059  Google Analytics  ...                    NaN
# 55060  Google Analytics  ...                    NaN
# 55061  Google Analytics  ...                    NaN
#
# [80 rows x 5 columns]
# Google Assistant
#                     App  ... Sentiment_Subjectivity
# 55062  Google Assistant  ...                    NaN
# 55063  Google Assistant  ...                    NaN
# 55064  Google Assistant  ...                    NaN
# 55065  Google Assistant  ...                    NaN
# 55066  Google Assistant  ...                    NaN
# 55067  Google Assistant  ...                    NaN
# 55068  Google Assistant  ...                    NaN
# 55069  Google Assistant  ...                    NaN
# 55070  Google Assistant  ...                    NaN
# 55071  Google Assistant  ...                    NaN
# 55072  Google Assistant  ...                    NaN
# 55073  Google Assistant  ...                    NaN
# 55074  Google Assistant  ...                    NaN
# 55075  Google Assistant  ...                    NaN
# 55076  Google Assistant  ...                    NaN
# 55077  Google Assistant  ...                    NaN
# 55078  Google Assistant  ...                    NaN
# 55079  Google Assistant  ...                    NaN
# 55080  Google Assistant  ...                    NaN
# 55081  Google Assistant  ...                    NaN
# 55082  Google Assistant  ...                    NaN
# 55083  Google Assistant  ...                    NaN
# 55084  Google Assistant  ...                    NaN
# 55085  Google Assistant  ...                    NaN
# 55086  Google Assistant  ...                    NaN
# 55087  Google Assistant  ...                    NaN
# 55088  Google Assistant  ...                    NaN
# 55089  Google Assistant  ...                    NaN
# 55090  Google Assistant  ...                    NaN
# 55091  Google Assistant  ...                    NaN
# 55092  Google Assistant  ...                    NaN
# 55093  Google Assistant  ...                    NaN
# 55094  Google Assistant  ...                    NaN
# 55095  Google Assistant  ...                    NaN
# 55096  Google Assistant  ...                    NaN
# 55097  Google Assistant  ...                    NaN
# 55098  Google Assistant  ...                    NaN
# 55099  Google Assistant  ...                    NaN
# 55100  Google Assistant  ...                    NaN
# 55101  Google Assistant  ...                    NaN
#
# [40 rows x 5 columns]
# Google Assistant Go
#                        App  ... Sentiment_Subjectivity
# 55102  Google Assistant Go  ...                    NaN
# 55103  Google Assistant Go  ...                    NaN
# 55104  Google Assistant Go  ...                    NaN
# 55105  Google Assistant Go  ...                    NaN
# 55106  Google Assistant Go  ...                    NaN
# ...                    ...  ...                    ...
# 55164  Google Assistant Go  ...                    NaN
# 55165  Google Assistant Go  ...                    NaN
# 55166  Google Assistant Go  ...                    NaN
# 55167  Google Assistant Go  ...                    NaN
# 55168  Google Assistant Go  ...                    NaN
#
# [67 rows x 5 columns]
# Google Calendar
#                    App  ... Sentiment_Subjectivity
# 55169  Google Calendar  ...                    NaN
# 55170  Google Calendar  ...                    NaN
# 55171  Google Calendar  ...                    NaN
# 55172  Google Calendar  ...                    NaN
# 55173  Google Calendar  ...                    NaN
# ...                ...  ...                    ...
# 55284  Google Calendar  ...                    NaN
# 55285  Google Calendar  ...                    NaN
# 55286  Google Calendar  ...                    NaN
# 55287  Google Calendar  ...                    NaN
# 55288  Google Calendar  ...                    NaN
#
# [120 rows x 5 columns]
# Google Chrome: Fast & Secure
#                                 App  ... Sentiment_Subjectivity
# 55289  Google Chrome: Fast & Secure  ...                    NaN
# 55290  Google Chrome: Fast & Secure  ...                    NaN
# 55291  Google Chrome: Fast & Secure  ...                    NaN
# 55292  Google Chrome: Fast & Secure  ...                    NaN
# 55293  Google Chrome: Fast & Secure  ...                    NaN
# ...                             ...  ...                    ...
# 55364  Google Chrome: Fast & Secure  ...                    NaN
# 55365  Google Chrome: Fast & Secure  ...                    NaN
# 55366  Google Chrome: Fast & Secure  ...                    NaN
# 55367  Google Chrome: Fast & Secure  ...                    NaN
# 55368  Google Chrome: Fast & Secure  ...                    NaN
#
# [80 rows x 5 columns]
# Google Classroom
#                     App  ... Sentiment_Subjectivity
# 55369  Google Classroom  ...                    NaN
# 55370  Google Classroom  ...                    NaN
# 55371  Google Classroom  ...                    NaN
# 55372  Google Classroom  ...                    NaN
# 55373  Google Classroom  ...                    NaN
# ...                 ...  ...                    ...
# 55484  Google Classroom  ...                    NaN
# 55485  Google Classroom  ...                    NaN
# 55486  Google Classroom  ...                    NaN
# 55487  Google Classroom  ...                    NaN
# 55488  Google Classroom  ...                    NaN
#
# [120 rows x 5 columns]
# Google Docs
#                App  ... Sentiment_Subjectivity
# 55489  Google Docs  ...                    NaN
# 55490  Google Docs  ...                    NaN
# 55491  Google Docs  ...                    NaN
# 55492  Google Docs  ...                    NaN
# 55493  Google Docs  ...                    NaN
# ...            ...  ...                    ...
# 55564  Google Docs  ...                    NaN
# 55565  Google Docs  ...                    NaN
# 55566  Google Docs  ...                    NaN
# 55567  Google Docs  ...                    NaN
# 55568  Google Docs  ...                    NaN
#
# [80 rows x 5 columns]
# Google Drive
#                 App  ... Sentiment_Subjectivity
# 55569  Google Drive  ...                    NaN
# 55570  Google Drive  ...                    NaN
# 55571  Google Drive  ...                    NaN
# 55572  Google Drive  ...                    NaN
# 55573  Google Drive  ...                    NaN
# ...             ...  ...                    ...
# 55684  Google Drive  ...                    NaN
# 55685  Google Drive  ...                    NaN
# 55686  Google Drive  ...                    NaN
# 55687  Google Drive  ...                    NaN
# 55688  Google Drive  ...                    NaN
#
# [120 rows x 5 columns]
# Google Duo - High Quality Video Calls
#                                          App  ... Sentiment_Subjectivity
# 55689  Google Duo - High Quality Video Calls  ...                    NaN
# 55690  Google Duo - High Quality Video Calls  ...                    NaN
# 55691  Google Duo - High Quality Video Calls  ...                    NaN
# 55692  Google Duo - High Quality Video Calls  ...                    NaN
# 55693  Google Duo - High Quality Video Calls  ...                    NaN
# 55694  Google Duo - High Quality Video Calls  ...                    NaN
# 55695  Google Duo - High Quality Video Calls  ...                    NaN
# 55696  Google Duo - High Quality Video Calls  ...                    NaN
# 55697  Google Duo - High Quality Video Calls  ...                    NaN
# 55698  Google Duo - High Quality Video Calls  ...                    NaN
# 55699  Google Duo - High Quality Video Calls  ...                    NaN
# 55700  Google Duo - High Quality Video Calls  ...                    NaN
# 55701  Google Duo - High Quality Video Calls  ...                    NaN
# 55702  Google Duo - High Quality Video Calls  ...                    NaN
# 55703  Google Duo - High Quality Video Calls  ...                    NaN
# 55704  Google Duo - High Quality Video Calls  ...                    NaN
# 55705  Google Duo - High Quality Video Calls  ...                    NaN
# 55706  Google Duo - High Quality Video Calls  ...                    NaN
# 55707  Google Duo - High Quality Video Calls  ...                    NaN
# 55708  Google Duo - High Quality Video Calls  ...                    NaN
# 55709  Google Duo - High Quality Video Calls  ...                    NaN
# 55710  Google Duo - High Quality Video Calls  ...               0.431250
# 55711  Google Duo - High Quality Video Calls  ...               0.150000
# 55712  Google Duo - High Quality Video Calls  ...               0.000000
# 55713  Google Duo - High Quality Video Calls  ...               0.694667
# 55714  Google Duo - High Quality Video Calls  ...               0.400000
# 55715  Google Duo - High Quality Video Calls  ...               0.712500
# 55716  Google Duo - High Quality Video Calls  ...               0.556250
# 55717  Google Duo - High Quality Video Calls  ...               0.750000
# 55718  Google Duo - High Quality Video Calls  ...               0.483333
# 55719  Google Duo - High Quality Video Calls  ...               0.310000
# 55720  Google Duo - High Quality Video Calls  ...                    NaN
# 55721  Google Duo - High Quality Video Calls  ...               0.462500
# 55722  Google Duo - High Quality Video Calls  ...               0.720000
# 55723  Google Duo - High Quality Video Calls  ...               0.833333
# 55724  Google Duo - High Quality Video Calls  ...               0.460000
# 55725  Google Duo - High Quality Video Calls  ...               0.591667
# 55726  Google Duo - High Quality Video Calls  ...               0.608333
# 55727  Google Duo - High Quality Video Calls  ...               0.400000
# 55728  Google Duo - High Quality Video Calls  ...               0.400000
#
# [40 rows x 5 columns]
# Google Earth
#                 App  ... Sentiment_Subjectivity
# 55729  Google Earth  ...               0.541667
# 55730  Google Earth  ...               0.725000
# 55731  Google Earth  ...               0.750000
# 55732  Google Earth  ...               0.479643
# 55733  Google Earth  ...               0.833333
# 55734  Google Earth  ...               0.462500
# 55735  Google Earth  ...               0.386667
# 55736  Google Earth  ...               0.800000
# 55737  Google Earth  ...               0.468750
# 55738  Google Earth  ...               0.750000
# 55739  Google Earth  ...               0.000000
# 55740  Google Earth  ...               0.516667
# 55741  Google Earth  ...               0.144444
# 55742  Google Earth  ...               0.500000
# 55743  Google Earth  ...                    NaN
# 55744  Google Earth  ...               0.277778
# 55745  Google Earth  ...               0.237500
# 55746  Google Earth  ...               0.358333
# 55747  Google Earth  ...               0.633333
# 55748  Google Earth  ...               0.416667
# 55749  Google Earth  ...               0.533333
# 55750  Google Earth  ...               0.419388
# 55751  Google Earth  ...               0.000000
# 55752  Google Earth  ...               0.000000
# 55753  Google Earth  ...               0.566667
# 55754  Google Earth  ...               0.460000
# 55755  Google Earth  ...               0.512500
# 55756  Google Earth  ...               0.550000
# 55757  Google Earth  ...               0.500000
# 55758  Google Earth  ...               0.640000
# 55759  Google Earth  ...               0.000000
# 55760  Google Earth  ...               0.433333
# 55761  Google Earth  ...               1.000000
# 55762  Google Earth  ...               0.550595
# 55763  Google Earth  ...               0.572222
# 55764  Google Earth  ...               0.511111
# 55765  Google Earth  ...                    NaN
# 55766  Google Earth  ...               0.200000
# 55767  Google Earth  ...               0.487143
# 55768  Google Earth  ...               0.450000
#
# [40 rows x 5 columns]
# Google Fit - Fitness Tracking
#                                  App  ... Sentiment_Subjectivity
# 55769  Google Fit - Fitness Tracking  ...               0.550833
# 55770  Google Fit - Fitness Tracking  ...               0.533333
# 55771  Google Fit - Fitness Tracking  ...               0.351250
# 55772  Google Fit - Fitness Tracking  ...               0.306667
# 55773  Google Fit - Fitness Tracking  ...               0.391667
# 55774  Google Fit - Fitness Tracking  ...               0.600000
# 55775  Google Fit - Fitness Tracking  ...               0.413571
# 55776  Google Fit - Fitness Tracking  ...               0.517262
# 55777  Google Fit - Fitness Tracking  ...               0.508333
# 55778  Google Fit - Fitness Tracking  ...               0.841667
# 55779  Google Fit - Fitness Tracking  ...               0.300000
# 55780  Google Fit - Fitness Tracking  ...               0.446429
# 55781  Google Fit - Fitness Tracking  ...               0.483333
# 55782  Google Fit - Fitness Tracking  ...               0.000000
# 55783  Google Fit - Fitness Tracking  ...               0.000000
# 55784  Google Fit - Fitness Tracking  ...               0.500000
# 55785  Google Fit - Fitness Tracking  ...               0.733333
# 55786  Google Fit - Fitness Tracking  ...               0.484848
# 55787  Google Fit - Fitness Tracking  ...               0.700000
# 55788  Google Fit - Fitness Tracking  ...               0.000000
# 55789  Google Fit - Fitness Tracking  ...               0.600000
# 55790  Google Fit - Fitness Tracking  ...               0.633333
# 55791  Google Fit - Fitness Tracking  ...               0.000000
# 55792  Google Fit - Fitness Tracking  ...               0.200000
# 55793  Google Fit - Fitness Tracking  ...               0.466667
# 55794  Google Fit - Fitness Tracking  ...               0.611111
# 55795  Google Fit - Fitness Tracking  ...               0.732500
# 55796  Google Fit - Fitness Tracking  ...               0.828472
# 55797  Google Fit - Fitness Tracking  ...               0.497619
# 55798  Google Fit - Fitness Tracking  ...               0.650000
# 55799  Google Fit - Fitness Tracking  ...               0.652778
# 55800  Google Fit - Fitness Tracking  ...               0.575397
# 55801  Google Fit - Fitness Tracking  ...               0.500000
# 55802  Google Fit - Fitness Tracking  ...               0.562500
# 55803  Google Fit - Fitness Tracking  ...               0.000000
# 55804  Google Fit - Fitness Tracking  ...               0.200000
# 55805  Google Fit - Fitness Tracking  ...               0.541667
# 55806  Google Fit - Fitness Tracking  ...               0.600000
# 55807  Google Fit - Fitness Tracking  ...               0.600000
# 55808  Google Fit - Fitness Tracking  ...               1.000000
#
# [40 rows x 5 columns]
# Google Handwriting Input
#                             App  ... Sentiment_Subjectivity
# 55809  Google Handwriting Input  ...               0.490000
# 55810  Google Handwriting Input  ...               0.580000
# 55811  Google Handwriting Input  ...               0.000000
# 55812  Google Handwriting Input  ...                    NaN
# 55813  Google Handwriting Input  ...               0.477778
# 55814  Google Handwriting Input  ...               0.780000
# 55815  Google Handwriting Input  ...               0.000000
# 55816  Google Handwriting Input  ...               0.000000
# 55817  Google Handwriting Input  ...               0.600000
# 55818  Google Handwriting Input  ...               1.000000
# 55819  Google Handwriting Input  ...               1.000000
# 55820  Google Handwriting Input  ...               1.000000
# 55821  Google Handwriting Input  ...               0.540000
# 55822  Google Handwriting Input  ...               0.466667
# 55823  Google Handwriting Input  ...               0.410897
# 55824  Google Handwriting Input  ...                    NaN
# 55825  Google Handwriting Input  ...               0.500000
# 55826  Google Handwriting Input  ...               0.500000
# 55827  Google Handwriting Input  ...               0.000000
# 55828  Google Handwriting Input  ...               0.700000
# 55829  Google Handwriting Input  ...               0.000000
# 55830  Google Handwriting Input  ...               0.000000
# 55831  Google Handwriting Input  ...               0.000000
# 55832  Google Handwriting Input  ...               0.000000
# 55833  Google Handwriting Input  ...               0.625000
# 55834  Google Handwriting Input  ...               0.000000
# 55835  Google Handwriting Input  ...               0.000000
# 55836  Google Handwriting Input  ...               0.833333
# 55837  Google Handwriting Input  ...               0.000000
# 55838  Google Handwriting Input  ...               0.000000
# 55839  Google Handwriting Input  ...               0.000000
# 55840  Google Handwriting Input  ...               0.000000
# 55841  Google Handwriting Input  ...               0.000000
# 55842  Google Handwriting Input  ...               0.916667
# 55843  Google Handwriting Input  ...               0.600000
# 55844  Google Handwriting Input  ...               0.750000
# 55845  Google Handwriting Input  ...               0.675000
# 55846  Google Handwriting Input  ...               1.000000
# 55847  Google Handwriting Input  ...               0.000000
# 55848  Google Handwriting Input  ...               0.500000
#
# [40 rows x 5 columns]
# Google Keep
#                App  ... Sentiment_Subjectivity
# 55849  Google Keep  ...               0.250000
# 55850  Google Keep  ...               0.432121
# 55851  Google Keep  ...               0.470238
# 55852  Google Keep  ...               0.541667
# 55853  Google Keep  ...               0.300000
# ...            ...  ...                    ...
# 55964  Google Keep  ...               0.900000
# 55965  Google Keep  ...               0.900000
# 55966  Google Keep  ...               0.650000
# 55967  Google Keep  ...               0.066667
# 55968  Google Keep  ...               0.562500
#
# [120 rows x 5 columns]
# Google My Business
#                       App  ... Sentiment_Subjectivity
# 55969  Google My Business  ...               0.677273
# 55970  Google My Business  ...               0.625000
# 55971  Google My Business  ...               0.733333
# 55972  Google My Business  ...               0.100000
# 55973  Google My Business  ...               0.000000
# ...                   ...  ...                    ...
# 56084  Google My Business  ...               1.000000
# 56085  Google My Business  ...               1.000000
# 56086  Google My Business  ...               0.780000
# 56087  Google My Business  ...               0.600000
# 56088  Google My Business  ...               1.000000
#
# [120 rows x 5 columns]
# Google News
#                App  ... Sentiment_Subjectivity
# 56089  Google News  ...               0.550000
# 56090  Google News  ...               0.495536
# 56091  Google News  ...               0.375000
# 56092  Google News  ...               0.291667
# 56093  Google News  ...               0.612233
# ...            ...  ...                    ...
# 56204  Google News  ...               0.511905
# 56205  Google News  ...               0.560000
# 56206  Google News  ...               0.521875
# 56207  Google News  ...               0.605714
# 56208  Google News  ...               0.524242
#
# [120 rows x 5 columns]
# Google PDF Viewer
#                      App  ... Sentiment_Subjectivity
# 56209  Google PDF Viewer  ...               0.474851
# 56210  Google PDF Viewer  ...               0.293333
# 56211  Google PDF Viewer  ...               0.392262
# 56212  Google PDF Viewer  ...               0.433333
# 56213  Google PDF Viewer  ...               0.050000
# ...                  ...  ...                    ...
# 56284  Google PDF Viewer  ...               0.633333
# 56285  Google PDF Viewer  ...               0.631250
# 56286  Google PDF Viewer  ...               0.512500
# 56287  Google PDF Viewer  ...               0.500000
# 56288  Google PDF Viewer  ...               0.000000
#
# [80 rows x 5 columns]
# Google Pay
#               App  ... Sentiment_Subjectivity
# 56289  Google Pay  ...               0.227778
# 56290  Google Pay  ...               0.440741
# 56291  Google Pay  ...               0.644444
# 56292  Google Pay  ...               0.777083
# 56293  Google Pay  ...               0.569444
# ...           ...  ...                    ...
# 56404  Google Pay  ...               0.366667
# 56405  Google Pay  ...               0.500000
# 56406  Google Pay  ...               0.800000
# 56407  Google Pay  ...               0.000000
# 56408  Google Pay  ...               0.900000
#
# [120 rows x 5 columns]
# Google Photos
#                  App  ... Sentiment_Subjectivity
# 56409  Google Photos  ...                    NaN
# 56410  Google Photos  ...               0.408442
# 56411  Google Photos  ...               0.300000
# 56412  Google Photos  ...               0.592857
# 56413  Google Photos  ...               0.632333
# ...              ...  ...                    ...
# 56624  Google Photos  ...                    NaN
# 56625  Google Photos  ...                    NaN
# 56626  Google Photos  ...                    NaN
# 56627  Google Photos  ...                    NaN
# 56628  Google Photos  ...                    NaN
#
# [220 rows x 5 columns]
# Google Play Books
#                      App  ... Sentiment_Subjectivity
# 56629  Google Play Books  ...                    NaN
# 56630  Google Play Books  ...                    NaN
# 56631  Google Play Books  ...                    NaN
# 56632  Google Play Books  ...                    NaN
# 56633  Google Play Books  ...                    NaN
# 56634  Google Play Books  ...                    NaN
# 56635  Google Play Books  ...                    NaN
# 56636  Google Play Books  ...                    NaN
# 56637  Google Play Books  ...                    NaN
# 56638  Google Play Books  ...                    NaN
# 56639  Google Play Books  ...                    NaN
# 56640  Google Play Books  ...                    NaN
# 56641  Google Play Books  ...                    NaN
# 56642  Google Play Books  ...                    NaN
# 56643  Google Play Books  ...                    NaN
# 56644  Google Play Books  ...                    NaN
# 56645  Google Play Books  ...                    NaN
# 56646  Google Play Books  ...                    NaN
# 56647  Google Play Books  ...                    NaN
# 56648  Google Play Books  ...                    NaN
# 56649  Google Play Books  ...                    NaN
# 56650  Google Play Books  ...                    NaN
# 56651  Google Play Books  ...                    NaN
# 56652  Google Play Books  ...                    NaN
# 56653  Google Play Books  ...                    NaN
# 56654  Google Play Books  ...                    NaN
# 56655  Google Play Books  ...                    NaN
# 56656  Google Play Books  ...                    NaN
# 56657  Google Play Books  ...                    NaN
# 56658  Google Play Books  ...                    NaN
# 56659  Google Play Books  ...                    NaN
# 56660  Google Play Books  ...                    NaN
# 56661  Google Play Books  ...                    NaN
# 56662  Google Play Books  ...                    NaN
# 56663  Google Play Books  ...                    NaN
# 56664  Google Play Books  ...                    NaN
# 56665  Google Play Books  ...                    NaN
# 56666  Google Play Books  ...                    NaN
# 56667  Google Play Books  ...                    NaN
# 56668  Google Play Books  ...                    NaN
#
# [40 rows x 5 columns]
# Google Play Games
#                      App  ... Sentiment_Subjectivity
# 56669  Google Play Games  ...                    NaN
# 56670  Google Play Games  ...                    NaN
# 56671  Google Play Games  ...                    NaN
# 56672  Google Play Games  ...                    NaN
# 56673  Google Play Games  ...                    NaN
# 56674  Google Play Games  ...                    NaN
# 56675  Google Play Games  ...                    NaN
# 56676  Google Play Games  ...                    NaN
# 56677  Google Play Games  ...                    NaN
# 56678  Google Play Games  ...                    NaN
# 56679  Google Play Games  ...                    NaN
# 56680  Google Play Games  ...                    NaN
# 56681  Google Play Games  ...                    NaN
# 56682  Google Play Games  ...                    NaN
# 56683  Google Play Games  ...                    NaN
# 56684  Google Play Games  ...                    NaN
# 56685  Google Play Games  ...                    NaN
# 56686  Google Play Games  ...                    NaN
# 56687  Google Play Games  ...                    NaN
# 56688  Google Play Games  ...                    NaN
# 56689  Google Play Games  ...                    NaN
# 56690  Google Play Games  ...                    NaN
# 56691  Google Play Games  ...                    NaN
# 56692  Google Play Games  ...                    NaN
# 56693  Google Play Games  ...                    NaN
# 56694  Google Play Games  ...                    NaN
# 56695  Google Play Games  ...                    NaN
# 56696  Google Play Games  ...                    NaN
# 56697  Google Play Games  ...                    NaN
# 56698  Google Play Games  ...                    NaN
# 56699  Google Play Games  ...                    NaN
# 56700  Google Play Games  ...                    NaN
# 56701  Google Play Games  ...                    NaN
# 56702  Google Play Games  ...                    NaN
# 56703  Google Play Games  ...                    NaN
# 56704  Google Play Games  ...                    NaN
# 56705  Google Play Games  ...                    NaN
# 56706  Google Play Games  ...                    NaN
# 56707  Google Play Games  ...                    NaN
# 56708  Google Play Games  ...                    NaN
#
# [40 rows x 5 columns]
# Google Play Movies & TV
#                            App  ... Sentiment_Subjectivity
# 56709  Google Play Movies & TV  ...                    NaN
# 56710  Google Play Movies & TV  ...                    NaN
# 56711  Google Play Movies & TV  ...                    NaN
# 56712  Google Play Movies & TV  ...                    NaN
# 56713  Google Play Movies & TV  ...                    NaN
# 56714  Google Play Movies & TV  ...                    NaN
# 56715  Google Play Movies & TV  ...                    NaN
# 56716  Google Play Movies & TV  ...                    NaN
# 56717  Google Play Movies & TV  ...                    NaN
# 56718  Google Play Movies & TV  ...                    NaN
# 56719  Google Play Movies & TV  ...                    NaN
# 56720  Google Play Movies & TV  ...                    NaN
# 56721  Google Play Movies & TV  ...                    NaN
# 56722  Google Play Movies & TV  ...                    NaN
# 56723  Google Play Movies & TV  ...                    NaN
# 56724  Google Play Movies & TV  ...                    NaN
# 56725  Google Play Movies & TV  ...                    NaN
# 56726  Google Play Movies & TV  ...                    NaN
# 56727  Google Play Movies & TV  ...                    NaN
# 56728  Google Play Movies & TV  ...                    NaN
# 56729  Google Play Movies & TV  ...                    NaN
# 56730  Google Play Movies & TV  ...                    NaN
# 56731  Google Play Movies & TV  ...                    NaN
# 56732  Google Play Movies & TV  ...                    NaN
# 56733  Google Play Movies & TV  ...                    NaN
# 56734  Google Play Movies & TV  ...                    NaN
# 56735  Google Play Movies & TV  ...                    NaN
# 56736  Google Play Movies & TV  ...                    NaN
# 56737  Google Play Movies & TV  ...                    NaN
# 56738  Google Play Movies & TV  ...                    NaN
# 56739  Google Play Movies & TV  ...                    NaN
# 56740  Google Play Movies & TV  ...                    NaN
# 56741  Google Play Movies & TV  ...                    NaN
# 56742  Google Play Movies & TV  ...                    NaN
# 56743  Google Play Movies & TV  ...                    NaN
# 56744  Google Play Movies & TV  ...                    NaN
# 56745  Google Play Movies & TV  ...                    NaN
# 56746  Google Play Movies & TV  ...                    NaN
# 56747  Google Play Movies & TV  ...                    NaN
# 56748  Google Play Movies & TV  ...                    NaN
#
# [40 rows x 5 columns]
# Google Primer
#                  App  ... Sentiment_Subjectivity
# 56749  Google Primer  ...                    NaN
# 56750  Google Primer  ...                    NaN
# 56751  Google Primer  ...                    NaN
# 56752  Google Primer  ...                    NaN
# 56753  Google Primer  ...                    NaN
# 56754  Google Primer  ...                    NaN
# 56755  Google Primer  ...                    NaN
# 56756  Google Primer  ...                    NaN
# 56757  Google Primer  ...                    NaN
# 56758  Google Primer  ...                    NaN
# 56759  Google Primer  ...                    NaN
# 56760  Google Primer  ...                    NaN
# 56761  Google Primer  ...                    NaN
# 56762  Google Primer  ...                    NaN
# 56763  Google Primer  ...                    NaN
# 56764  Google Primer  ...                    NaN
# 56765  Google Primer  ...                    NaN
# 56766  Google Primer  ...                    NaN
# 56767  Google Primer  ...                    NaN
# 56768  Google Primer  ...                    NaN
# 56769  Google Primer  ...                    NaN
# 56770  Google Primer  ...                    NaN
# 56771  Google Primer  ...                    NaN
# 56772  Google Primer  ...                    NaN
# 56773  Google Primer  ...                    NaN
# 56774  Google Primer  ...                    NaN
# 56775  Google Primer  ...                    NaN
# 56776  Google Primer  ...                    NaN
# 56777  Google Primer  ...                    NaN
# 56778  Google Primer  ...                    NaN
# 56779  Google Primer  ...                    NaN
# 56780  Google Primer  ...                    NaN
# 56781  Google Primer  ...                    NaN
# 56782  Google Primer  ...                    NaN
# 56783  Google Primer  ...                   0.75
# 56784  Google Primer  ...                    NaN
# 56785  Google Primer  ...                   0.60
# 56786  Google Primer  ...                    NaN
# 56787  Google Primer  ...                    NaN
# 56788  Google Primer  ...                    NaN
#
# [40 rows x 5 columns]
# Google Sheets
#                  App  ... Sentiment_Subjectivity
# 56789  Google Sheets  ...                    NaN
# 56790  Google Sheets  ...                    NaN
# 56791  Google Sheets  ...                    NaN
# 56792  Google Sheets  ...                    NaN
# 56793  Google Sheets  ...                    NaN
# 56794  Google Sheets  ...                    NaN
# 56795  Google Sheets  ...                    NaN
# 56796  Google Sheets  ...                    NaN
# 56797  Google Sheets  ...                    NaN
# 56798  Google Sheets  ...                    NaN
# 56799  Google Sheets  ...                    NaN
# 56800  Google Sheets  ...                    NaN
# 56801  Google Sheets  ...                    NaN
# 56802  Google Sheets  ...                    NaN
# 56803  Google Sheets  ...                    NaN
# 56804  Google Sheets  ...                    NaN
# 56805  Google Sheets  ...                    NaN
# 56806  Google Sheets  ...                    NaN
# 56807  Google Sheets  ...                    NaN
# 56808  Google Sheets  ...                    NaN
# 56809  Google Sheets  ...                    NaN
# 56810  Google Sheets  ...                    NaN
# 56811  Google Sheets  ...                    NaN
# 56812  Google Sheets  ...                    NaN
# 56813  Google Sheets  ...                    NaN
# 56814  Google Sheets  ...                    NaN
# 56815  Google Sheets  ...                    NaN
# 56816  Google Sheets  ...                    NaN
# 56817  Google Sheets  ...                    NaN
# 56818  Google Sheets  ...                    NaN
# 56819  Google Sheets  ...                    NaN
# 56820  Google Sheets  ...                    NaN
# 56821  Google Sheets  ...                    NaN
# 56822  Google Sheets  ...                    NaN
# 56823  Google Sheets  ...                    NaN
# 56824  Google Sheets  ...                    NaN
# 56825  Google Sheets  ...                    NaN
# 56826  Google Sheets  ...                    NaN
# 56827  Google Sheets  ...                    NaN
# 56828  Google Sheets  ...                    NaN
#
# [40 rows x 5 columns]
# Google Slides
#                  App  ... Sentiment_Subjectivity
# 56829  Google Slides  ...                    NaN
# 56830  Google Slides  ...                    NaN
# 56831  Google Slides  ...                    NaN
# 56832  Google Slides  ...                    NaN
# 56833  Google Slides  ...                    NaN
# 56834  Google Slides  ...                    NaN
# 56835  Google Slides  ...                    NaN
# 56836  Google Slides  ...                    NaN
# 56837  Google Slides  ...                    NaN
# 56838  Google Slides  ...                    NaN
# 56839  Google Slides  ...                    NaN
# 56840  Google Slides  ...                    NaN
# 56841  Google Slides  ...                    NaN
# 56842  Google Slides  ...                    NaN
# 56843  Google Slides  ...                    NaN
# 56844  Google Slides  ...                    NaN
# 56845  Google Slides  ...                    NaN
# 56846  Google Slides  ...                    NaN
# 56847  Google Slides  ...                    NaN
# 56848  Google Slides  ...                    NaN
# 56849  Google Slides  ...                    NaN
# 56850  Google Slides  ...                    NaN
# 56851  Google Slides  ...                    NaN
# 56852  Google Slides  ...                    NaN
# 56853  Google Slides  ...                    NaN
# 56854  Google Slides  ...                    NaN
# 56855  Google Slides  ...                    NaN
# 56856  Google Slides  ...                    NaN
# 56857  Google Slides  ...                    NaN
# 56858  Google Slides  ...                    NaN
# 56859  Google Slides  ...                    NaN
# 56860  Google Slides  ...                    NaN
# 56861  Google Slides  ...                    NaN
# 56862  Google Slides  ...                    NaN
# 56863  Google Slides  ...                    NaN
# 56864  Google Slides  ...                    NaN
# 56865  Google Slides  ...                    NaN
# 56866  Google Slides  ...                    NaN
# 56867  Google Slides  ...               0.916667
# 56868  Google Slides  ...                    NaN
#
# [40 rows x 5 columns]
# Google Street View
#                       App  ... Sentiment_Subjectivity
# 56869  Google Street View  ...                    NaN
# 56870  Google Street View  ...                    0.2
# 56871  Google Street View  ...                    NaN
# 56872  Google Street View  ...                    NaN
# 56873  Google Street View  ...                    NaN
# ...                   ...  ...                    ...
# 56944  Google Street View  ...                    NaN
# 56945  Google Street View  ...                    NaN
# 56946  Google Street View  ...                    0.9
# 56947  Google Street View  ...                    1.0
# 56948  Google Street View  ...                    NaN
#
# [80 rows x 5 columns]
# Google Translate
#                     App  ... Sentiment_Subjectivity
# 56949  Google Translate  ...                    NaN
# 56950  Google Translate  ...                    NaN
# 56951  Google Translate  ...                    NaN
# 56952  Google Translate  ...                    NaN
# 56953  Google Translate  ...                    NaN
# ...                 ...  ...                    ...
# 57071  Google Translate  ...                    NaN
# 57072  Google Translate  ...                    NaN
# 57073  Google Translate  ...                    NaN
# 57074  Google Translate  ...                    NaN
# 57075  Google Translate  ...                    NaN
#
# [127 rows x 5 columns]
# Google Trips - Travel Planner
#                                  App  ... Sentiment_Subjectivity
# 57076  Google Trips - Travel Planner  ...                    NaN
# 57077  Google Trips - Travel Planner  ...                    NaN
# 57078  Google Trips - Travel Planner  ...                    NaN
# 57079  Google Trips - Travel Planner  ...                    NaN
# 57080  Google Trips - Travel Planner  ...                    NaN
# 57081  Google Trips - Travel Planner  ...                    NaN
# 57082  Google Trips - Travel Planner  ...                    NaN
# 57083  Google Trips - Travel Planner  ...                    NaN
# 57084  Google Trips - Travel Planner  ...                    NaN
# 57085  Google Trips - Travel Planner  ...                    NaN
# 57086  Google Trips - Travel Planner  ...                    NaN
# 57087  Google Trips - Travel Planner  ...                    NaN
# 57088  Google Trips - Travel Planner  ...                    NaN
# 57089  Google Trips - Travel Planner  ...                    NaN
# 57090  Google Trips - Travel Planner  ...                    NaN
# 57091  Google Trips - Travel Planner  ...                    NaN
# 57092  Google Trips - Travel Planner  ...                    NaN
# 57093  Google Trips - Travel Planner  ...                    NaN
# 57094  Google Trips - Travel Planner  ...                    NaN
# 57095  Google Trips - Travel Planner  ...                    NaN
# 57096  Google Trips - Travel Planner  ...                    NaN
# 57097  Google Trips - Travel Planner  ...                    NaN
# 57098  Google Trips - Travel Planner  ...                    NaN
# 57099  Google Trips - Travel Planner  ...                    NaN
# 57100  Google Trips - Travel Planner  ...                    NaN
# 57101  Google Trips - Travel Planner  ...                    NaN
# 57102  Google Trips - Travel Planner  ...                    NaN
# 57103  Google Trips - Travel Planner  ...                    NaN
# 57104  Google Trips - Travel Planner  ...                    NaN
# 57105  Google Trips - Travel Planner  ...                    NaN
# 57106  Google Trips - Travel Planner  ...                    NaN
# 57107  Google Trips - Travel Planner  ...                    NaN
# 57108  Google Trips - Travel Planner  ...                    NaN
# 57109  Google Trips - Travel Planner  ...                    NaN
# 57110  Google Trips - Travel Planner  ...                    NaN
# 57111  Google Trips - Travel Planner  ...                    0.0
# 57112  Google Trips - Travel Planner  ...                    NaN
# 57113  Google Trips - Travel Planner  ...                    NaN
# 57114  Google Trips - Travel Planner  ...                    NaN
# 57115  Google Trips - Travel Planner  ...                    NaN
#
# [40 rows x 5 columns]
# Google Voice
#                 App  ... Sentiment_Subjectivity
# 57116  Google Voice  ...                    NaN
# 57117  Google Voice  ...                    NaN
# 57118  Google Voice  ...               0.213333
# 57119  Google Voice  ...                    NaN
# 57120  Google Voice  ...                    NaN
# ...             ...  ...                    ...
# 57191  Google Voice  ...                    NaN
# 57192  Google Voice  ...                    NaN
# 57193  Google Voice  ...                    NaN
# 57194  Google Voice  ...                    NaN
# 57195  Google Voice  ...                    NaN
#
# [80 rows x 5 columns]
# Google+
#            App  ... Sentiment_Subjectivity
# 57196  Google+  ...                    NaN
# 57197  Google+  ...               0.355556
# 57198  Google+  ...                    NaN
# 57199  Google+  ...                    NaN
# 57200  Google+  ...                    NaN
# 57201  Google+  ...                    NaN
# 57202  Google+  ...                    NaN
# 57203  Google+  ...                    NaN
# 57204  Google+  ...                    NaN
# 57205  Google+  ...                    NaN
# 57206  Google+  ...                    NaN
# 57207  Google+  ...                    NaN
# 57208  Google+  ...                    NaN
# 57209  Google+  ...                    NaN
# 57210  Google+  ...                    NaN
# 57211  Google+  ...                    NaN
# ...
# 63992  Hotels Combined - Cheap deals  ...               0.300000
# 63993  Hotels Combined - Cheap deals  ...               0.415476
# 63994  Hotels Combined - Cheap deals  ...               0.000000
# 63995  Hotels Combined - Cheap deals  ...               0.800000
#
# [40 rows x 5 columns]
# Hotels.com: Book Hotel Rooms & Find Vacation Deals
#                                                      App  ... Sentiment_Subjectivity
# 63996  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.566667
# 63997  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.633333
# 63998  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.404167
# 63999  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.646667
# 64000  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.338889
# ...                                                  ...  ...                    ...
# 64071  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.500000
# 64072  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.250000
# 64073  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.670909
# 64074  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...                    NaN
# 64075  Hotels.com: Book Hotel Rooms & Find Vacation D...  ...               0.200000
#
# [80 rows x 5 columns]
# Hotspot Shield Free VPN Proxy & Wi-Fi Security
#                                                   App  ... Sentiment_Subjectivity
# 64076  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.900000
# 64077  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.475000
# 64078  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64079  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64080  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64081  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64082  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
# 64083  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               1.000000
# 64084  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.800000
# 64085  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64086  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
# 64087  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64088  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64089  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               1.000000
# 64090  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.300000
# 64091  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.780000
# 64092  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.750000
# 64093  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               1.000000
# 64094  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64095  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64096  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
# 64097  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.500000
# 64098  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64099  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.666667
# 64100  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.200000
# 64101  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.650000
# 64102  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64103  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64104  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
# 64105  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
# 64106  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64107  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64108  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64109  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.000000
# 64110  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64111  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.750000
# 64112  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64113  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64114  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...               0.600000
# 64115  Hotspot Shield Free VPN Proxy & Wi-Fi Security  ...                    NaN
#
# [40 rows x 5 columns]
# Hotstar
#            App  ... Sentiment_Subjectivity
# 64116  Hotstar  ...               0.000000
# 64117  Hotstar  ...               0.300000
# 64118  Hotstar  ...               0.496667
# 64119  Hotstar  ...                    NaN
# 64120  Hotstar  ...               0.650000
# 64121  Hotstar  ...               0.000000
# 64122  Hotstar  ...                    NaN
# 64123  Hotstar  ...               0.629167
# 64124  Hotstar  ...               0.100000
# 64125  Hotstar  ...               0.685714
# 64126  Hotstar  ...                    NaN
# 64127  Hotstar  ...               0.613333
# 64128  Hotstar  ...                    NaN
# 64129  Hotstar  ...               0.250000
# 64130  Hotstar  ...               0.800000
# 64131  Hotstar  ...               0.550000
# 64132  Hotstar  ...               0.400000
# 64133  Hotstar  ...               0.686667
# 64134  Hotstar  ...               0.400000
# 64135  Hotstar  ...               0.675000
# 64136  Hotstar  ...               0.576905
# 64137  Hotstar  ...               0.414935
# 64138  Hotstar  ...                    NaN
# 64139  Hotstar  ...                    NaN
# 64140  Hotstar  ...               0.490000
# 64141  Hotstar  ...               0.950000
# 64142  Hotstar  ...               1.000000
# 64143  Hotstar  ...               0.644444
# 64144  Hotstar  ...               0.317857
# 64145  Hotstar  ...               0.375000
# 64146  Hotstar  ...                    NaN
# 64147  Hotstar  ...               0.506122
# 64148  Hotstar  ...               0.633929
# 64149  Hotstar  ...                    NaN
# 64150  Hotstar  ...               0.500000
# 64151  Hotstar  ...               0.366667
# 64152  Hotstar  ...               0.511111
# 64153  Hotstar  ...               0.300000
# 64154  Hotstar  ...               0.500000
# 64155  Hotstar  ...               0.483333
#
# [40 rows x 5 columns]
# Hotwire Hotel & Car Rental App
#                                   App  ... Sentiment_Subjectivity
# 64156  Hotwire Hotel & Car Rental App  ...                    NaN
# 64157  Hotwire Hotel & Car Rental App  ...               0.655556
# 64158  Hotwire Hotel & Car Rental App  ...               0.517262
# 64159  Hotwire Hotel & Car Rental App  ...               0.750000
# 64160  Hotwire Hotel & Car Rental App  ...                    NaN
# 64161  Hotwire Hotel & Car Rental App  ...               0.000000
# 64162  Hotwire Hotel & Car Rental App  ...                    NaN
# 64163  Hotwire Hotel & Car Rental App  ...               0.833333
# 64164  Hotwire Hotel & Car Rental App  ...               0.500000
# 64165  Hotwire Hotel & Car Rental App  ...               0.666667
# 64166  Hotwire Hotel & Car Rental App  ...               0.615000
# 64167  Hotwire Hotel & Car Rental App  ...                    NaN
# 64168  Hotwire Hotel & Car Rental App  ...               0.750000
# 64169  Hotwire Hotel & Car Rental App  ...               0.000000
# 64170  Hotwire Hotel & Car Rental App  ...               0.000000
# 64171  Hotwire Hotel & Car Rental App  ...               0.750000
# 64172  Hotwire Hotel & Car Rental App  ...                    NaN
# 64173  Hotwire Hotel & Car Rental App  ...               0.270833
# 64174  Hotwire Hotel & Car Rental App  ...               0.662500
# 64175  Hotwire Hotel & Car Rental App  ...               0.566667
# 64176  Hotwire Hotel & Car Rental App  ...               0.397619
# 64177  Hotwire Hotel & Car Rental App  ...               0.875000
# 64178  Hotwire Hotel & Car Rental App  ...               0.000000
# 64179  Hotwire Hotel & Car Rental App  ...               0.000000
# 64180  Hotwire Hotel & Car Rental App  ...               0.666667
# 64181  Hotwire Hotel & Car Rental App  ...               0.600000
# 64182  Hotwire Hotel & Car Rental App  ...               0.500000
# 64183  Hotwire Hotel & Car Rental App  ...               0.600000
# 64184  Hotwire Hotel & Car Rental App  ...               0.187500
# 64185  Hotwire Hotel & Car Rental App  ...               0.600000
# 64186  Hotwire Hotel & Car Rental App  ...               0.365000
# 64187  Hotwire Hotel & Car Rental App  ...               0.900000
# 64188  Hotwire Hotel & Car Rental App  ...               0.000000
# 64189  Hotwire Hotel & Car Rental App  ...               0.100000
# 64190  Hotwire Hotel & Car Rental App  ...               0.600000
# 64191  Hotwire Hotel & Car Rental App  ...               0.491071
# 64192  Hotwire Hotel & Car Rental App  ...               0.750000
# 64193  Hotwire Hotel & Car Rental App  ...                    NaN
# 64194  Hotwire Hotel & Car Rental App  ...               0.000000
# 64195  Hotwire Hotel & Car Rental App  ...                    NaN
#
# [40 rows x 5 columns]
# Housing-Real Estate & Property
#                                   App  ... Sentiment_Subjectivity
# 64196  Housing-Real Estate & Property  ...               0.125000
# 64197  Housing-Real Estate & Property  ...               0.625000
# 64198  Housing-Real Estate & Property  ...               0.375000
# 64199  Housing-Real Estate & Property  ...               0.200000
# 64200  Housing-Real Estate & Property  ...               0.000000
# 64201  Housing-Real Estate & Property  ...               0.200000
# 64202  Housing-Real Estate & Property  ...                    NaN
# 64203  Housing-Real Estate & Property  ...                    NaN
# 64204  Housing-Real Estate & Property  ...                    NaN
# 64205  Housing-Real Estate & Property  ...               0.000000
# 64206  Housing-Real Estate & Property  ...                    NaN
# 64207  Housing-Real Estate & Property  ...               0.600000
# 64208  Housing-Real Estate & Property  ...                    NaN
# 64209  Housing-Real Estate & Property  ...               0.511458
# 64210  Housing-Real Estate & Property  ...                    NaN
# 64211  Housing-Real Estate & Property  ...                    NaN
# 64212  Housing-Real Estate & Property  ...                    NaN
# 64213  Housing-Real Estate & Property  ...               0.418750
# 64214  Housing-Real Estate & Property  ...                    NaN
# 64215  Housing-Real Estate & Property  ...               0.717262
# 64216  Housing-Real Estate & Property  ...               0.250000
# 64217  Housing-Real Estate & Property  ...               0.550000
# 64218  Housing-Real Estate & Property  ...               0.000000
# 64219  Housing-Real Estate & Property  ...                    NaN
# 64220  Housing-Real Estate & Property  ...               0.533333
# 64221  Housing-Real Estate & Property  ...               0.259470
# 64222  Housing-Real Estate & Property  ...               0.486667
# 64223  Housing-Real Estate & Property  ...               0.447222
# 64224  Housing-Real Estate & Property  ...                    NaN
# 64225  Housing-Real Estate & Property  ...                    NaN
# 64226  Housing-Real Estate & Property  ...               0.250000
# 64227  Housing-Real Estate & Property  ...               1.000000
# 64228  Housing-Real Estate & Property  ...                    NaN
# 64229  Housing-Real Estate & Property  ...                    NaN
# 64230  Housing-Real Estate & Property  ...               0.400000
# 64231  Housing-Real Estate & Property  ...                    NaN
# 64232  Housing-Real Estate & Property  ...                    NaN
# 64233  Housing-Real Estate & Property  ...                    NaN
# 64234  Housing-Real Estate & Property  ...                    NaN
# 64235  Housing-Real Estate & Property  ...                    NaN
#
# [40 rows x 5 columns]
# Houzz Interior Design Ideas
#                                App  ... Sentiment_Subjectivity
# 64236  Houzz Interior Design Ideas  ...                    NaN
# 64237  Houzz Interior Design Ideas  ...                    NaN
# 64238  Houzz Interior Design Ideas  ...                    NaN
# 64239  Houzz Interior Design Ideas  ...                    NaN
# 64240  Houzz Interior Design Ideas  ...                    NaN
# 64241  Houzz Interior Design Ideas  ...                    NaN
# 64242  Houzz Interior Design Ideas  ...                    NaN
# 64243  Houzz Interior Design Ideas  ...                    NaN
# 64244  Houzz Interior Design Ideas  ...                    NaN
# 64245  Houzz Interior Design Ideas  ...                    NaN
# 64246  Houzz Interior Design Ideas  ...                    NaN
# 64247  Houzz Interior Design Ideas  ...                    NaN
# 64248  Houzz Interior Design Ideas  ...                    NaN
# 64249  Houzz Interior Design Ideas  ...                    NaN
# 64250  Houzz Interior Design Ideas  ...                    NaN
# 64251  Houzz Interior Design Ideas  ...                    NaN
# 64252  Houzz Interior Design Ideas  ...                    NaN
# 64253  Houzz Interior Design Ideas  ...                    NaN
# 64254  Houzz Interior Design Ideas  ...                    NaN
# 64255  Houzz Interior Design Ideas  ...                    NaN
# 64256  Houzz Interior Design Ideas  ...                    NaN
# 64257  Houzz Interior Design Ideas  ...                    NaN
# 64258  Houzz Interior Design Ideas  ...                    NaN
# 64259  Houzz Interior Design Ideas  ...                    NaN
# 64260  Houzz Interior Design Ideas  ...                    NaN
# 64261  Houzz Interior Design Ideas  ...                    NaN
# 64262  Houzz Interior Design Ideas  ...                    NaN
# 64263  Houzz Interior Design Ideas  ...                    NaN
# 64264  Houzz Interior Design Ideas  ...                    NaN
# 64265  Houzz Interior Design Ideas  ...                    NaN
# 64266  Houzz Interior Design Ideas  ...                    NaN
# 64267  Houzz Interior Design Ideas  ...                    NaN
# 64268  Houzz Interior Design Ideas  ...                    NaN
# 64269  Houzz Interior Design Ideas  ...                    NaN
# 64270  Houzz Interior Design Ideas  ...                    NaN
# 64271  Houzz Interior Design Ideas  ...                    NaN
# 64272  Houzz Interior Design Ideas  ...                    NaN
# 64273  Houzz Interior Design Ideas  ...                    NaN
# 64274  Houzz Interior Design Ideas  ...                    NaN
# 64275  Houzz Interior Design Ideas  ...                    NaN
# 64276  Houzz Interior Design Ideas  ...                    NaN
# 64277  Houzz Interior Design Ideas  ...                    NaN
# 64278  Houzz Interior Design Ideas  ...                    NaN
# 64279  Houzz Interior Design Ideas  ...                    NaN
# 64280  Houzz Interior Design Ideas  ...                    NaN
# 64281  Houzz Interior Design Ideas  ...                    NaN
# 64282  Houzz Interior Design Ideas  ...                    NaN
# 64283  Houzz Interior Design Ideas  ...                    NaN
# 64284  Houzz Interior Design Ideas  ...                    NaN
# 64285  Houzz Interior Design Ideas  ...                    NaN
# 64286  Houzz Interior Design Ideas  ...                    NaN
# 64287  Houzz Interior Design Ideas  ...                    NaN
# 64288  Houzz Interior Design Ideas  ...                    NaN
# 64289  Houzz Interior Design Ideas  ...                    NaN
# 64290  Houzz Interior Design Ideas  ...                    NaN
# 64291  Houzz Interior Design Ideas  ...                    NaN
# 64292  Houzz Interior Design Ideas  ...                    NaN
# 64293  Houzz Interior Design Ideas  ...                    NaN
# 64294  Houzz Interior Design Ideas  ...                    NaN
#
# [59 rows x 5 columns]

# %% [markdown]
# **Removing the missing values from the User reviews dataset**.

# %%
new_df_reviews = df_reviews.dropna()
new_df_reviews
# Out:
#                                   App  ... Sentiment_Subjectivity
# 0               10 Best Foods for You  ...               0.533333
# 1               10 Best Foods for You  ...               0.288462
# 3               10 Best Foods for You  ...               0.875000
# 4               10 Best Foods for You  ...               0.300000
# 5               10 Best Foods for You  ...               0.300000
# ...                               ...  ...                    ...
# 64222  Housing-Real Estate & Property  ...               0.486667
# 64223  Housing-Real Estate & Property  ...               0.447222
# 64226  Housing-Real Estate & Property  ...               0.250000
# 64227  Housing-Real Estate & Property  ...               1.000000
# 64230  Housing-Real Estate & Property  ...               0.400000
#
# [37427 rows x 5 columns]

# %%
new_df_reviews.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
import missingno as msno
msno.matrix(new_df_reviews)
plt.show()

# %% [markdown]
# **This shows that the missing data in the User Data has been removed successfully.**

# %%
grp = new_df_reviews.groupby('App')
x = grp['Sentiment_Polarity'].agg(np.mean)
y = grp['Sentiment_Subjectivity'].agg(np.mean)
print(x)
print(y)
# Out:
# App
# 10 Best Foods for You                                 0.470733
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      0.392405
# 11st                                                  0.185943
# 1800 Contacts - Lens Store                            0.318145
# 1LINE – One Line with One Touch                       0.196290
#                                                         ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals    0.101622
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        0.251765
# Hotstar                                               0.038178
# Hotwire Hotel & Car Rental App                        0.187029
# Housing-Real Estate & Property                       -0.021427
# Name: Sentiment_Polarity, Length: 865, dtype: float64
# App
# 10 Best Foods for You                                 0.495455
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      0.545516
# 11st                                                  0.455340
# 1800 Contacts - Lens Store                            0.591098
# 1LINE – One Line with One Touch                       0.557315
#                                                         ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals    0.545444
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        0.393284
# Hotstar                                               0.493964
# Hotwire Hotel & Car Rental App                        0.459717
# Housing-Real Estate & Property                        0.378532
# Name: Sentiment_Subjectivity, Length: 865, dtype: float64

# %% [markdown]
# # **Merging dataframes on apps**

# %%
merged_df = df.merge(new_df_reviews, on="App")
merged_df
# Out:
#                                 App  ... Sentiment_Subjectivity
# 0               Coloring book moana  ...               1.000000
# 1               Coloring book moana  ...               0.833333
# 2               Coloring book moana  ...               0.000000
# 3               Coloring book moana  ...               0.600000
# 4               Coloring book moana  ...               0.900000
# ...                             ...  ...                    ...
# 59158  A+ Gallery - Photos & Videos  ...               0.512500
# 59159  A+ Gallery - Photos & Videos  ...               0.733333
# 59160  A+ Gallery - Photos & Videos  ...               0.200000
# 59161  A+ Gallery - Photos & Videos  ...               0.000000
# 59162  A+ Gallery - Photos & Videos  ...               0.450000
#
# [59163 rows x 17 columns]

# %% [markdown]
# **In the merged dataframe, we have three new columns i.e.. Sentiment, Sentiment Polarity and Sentiment Subjectivity. Sentiment basically determines the attitude or the emotion of the writer, i.e., whether it is positive or negative or neutral. Sentiment Polarity is float which lies in the range of [-1,1] where 1 means positive statement and -1 means a negative statement. Sentiment Subjectivity generally refer to personal opinion, emotion or judgment, which lies in the range of [0,1]**

# %% [markdown]
# #**5. Dataset Visualization**
# **Asking questions and aswering them.**
# * **Installs per Category**
# * **Pricing vs Category**
# * **Number of Reviews per Category**
# * **What are the top 20 apps present in the google play store per in the Genres?**
# * **What are the Genre that are getting installed the most in top 20 Genres?**
# * **Count of applications for each Category**
# * **Number of Installed applications for each category**
# * **Distribution of Rating**
# * **Highest and Lowest Genres**
# * **Rating according to Genres**
# * **What are teh count of applications in each category differentiated by their type**
# * **How many apps wqere installed according to their type**
# * **How does size impact on the Number of installs of any applications**
# * **Histogram of log installs**
# * **Histogram of size**
# * **Different Android Version**
# * **Scatter Matrix**
# * **What is the percentage of paid to free apps?**
# * **What is the most dominant category?**
# * **What size should my app have?**
# * **What price should my paid app have?**
# * **What are the number of installs for apps priced more than $100?**
# * **What is the most successful category?**
# * **Distribution of app sizes**
# * **Rating per categories and type**
# * **Distribution of content rating per categories**
# * **Number of Installs type wise according to Genre**
# * **Histogram of Subjectivity**
# * **Does Sentiment_subjectivity propotional to sentiment_polarity**
# * **Wordcloud**
# * **Percentage of Review Sentiments**

# %%
  grp = df1.groupby('Category')
  x = grp['Installs'].agg(np.mean)
  y = grp['Price'].agg(np.sum)
  z = grp['Reviews'].agg(np.mean)
  print(x)
  print(y)
  print(z)
# Out:
# Category
# ART_AND_DESIGN         2.003760e+06
# AUTO_AND_VEHICLES      7.278055e+05
# BEAUTY                 6.408619e+05
# BOOKS_AND_REFERENCE    1.082651e+07
# BUSINESS               3.198215e+06
# COMICS                 9.661397e+05
# COMMUNICATION          7.867180e+07
# DATING                 1.298883e+06
# EDUCATION              4.138388e+06
# ENTERTAINMENT          2.212306e+07
# EVENTS                 3.544313e+05
# FAMILY                 5.844663e+06
# FINANCE                2.430008e+06
# FOOD_AND_DRINK         2.431866e+06
# GAME                   2.937045e+07
# HEALTH_AND_FITNESS     5.194680e+06
# HOUSE_AND_HOME         1.839441e+06
# LIBRARIES_AND_DEMO     9.551231e+05
# LIFESTYLE              1.753250e+06
# MAPS_AND_NAVIGATION    5.840867e+06
# MEDICAL                1.396115e+05
# NEWS_AND_MAGAZINES     2.520145e+07
# PARENTING              6.223222e+05
# PERSONALIZATION        6.691461e+06
# PHOTOGRAPHY            3.197777e+07
# PRODUCTIVITY           3.731458e+07
# SHOPPING               1.273927e+07
# SOCIAL                 5.128624e+07
# SPORTS                 5.344516e+06
# TOOLS                  1.560044e+07
# TRAVEL_AND_LOCAL       3.103346e+07
# VIDEO_PLAYERS          3.888686e+07
# WEATHER                5.681287e+06
# Name: Installs, dtype: float64
# Category
# ART_AND_DESIGN            5.97
# AUTO_AND_VEHICLES         1.99
# BEAUTY                    0.00
# BOOKS_AND_REFERENCE      23.88
# BUSINESS                 64.41
# COMICS                    0.00
# COMMUNICATION            56.69
# DATING                   22.96
# EDUCATION                17.96
# ENTERTAINMENT             7.98
# EVENTS                    0.00
# FAMILY                 2282.78
# FINANCE                2439.87
# FOOD_AND_DRINK            8.48
# GAME                    280.36
# HEALTH_AND_FITNESS       42.39
# HOUSE_AND_HOME            0.00
# LIBRARIES_AND_DEMO        0.00
# LIFESTYLE              1960.88
# MAPS_AND_NAVIGATION      26.95
# MEDICAL                 648.86
# NEWS_AND_MAGAZINES        3.98
# PARENTING                 9.58
# PERSONALIZATION         125.27
# PHOTOGRAPHY              76.26
# PRODUCTIVITY             70.92
# SHOPPING                  5.48
# SOCIAL                    1.98
# SPORTS                   93.21
# TOOLS                   207.90
# TRAVEL_AND_LOCAL         37.49
# VIDEO_PLAYERS            10.46
# WEATHER                  29.43
# Name: Price, dtype: float64
# Category
# ART_AND_DESIGN         2.765116e+04
# AUTO_AND_VEHICLES      1.594014e+04
# BEAUTY                 9.407929e+03
# BOOKS_AND_REFERENCE    1.235752e+05
# BUSINESS               4.576928e+04
# COMICS                 5.830940e+04
# COMMUNICATION          1.958544e+06
# DATING                 3.487525e+04
# EDUCATION              1.795715e+05
# ENTERTAINMENT          4.285650e+05
# EVENTS                 3.568667e+03
# FAMILY                 2.309480e+05
# FINANCE                5.362640e+04
# FOOD_AND_DRINK         7.237033e+04
# GAME                   1.318002e+06
# HEALTH_AND_FITNESS     1.177293e+05
# HOUSE_AND_HOME         4.109399e+04
# LIBRARIES_AND_DEMO     1.590054e+04
# LIFESTYLE              4.203134e+04
# MAPS_AND_NAVIGATION    2.472505e+05
# MEDICAL                4.623930e+03
# NEWS_AND_MAGAZINES     1.787145e+05
# PARENTING              1.907218e+04
# PERSONALIZATION        2.425575e+05
# PHOTOGRAPHY            6.720308e+05
# PRODUCTIVITY           3.070486e+05
# SHOPPING               4.699553e+05
# SOCIAL                 2.186789e+06
# SPORTS                 2.283990e+05
# TOOLS                  3.721855e+05
# TRAVEL_AND_LOCAL       2.710488e+05
# VIDEO_PLAYERS          6.898731e+05
# WEATHER                1.947293e+05
# Name: Reviews, dtype: float64

# %% [markdown]
# ## **Number of Installs per Category**

# %%
plt.figure(figsize=(20,10))
plt.plot(x, 'ro', color='b')
plt.xticks(rotation = 90)
plt.title('Number of Installs per Category')
plt.xlabel('Categories ------->')
plt.ylabel('Installs ------>');

# %% [markdown]
# ### **Pricing per Category**

# %%
plt.figure(figsize = (20,10))
plt.plot(y, 'r--', color = 'r')
plt.xticks(rotation = 90)
plt.title('Pricing per Category')
plt.xlabel('Catgories ------>')
plt.ylabel('Prices ----->');

# %% [markdown]
# ### **Number of Reviews per Category**

# %%
plt.figure(figsize = (20,10))
plt.plot(z, 'g^', color = 'g')
plt.xticks(rotation = 90)
plt.title('Category vs Reviews')
plt.xlabel('Catgories ------>')
plt.ylabel('Reviews ----->');

# %% [markdown]
# ### **What are the top 20 apps present in the google play store as per their Genres?**

# %%
top_genres = df1.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
genres_installs = df1.groupby(['Genres'])[['Installs']].sum()
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.head(20)

plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Which are the Genres that are getting installed the most in top 20 Genres?**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Installs")
plt.title("Installs according to Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Installs)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **As we can see from the above two plots: Maxinum number of apps present in google play store comes under Tools, Entertainment and Education Genres but as per the installation and requirement in the market plot, scenario is not the same. Maximum installed apps comes under Communication, Tools and Productivity Genres.**

# %% [markdown]
# ### **Count of applications for each Category**

# %%
top_category = df1.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})
category_installs = df1.groupby(['Category'])[['Installs']].sum()
top_category_installs = pd.merge(top_category, category_installs, on='Category')
top_20_category_installs = top_category_installs

plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of application")
plt.title("Count of applications for each Category")
sns.barplot(top_20_category_installs.Category, top_20_category_installs.Count)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Number of installed applications for each Category**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installed applications for each Category")
sns.barplot(top_20_category_installs.Category, top_20_category_installs.Installs)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Average rating**

# %%
df1.dropna()
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10834                                      FR Calculator  ...          4.1 and up
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  ...  Varies with device
#
# [8892 rows x 13 columns]

# %%
genres_ratings_df = df1.groupby(['Genres'])[['Rating']].mean()
genres_installs_ratings = pd.merge(top_genres_installs, genres_ratings_df, on='Genres')
genres_installs_ratings['Rating'].describe()
# Out:
# count    115.000000
# mean       4.258865
# std        0.182193
# min        3.800000
# 25%        4.148914
# 50%        4.266667
# 75%        4.354464
# max        4.800000
# Name: Rating, dtype: float64

# %% [markdown]
# ### **Distribution of Rating**

# %%
plt.figure(figsize=(14,7))
g = sns.kdeplot(genres_installs_ratings.Rating, color="Green", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
plt.show()

# %% [markdown]
# ### **Highest and lowest rated Genres**

# %%
genres_installs_ratings.sort_values('Rating', ascending =False, inplace=True)

highest_rated_genres = genres_installs_ratings.iloc[0:20]
lowest_rated_genres = genres_installs_ratings.iloc[-20:]
lowest_rated_genres = lowest_rated_genres[lowest_rated_genres['Rating'].notnull()]

plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Rating")
plt.title("Ratings according to Genres")
sns.barplot(highest_rated_genres.Genres, highest_rated_genres.Rating)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **Ratings according to Genres**

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65)
plt.xlabel("Genres")
plt.ylabel("Rating")
plt.title("Ratings according to Genres")
sns.barplot(lowest_rated_genres.Genres, lowest_rated_genres.Rating)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### **What are the count of applications in each category differentiated by their type?**

# %%
app_count = df1.groupby(['Category','Type'])[['App']].count().reset_index().rename(columns={'App':'Count','index':'App'})
df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()


df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9))
plt.xlabel("Category", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Count of applications in each category differentiated by their type")
plt.show()

# %% [markdown]
# **It looks like certain app categories have more free apps available for download than others. In our dataset, the majority of apps in Family, Food & Drink and Tools, as well as Social categories were free to install. At the same time Family, Sports, Tools and Medical categories had the biggest number of paid apps available for download.**

# %% [markdown]
# ### **How many apps were installed according to its type?**

# %%
df['log_installs'] = np.log2(df1['Installs'])
df['Gaming Category App'] = df1['Category']=='GAME'
categoty_type_installs = df1.groupby(['Category','Type'])[['Installs']].sum().reset_index()
categoty_type_installs['log_Installs'] = np.log2(categoty_type_installs['Installs'])

plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Category")
sns.barplot('Category', 'log_Installs', hue='Type', data=categoty_type_installs);
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **It can be concludd that the number of free applications installed by the user are high when compared with the paid ones.**

# %% [markdown]
# **Size of the applications present in the datset are in MB and KB. Therefore for ease in data processing, converting entire size column to MB.**

# %%
# Converting KB to MB 
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(x))

# %% [markdown]
# ### **How does size impact on the number of installs of any application?**

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(df['Size'], df['log_installs'], hue=df['Type'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## **Histogram of log installs**

# %%
df.loc[df['log_installs']== df['log_installs'].min(),'log_installs']=0


plt.xlabel("Log of Installs")
plt.title("Distribution of Logrithm of Installs")
plt.hist(df['log_installs']);

# %% [markdown]
# ### **Histogram of size**

# %%
# to remove null values from size column
df1.loc[df1['Size'].isnull(),'Size']=0

plt.xlabel("Size")
plt.title("Distribution of Size")
plt.hist(df['Size']);
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# ## ** Different Android version**

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
import plotly.graph_objects as go
labels = df1['Android Ver'].unique()
values=[]
for each in labels:
    values.append(len(df1[df1['Android Ver']==each]))

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3, title="Android Version")])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cd57a94d-331f-4be0-80e2-f001ef522088" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd57a94d-331f-4be0-80e2-f001ef522088")) {                    Plotly.newPlot(                        "cd57a94d-331f-4be0-80e2-f001ef522088",                        [{"hole":0.3,"labels":["4.0.3 and up","4.2 and up","4.4 and up","2.3 and up","3.0 and up","4.1 and up","4.0 and up","2.3.3 and up","Varies with device","2.2 and up","5.0 and up","6.0 and up","1.6 and up","1.5 and up","2.1 and up","7.0 and up","4.3 and up","4.0.3 - 7.1.1","2.0 and up","3.2 and up","4.4W and up","5.1 and up","7.1 and up","7.0 - 7.1.1","8.0 and up","5.0 - 8.0","3.1 and up","2.0.1 and up","4.1 - 7.1.1","5.0 - 6.0","1.0 and up"],"title":{"text":"Android Version"},"values":[1197,331,789,573,207,1989,1094,238,1178,203,481,46,87,16,112,41,199,2,27,31,5,16,3,1,5,2,8,7,1,1,2],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"t ...

# %% [markdown]
# ## **Scatter Plot**

# %%
sns.pairplot(df1[["Size", "Reviews", "Installs", "Rating", "Type"]], hue="Type", palette="GnBu")

# %% [markdown]
# **This matches our assumption that size greatly affects other features. The Scatter Matrix shows that when the app size is relatively small, other features prosper. This shows that cosumer behaviour on the play store is greatly affected by the app download size**.
#
# **Takeaway: Developers should optimize their app download size as much as possible**

# %% [markdown]
# ###**What is the percentage of paid to free apps?**

# %%
plt.rcParams['figure.figsize']=(14,7)
size = df1["Type"].value_counts()
labels = df1["Type"].unique()
colors=["#43a6cc", "#bae4bf"]

plt.pie(size, labels=labels, colors=colors, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## **What size should my app have?**

# %%
plt.rcParams['figure.figsize']=(20,15)
medians = df.groupby(['Category'])['Size'].median().values
median_labels = [str(np.round(s, 2)) for s in medians]
ax = sns.boxplot(x="Size", y="Category", data=df, palette="GnBu")
ax = sns.boxplot()
df["Size"].mean()
# Out:
# 21.28778830257038

# %% [markdown]
# **The trend is games have a much larger download size than any other category. If you're developing anything other than a game, you need to optimize your downlaod size. on Average any app should have a size of 17.8 MB.**

# %% [markdown]
# ### **What is the most dominant category?**

# %%
categories = df1["Category"].value_counts()
sns.barplot(x=categories.values, y=categories.index, palette="GnBu")

# %% [markdown]
# **This is an interesting finding, our first assumption for the most dominant category was family.**

# %% [markdown]
# ###**What price should my paid app have?**

# %%
paid_apps = df1[df1["Type"] == "Paid"]
sns.boxplot(x="Price", y="Category", data=paid_apps, palette="GnBu")
df1["Price"].mean()
# Out:
# 0.9631545209176688

# %% [markdown]
# **Finance and lifestyle are valued the most but it's intresting to find that there are apps with values of more than $100.**
#
# **On average an app price is $1 **

# %% [markdown]
# ### **What are the number of installs for apps priced more than $100?**

# %%
plt.rcParams['figure.figsize']=(10,5)
expensive_apps = df1[df1["Price"] > 100]
sns.lineplot(x="Price", y="Installs", data=expensive_apps, palette="GnBu")

# %% [markdown]
# ### **What is the most successful category?**

# %%
plt.rcParams['figure.figsize']=(10,10)
plot = sns.barplot(x="Installs", y="Category", data=df1, palette="GnBu")

# %% [markdown]
# **Most successful category based on the number of installs is the communication category.**

# %% [markdown]
# ### **Distribution of app sizes**

# %%
plt.rcParams['figure.figsize']=(10,5)
sns.distplot(df["Size"], color="blue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### **Rating per categories and type**

# %%
plt.rcParams['figure.figsize']=(10,17)
sns.violinplot(x="Rating", y="Category", hue="Type", data=df1, split=True, palette="GnBu")

# %% [markdown]
# ### **Distribution of content rating per categories**
#
# ---

# %%
plt.rcParams['figure.figsize']=(10,15)
content_category = df1[["Content Rating", "Category"]].groupby(["Content Rating", "Category"]).size().reset_index(name='counts')
sns.barplot(x="counts" , y="Category", hue="Content Rating",data=content_category, palette="GnBu")

# %% [markdown]
# ### **Number of installs type wise according to Genres**

# %%
category_sentiment = merged_df.groupby(['Category','Sentiment']).size().reset_index(name='Sentiment Count')
category_sentiment['log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])

plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installs type wise according to Genres")
sns.barplot('Category', 'log_sentiment_count', hue='Sentiment', data=category_sentiment);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### **Histogram of subjectivity**

# %%
plt.figure(figsize=(14,7))
plt.xlabel("Subjectivity")
plt.title("Distribution of Subjectivity")
plt.hist(merged_df[merged_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'])
plt.show()

# %% [markdown]
# **It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that macimum number of users give reviews to the applications, according to their experience.**

# %% [markdown]
# ### **Does sentiment_subjectivity proportional to sentiment_polarity?**

# %%
sentimet_subjectivity_polarity = merged_df.groupby(['Category'])['Sentiment_Polarity','Sentiment_Subjectivity'].mean().reset_index().rename(columns={'Sentiment_Polarity':'Sentiment_polarity_avg','Sentiment_Subjectivity':'sentiment_subjectivity_avg'})
merged_df['Sentiment_Subjectivity'] = merged_df['Sentiment_Subjectivity'].abs()
merged_df['Sentiment_Polarity'] = merged_df['Sentiment_Polarity'].abs()

plt.figure(figsize=(14,7))
sns.scatterplot(merged_df['Sentiment_Subjectivity'], merged_df['Sentiment_Polarity'])
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# **From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low**

# %% [markdown]
# ### **Wordcloud**

# %%
review_notnull = merged_df[merged_df['Translated_Review'].notnull()]

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = review_notnull.Translated_Review.values
wordcloud = WordCloud(
    width = 3920,
    height = 2080,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text).lower())
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### **Percentage of Review Sentimets**

# %%
import matplotlib
counts = list(merged_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negetive Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (8, 8)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentimets', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()
